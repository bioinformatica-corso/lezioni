# %% [markdown]
# # Esercizio 2
#
# Considerare il file `movies.csv` ottenuto estraendo i primi 1000 record del dataset scaricabile all'indirizzo https://www.kaggle.com/rounakbanik/the-movies-dataset#movies_metadata.csv.
# Tale dataset è in formato csv e contiene, in *record* di 24 campi separati da virgola, le informazioni su film.
#
# Il file `movies.csv` contiene solo un subset dei campi del dataset originale.
#
# ---
#
# I campi del file csv che occorrono per risolvere l'esercizio sono:
#
# - `id`: indice progressivo
# - `genres`: stringa che rappresenta il letterale di una lista di dizionari con chiavi `id` e `name` che forniscono ciascuno un genere
#
#         [{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}]
#
# - `original_title`: titolo originale
# - `popularity`: valore di popolarità
# - `tagline`: tagline del film
# - `original_language`: lingua originale
# - `production_countries`: stringa che rappresenta il letterale di una lista di dizionari con chiavi `iso_3166_1` e `name` che forniscono ciascuno un paese di origine
#
#          [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]
#
# ***
#
# Si richiede di:
# - elencare i 10 paesi che hanno prodotto più film, ordinandoli per numero decrescente di film prodotti, specificando per ognuno il numero di film prodotti
# - fornire per ognuno dei generi cinematografici presenti nel dataset la classifica degli N (parametro in input) film più popolari (per quel genere) ordinandoli per popolarità decrescente e specificando per ognuno di essi il titolo originale e la tagline
# - l'insieme delle lingue originali che sono coinvolte nella classifica precedente
#
# ---
#
# Parametri di input:
# - dataset dei film
# - parametro N
#
# ---
#
# Requisiti generali:
#
# - definire una funzione `get_items()` che prenda in input uno qualsiasi tra i due campi `genres`e `production_countries` (indifferentemente) ed estragga
#     - la lista dei generi nel caso si passi come argomento il valore di un campo `genres`
#     - la lista dei paesi di produzione nel caso si passi come argomento il valore di un campo `production_countries`
#
# Produrre l'output nelle seguenti variabili:
#
# - lista di 10 tuple di due elementi `(nome di paese, numero di film prodotti)` contenenti i primi 10 paesi che hanno prodotto più film, ordinate per numero decrescente di film prodotti
# - dizionario delle classifiche per genere dei primi N film ordinati per popolarità decrescente:
#     - *chiave*: genere di un film
#     - *valore*: lista di N liste di due elementi `[titolo originale, tagline]` con i primi N film ordinati per popolarità decrescente
# - dizionario degli insiemi delle lingue coinvolte in ciascuna delle classifiche precedenti per genere:
#     - *chiave*: genere di un film
#     - *valore*: insieme delle lingue originali coinvolte
#
# ***

# %% [markdown]
# ### 1) Come leggere un file csv
#
# Il modulo `pandas` permette di leggere un file in formato csv (anche zippato) tramite la funzione `read_csv()`, che prende come argomento il nome del file da leggere.
#
# L'oggetto restituito è un oggetto di tipo `DataFrame` (un *data frame*), cioé una tabella organizzata in righe (*record*) e colonne intestate.
#
# Il codice seguente
#
#     import pandas as pd
#     df = pd.read_csv(input_file_name)
#
# legge il file `input_file_name` e lo restituisce in un oggetto di tipo `DataFrame`.

# %%
import pandas as pd
df = pd.read_csv('movies.csv')
df
# Out:
#       id                                             genres  \
# 0      0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4      4                     [{'id': 35, 'name': 'Comedy'}]
# 5      5  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 6      6  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 7      7  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 8      8  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 9      9  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 10    10  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 11    11  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 12    12  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 13    13  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...
# 14    14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 15    15  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 16    16  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 17    17  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 18    18  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...
# 19    19  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 20    20  [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'nam...
# 21    21  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 22    22  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 23    23  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 24    24  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 25    25                      [{'id': 18, 'name': 'Drama'}]
# 26    26  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 27    27  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 28    28  [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...
# 29    29  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# ..   ...                                                ...
# 970  970  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 971  971  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 972  972                     [{'id': 35, 'name': 'Comedy'}]
# 973  973                                                 []
# 974  974  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
#
# 9                 No limits. No fears. No substitutes.                en
# 10   Why can't the most powerful man in the world h...                en
# 11                                                 NaN                en
# 12                      Part Dog. Part Wolf. All Hero.                en
# 13   Triumphant in Victory, Bitter in Defeat. He Ch...                en
# 14   The Course Has Been Set. There Is No Turning B...                en
# 15                    No one stays at the top forever.                en
# 16            Lose your heart and come to your senses.                en
# 17   Twelve outrageous guests. Four scandalous requ...                en
# 18             New animals. New adventures. Same hair.                en
# 19                         Get on, or GET OUT THE WAY!                en
# 20   The mob is tough, but it’s nothing like show b...                en
# 21   One man is copying the most notorious killers ...                en
# 22   In the shadows of life, In the business of dea...                en
# 23   An extraordinary encounter with another human ...                en
# 24                      I Love You... The Way You Are.                en
# 25                     Envy, greed, jealousy and love.                en
# 26   In every woman there is the girl she left behind.                en
# 27                                                 NaN                en
# 28           Where happily ever after is just a dream.                fr
# 29   In 1930's Shanghai violence was not the proble...                zh
# ..                                                 ...               ...
# 970  You have one minute to decide the rest of your...                en
# 971                                                NaN                en
# 972                                                NaN                en
# 973           It's the hardest move a guy has to make.                en
# 974               Not all surgery is intended to cure.                en
# 975                  Two good cops. One bad situation.                en
# 976         No Fear. No Limits. No Brakes. Just Ducks.                en
# 977                                                NaN                en
# 978  Wanted: For chicanery, skulduggery, tomfoolery...                en
# 979                NOW...on the MOTION PICTURE SCREEN!                en
# 980  Caught in a world where they don't belong... t...                en
# 981          Herbie will honk his way into your heart.                en
# 982           The Loveable Bug's back doin' his thing!                en
# 983  All the heart, all the excitement of a great f...                en
# 984                                                NaN                en
# 985  Meet the people, the pleasure, the entertainme...                en
# 986                                                NaN                en
# 987                            "I was a Teen-age boy!"                en
# 988                       THE ADVENTURE OF ADVENTURES!                en
# 989  It takes a Siamese secret agent to unravel the...                en
# 990          The mightiest motion picture of them all!                en
# 991      One dream. Four Jamaicans. Twenty below zero.                en
# 992                                  Ya Gotta Believe!                en
# 993                 The greatest love story ever told.                en
# 994                                                NaN                en
# 995                                                NaN                en
# 996  Tired of living in a Medieval mess...Merlin us...                en
# 997                                                NaN                en
# 998  For the good of all men, and the love of one w...                en
# 999           It's supercalifragilisticexpialidocious!                en
#
#                                   production_countries
# 0    [{'iso_3166_1': 'US', 'name': 'United States o...
# 1    [{'iso_3166_1': 'US', 'name': 'United States o...
# 2    [{'iso_3166_1': 'US', 'name': 'United States o...
# 3    [{'iso_3166_1': 'US', 'name': 'United States o...
# 4    [{'iso_3166_1': 'US', 'name': 'United States o...
# 5    [{'iso_3166_1': 'US', 'name': 'United States o...
# 6    [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...
# 7    [{'iso_3166_1': 'US', 'name': 'United States o...
# 8    [{'iso_3166_1': 'US', 'name': 'United States o...
# 9    [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
# 10   [{'iso_3166_1': 'US', 'name': 'United States o...
# 11   [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...
# 12   [{'iso_3166_1': 'US', 'name': 'United States o...
# 13   [{'iso_3166_1': 'US', 'name': 'United States o...
# 14   [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...
# 15   [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...
# 16   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
# 17   [{'iso_3166_1': 'US', 'name': 'United States o...
# 18   [{'iso_3166_1': 'US', 'name': 'United States o...
# 19   [{'iso_3166_1': 'US', 'name': 'United States o...
# 20   [{'iso_3166_1': 'US', 'name': 'United States o...
# 21   [{'iso_3166_1': 'US', 'name': 'United States o...
# 22   [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...
# 23   [{'iso_3166_1': 'US', 'name': 'United States o...
# 24   [{'iso_3166_1': 'US', 'name': 'United States o...
# 25             [{'iso_3166_1': 'IT', 'name': 'Italy'}]
# 26   [{'iso_3166_1': 'US', 'name': 'United States o...
# 27   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...
# 28   [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...
# 29   [{'iso_3166_1': 'CN', 'name': 'China'}, {'iso_...
# ..                                                 ...
# 970  [{'iso_3166_1': 'US', 'name': 'United States o...
# 971  [{'iso_3166_1': 'US', 'name': 'United States o...
# 972                                                 []
# 973                                                 []
# 974  [{'iso_3166_1': 'US', 'name': 'United States o...
# 975  [{'iso_3166_1': 'US', 'name': 'United States o...
# 976  [{'iso_3166_1': 'US', 'name': 'United States o...
# 977  [{'iso_3166_1': 'US', 'name': 'United States o...
# 978  [{'iso_3166_1': 'US', 'name': 'United States o...
# 979  [{'iso_3166_1': 'US', 'name': 'United States o...
# 980  [{'iso_3166_1': 'US', 'name': 'United States o...
# 981  [{'iso_3166_1': 'US', 'name': 'United States o...
# 982  [{'iso_3166_1': 'US', 'name': 'United States o...
# 983  [{'iso_3166_1': 'US', 'name': 'United States o...
# 984  [{'iso_3166_1': 'US', 'name': 'United States o...
# 985  [{'iso_3166_1': 'US', 'name': 'United States o...
# 986  [{'iso_3166_1': 'US', 'name': 'United States o...
# 987  [{'iso_3166_1': 'US', 'name': 'United States o...
# 988  [{'iso_3166_1': 'TT', 'name': 'Trinidad and To...
# 989  [{'iso_3166_1': 'US', 'name': 'United States o...
# 990  [{'iso_3166_1': 'US', 'name': 'United States o...
# 991  [{'iso_3166_1': 'US', 'name': 'United States o...
# 992  [{'iso_3166_1': 'US', 'name': 'United States o...
# 993  [{'iso_3166_1': 'US', 'name': 'United States o...
# 994  [{'iso_3166_1': 'US', 'name': 'United States o...
# 995  [{'iso_3166_1': 'US', 'name': 'United States o...
# 996  [{'iso_3166_1': 'US', 'name': 'United States o...
# 997  [{'iso_3166_1': 'US', 'name': 'United States o...
# 998  [{'iso_3166_1': 'US', 'name': 'United States o...
# 999  [{'iso_3166_1': 'US', 'name': 'United States o...
#
# [1000 rows x 7 columns]

# %% [markdown]
# Per iterare lungo i record del *data frame* basta invocare il metodo `iterrows()` che restituisce un oggetto di tipo `generator` da usare in un ciclo `for` di scansione.
#
#     for (index, record) in df.iterrows():
#         do_something
#
# Ogni elemento fornito dell'iteratore è una tupla di due elementi:
# - `index`: indice progressivo del record (valore intero)
# - `record`: oggetto di tipo `Series` che contiene i campi del *record*
#
# L'accesso al campo relativo alla colonna con nome `column_name` del *record* `record` avviene usando la seguente sintassi:
#
#     record[column_name]
#
# **NOTA BENE**: il valore restituito da `record[column_name]` rispetta il tipo della colonna `column_name` nel file csv in input. Ad esempio se il campo nel dataset csv è un valore decimale allora il valore di `record[column_name]` sarà di tipo `float`.

# %%
for (index, record) in df.iterrows():
    print(record['popularity'])
# Out:
# 21.946943
# 17.015539
# 11.7129
# 3.859495
# 8.387519000000001
# 17.924927
# 6.677277
# 2.561161
# 5.23158
# 14.686035999999998
# 6.318445
# 5.430331
# 12.140733
# 5.092
# 7.284477000000001
# 10.137389
# 10.673167
# 9.026586
# 8.205447999999999
# 7.3379059999999985
# 12.669608
# 10.701801
# 11.065939
# 12.133094
# 10.332025
# 1.845899
# 8.681325
# 2.228434
# 9.822423
# 1.100915
# 9.481338
# 12.297305
# 0.745542
# 14.404764000000002
# 2.9236720000000003
# 11.709777
# 15.811921
# 22.494622
# 0.949155
# 12.06308
# 5.076649
# 8.590813
# 9.955445
# 10.135111
# 5.47596
# 9.813419
# 5.4905050000000015
# 2.469167
# 3.573935
# 5.120036
# 8.196679
# 10.36311
# 1.954175
# 10.685036
# 7.431939
# 9.884516
# 3.008607
# 3.166544
# 7.122093
# 7.274947999999998
# 5.480098
# 10.864284
# 6.4288300000000005
# 10.573867
# 9.88321
# 6.164226
# 15.031588
# 8.168694
# 6.60577
# 2.446972
# 0.284522
# 0.264695
# 1.831221
# 0.594433
# 4.709847
# 1.758391
# 0.8965049999999999
# 8.08426
# 5.865697
# 8.85591
# 1.450989
# 14.384198
# 6.636872
# 2.001733
# 11.794846
# 0.912955
# 10.750619
# 0.348765
# 0.367546
# 1.914697
# 0.283269
# 0.064512
# 1.0600969999999998
# 1.463219
# 8.500509
# 0.580724
# 0.537795
# 0.00264
# 5.5111550000000005
# 1.262649
# 9.364418
# 0.751733
# 7.370163000000002
# 6.728199000000001
# 6.746475
# 1.226688
# 2.702973
# 11.845918
# 1.625873
# 6.85606
# 4.989276
# 2.781581
# 0.000308
# 0.5502779999999999
# 4.990506
# 5.918737
# 5.511475
# 3.998494
# 4.040945
# 5.4973589999999986
# 7.1516910000000005
# 10.091707
# 4.914603
# 12.887829
# 5.807074
# 3.254308
# 7.186506
# 3.404213
# 4.623089
# 2.8036790000000003
# 8.722406
# 8.307210000000001
# 10.892812
# 14.436858
# 1.054814
# 8.702472
# 10.636458
# 0.901443
# 10.639244
# 15.11549

# %% [markdown]
# ### 2) Come interpretare *letteralmente* una stringa

# %% [markdown]
# La funzione `literal_eval()` del modulo `ast`  prende come argomento una stringa e restituice l'oggetto rappresentato *letteralmente* dalla stringa.

# %%
import ast

ast.literal_eval("[1,2,3]")
# Out:
# [1, 2, 3]

# %% [markdown]
# ### 3) Come testare se un valore è NaN (Not a Number)
#
# La funzione `isnan()` del modulo `numpy` restituisce il valore `True` se il valore passato come argomento è NaN.

# %%
import numpy

numpy.isnan(10)
# Out:
# False

# %% [markdown]
# ### 4) Funzioni/Metodi suggeriti

# %% [markdown]
# - la funzione `sorted()` prende come argomento un oggetto iterabile e restituisce la lista dei valori ordinati in senso crescente.

# %%
lista = [(11.02, 3), (10.2, 1), (11.02, 2), (2.34, 10)]
sorted(lista)
# Out:
# [(2.34, 10), (10.2, 1), (11.02, 2), (11.02, 3)]

# %% [markdown]
# - Il metodo `append()` degli oggetti di tipo `list` aggiunge in coda alla lista invocante il valore passato come argomento

# %%
lista = [1,2,3,4]
lista.append([5, 6])
lista
# Out:
# [1, 2, 3, 4, [5, 6]]

# %% [markdown]
# - Il metodo `extend()` degli oggetti di tipo `list` estende in coda la lista invocante con i valori contenuti nell'argomento passato

# %%
lista = [1,2,3,4]
lista.extend([5, 6])
lista
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# - il metodo `get` degli oggetti di tipo `dict` permette di ottenere il valore relativo alla chiave passata come primo argomento e di restituire il secondo argomento (valore di default) se la chiave non è presente nel dizionario.

# %%
my_dict = {'due': 2, 'quattro': 4, 'sei': 6}

# %%
my_dict.get('due', -1)
# Out:
# 2

# %%
my_dict.get('cinque', -1)
# Out:
# -1
