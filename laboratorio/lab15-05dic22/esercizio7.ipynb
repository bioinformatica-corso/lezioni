# %% [markdown]
# # Esercizio7 - Pysam

# %% [markdown]
# Prendere in input un file in formato `BAM` che contiene allineamenti al cromosoma X (*reference*) e:
#
# - controllare se sono presenti *paired-end* reads
# - determinare le lunghezze degli introni supportati dagli allineamenti del file `BAM`, senza utilizzare il metodo `find_introns()`
# - determinare la base della *reference* che ha la massima copertura in termini di reads allineati e produrre un file SAM contenente gli allineamenti che coprono tale base

# %% [markdown]
# ### 1) Importare `pysam` e la classe `AlignmentFile`

# %%
import pysam

# %%
from pysam import AlignmentFile

# %% [markdown]
# ### 2) Leggere il file `BAM` in input

# %%
pysam.index('./sample.bam')
# Out:
# ''

# %%
bam_file = AlignmentFile('./sample.bam', 'rb')

# %%
bam_file

# %% [markdown]
# ### 3) Controllare se sono presenti *paired-end* reads.

# %%
alignment_iter = bam_file.fetch()
alignment_list = list(alignment_iter)

any([alignment.is_paired for alignment in alignment_list])
# Out:
# False

# %% [markdown]
# ### 4) Determinare le lunghezze degli introni supportati dagli allineamenti nel file `BAM`

# %% [markdown]
# a) Ricavare l'insieme delle lunghezze degli introni supportati dalle cigar strings che contengono un'operazione `N` (cioé un inserimento nella reference che corrisponde a un introne).

# %%
import re

# %%
set([int(re.search(r'(\d+)N', alignment.cigarstring).group(1)) for alignment in alignment_list if 'N' in alignment.cigarstring])
# Out:
# {57, 287, 309, 598, 980, 1514, 1999, 4116, 4226}

# %% [markdown]
# b) Verificare che si trova la stessa cosa utilizzando il metodo `find_introns()`

# %%
set([intron[1]-intron[0] for intron in bam_file.find_introns(bam_file.fetch())])
# Out:
# {57, 287, 309, 598, 980, 1514, 1999, 4116, 4226}

# %% [markdown]
# ### 5) Trovare la base della reference che ha copertura massima

# %% [markdown]
# a) Determinare la lista delle colonne di *pileup*.

# %%
pileup_iter = bam_file.pileup()

# %%
pileup_columns = list(pileup_iter)

# %%
pileup_columns
# Out:
# [<pysam.libcalignedsegment.PileupColumn at 0x111819ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x111819b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x111819ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x111819c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x111819c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x111819cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x111819d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x111819dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x111819e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x111819eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x111819f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x111819f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced0b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced2e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced3c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced4a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced5f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced6d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced7b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ced9e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceda50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cedac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cedb30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cedba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cedc10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cedc80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cedcf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cedd60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceddd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cede40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cedeb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cedf20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cedf90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb0b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb2e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb3c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb4a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb5f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb6d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb7b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x111819a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceb9e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceba50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cebac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cebb30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cebba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cebc10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cebc80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cebcf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cebd60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x111819970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x111819660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cebdd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cebe40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cebeb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cebf20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cebf90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec0b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec2e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec3c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec4a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x1118199e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec5f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec6d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec7b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cec9e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceca50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cecac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cecb30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cecba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cecc10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cecc80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceccf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cecd60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cecdd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cece40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceceb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cecf20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cecf90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee0b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee2e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee3c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee4a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee5f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee6d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee7b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cee9e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceea50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceeac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceeb30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceeba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceec10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceec80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceecf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceed60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceedd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceee40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceeeb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceef20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceef90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef0b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef2e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef3c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef4a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef5f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef6d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef7b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cef9e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cefa50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cefac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cefb30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cefba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cefc10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cefc80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cefcf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cefd60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cefdd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cefe40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cefeb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceff20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112ceff90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf00b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf02e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf03c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf04a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf05f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf06d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf07b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf09e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf0f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf10b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf12e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf13c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf14a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf15f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf16d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf17b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf19e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf1f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf30b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf32e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf33c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf34a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf35f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf36d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf37b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf39e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf3f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf40b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf42e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf43c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf44a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf45f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf46d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf47b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf49e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf4f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf50b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf52e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf53c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf54a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf55f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf56d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf57b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf59e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf5f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf60b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf62e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf63c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf64a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf65f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf66d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf67b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf69e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf6f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf70b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf72e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf73c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf74a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf75f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf76d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf77b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf79e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf7f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf90b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf92e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf93c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf94a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf95f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf96d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf97b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf99e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cf9f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb0b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb2e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb3c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb4a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb5f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb6d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb7b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfb9e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfba50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfbac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfbb30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfbba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfbc10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfbc80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfbcf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfbd60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfbdd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfbe40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfbeb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfbf20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfbf90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc0b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc2e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc3c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc4a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc5f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc6d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc7b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfc9e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfca50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfcac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfcb30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfcba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfcc10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfcc80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfccf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfcd60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfcdd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfce40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfceb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfcf20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfcf90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd0b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd2e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd3c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd4a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd5f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd6d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd7b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfd9e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfda50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfdac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfdb30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfdba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfdc10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfdc80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfdcf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfdd60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfddd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfde40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfdeb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfdf20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfdf90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe0b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe2e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe3c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe4a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe5f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe6d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe7b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfe9e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfea50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfeac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfeb30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfeba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfec10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfec80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfecf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfed60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfedd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfee40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfeeb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfef20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfef90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff0b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff2e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff3c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff4a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff5f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff6d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff7b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cff9e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cffa50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cffac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cffb30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cffba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cffc10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cffc80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cffcf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cffd60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cffdd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cffe40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cffeb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfff20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112cfff90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d000b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d002e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d003c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d004a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d005f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d006d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d007b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d009e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d00f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d010b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d012e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d013c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d014a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d015f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d016d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d017b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d019e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d01f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d030b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d032e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d033c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d034a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d035f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d036d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d037b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d039e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d03f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d040b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d042e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d043c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d044a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d045f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d046d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d047b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d049e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d04f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d070b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d072e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d073c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d074a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d075f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d076d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d077b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d079e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d07f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d080b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d082e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d083c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d084a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d085f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d086d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d087b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d089e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d08f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d090b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d092e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d093c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d094a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d095f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d096d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d097b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d099e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09a50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09ac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09b30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09ba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09c10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09c80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09cf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09d60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09dd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09e40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09eb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09f20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d09f90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a0b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a2e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a3c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a4a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a5f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a6d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a7b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0a9e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0aa50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0aac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0ab30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0aba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0ac10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0ac80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0acf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0ad60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0add0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0ae40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0aeb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0af20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0af90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b0b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b2e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b3c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b4a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b510>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b580>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b5f0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b660>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b6d0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b740>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b7b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b820>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b890>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b900>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b970>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0b9e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0ba50>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0bac0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0bb30>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0bba0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0bc10>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0bc80>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0bcf0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0bd60>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0bdd0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0be40>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0beb0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0bf20>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0bf90>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0c040>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0c0b0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0c120>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0c190>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0c200>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0c270>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0c2e0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0c350>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0c3c0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0c430>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0c4a0>,
#  <pysam.libcalignedsegment.PileupColumn at 0x112d0c510>,
#  ...]

# %% [markdown]
# b) Estrarre le colonna di altezza massima (cioé coperta dal maggior numero di allineamenti).

# %%
max_height = max([pileup_col.nsegments for pileup_col in pileup_columns])

# %%
max_pileup_col = [pileup_col for pileup_col in pileup_columns if pileup_col.nsegments == max_height][0]

# %%
max_pileup_col.nsegments
# Out:
# 1469

# %%
max_pileup_col.pos
# Out:
# 286723

# %% [markdown]
# ### 6) Produrre il file `SAM` contenente gli allineamenti che coprono la base di copertura massima.
#
# Produrre gli allineamenti in un SAM file utilizzando la stessa Header Section del BAM file.

# %%
max_pileup_col.set_min_base_quality(0)

# %%
max_pileup_col.pileups
# Out:
# [<pysam.libcalignedsegment.PileupRead at 0x112e5ed60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5f310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5f4a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5f680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5f5e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5f720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5f770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5f6d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5f7c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5f860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5f8b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5f950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5f9a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5fc70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5fbd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5fcc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5fd10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5fd60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5fdb0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5fe00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5fea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5fe50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5fef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5ff40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e5ff90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e0e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e1d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e2c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e3b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e4a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e4f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e6d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e7c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e8b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e9a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6e9f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6ea40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6ea90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6eae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6eb30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6eb80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6ec20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6ec70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6ed10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6ed60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6ee50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6eef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6ee00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6eea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6ef40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6ef90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f0e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f1d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f2c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f3b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f4a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f4f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f5e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f6d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f7c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6f950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fa90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fb30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fb80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fbd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fc70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fc20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fcc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fd10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fd60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fdb0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fe00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fe50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6fef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6ff40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e6ff90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e741d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e742c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e743b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e744f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e745e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e746d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e747c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74a40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e749a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e749f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74ae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74b30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74a90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74b80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74bd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74c20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74c70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74cc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74d10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74d60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74ea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112e74f90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec10e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec11d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec12c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec13b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec14a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec14f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec15e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec16d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec17c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec18b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec19a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec19f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1a40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1a90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1ae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1b30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1b80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1bd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1c20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1c70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1cc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1d10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1d60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1db0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1e00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1e50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1ea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1ef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1f40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec1f90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec30e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec31d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec32c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec33b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec34a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec34f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec35e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec36d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec37c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec38b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec39a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec39f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3a40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3a90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3ae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3b30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3b80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3bd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3c20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3c70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3cc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3d10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3d60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3db0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3e00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3e50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3ea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3ef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3f40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec3f90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec60e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec61d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec62c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec63b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec64a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec64f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec65e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec66d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec67c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec68b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec69a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec69f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6a40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6a90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6ae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6b30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6b80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6bd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6c20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6c70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6cc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6d10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6d60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6db0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6e00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6e50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6ea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6ef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6f40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec6f90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec80e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec81d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec82c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec83b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec84a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec84f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec85e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec86d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec87c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec88b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec89a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec89f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8a40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8a90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8ae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8b30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8b80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8bd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8c20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8c70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8cc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8d10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8d60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8db0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8e00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8e50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8ea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8ef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8f40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ec8f90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca0e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca1d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca2c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca3b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca4a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca4f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca5e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca6d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca7c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca8b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca9a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eca9f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecaa40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecaa90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecaae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecab30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecab80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecabd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecac20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecac70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecacc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecad10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecad60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecadb0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecae00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecae50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecaea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecaef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecaf40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecaf90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc0e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc1d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc2c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc3b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc4a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc4f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc5e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc6d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc7c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc8b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc9a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecc9f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecca40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecca90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eccae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eccb30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eccb80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eccbd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eccc20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eccc70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecccc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eccd10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eccd60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eccdb0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecce00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecce50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eccea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eccef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eccf40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eccf90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece0e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece1d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece2c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece3b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece4a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece4f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece5e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece6d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece7c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece8b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece9a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ece9f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecea40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecea90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eceae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eceb30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eceb80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecebd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecec20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecec70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ececc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eced10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eced60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecedb0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecee00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecee50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eceea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eceef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecef40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ecef90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed10e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed11d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed12c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed13b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed14a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed14f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed15e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed16d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed17c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed18b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed19a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed19f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1a40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1a90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1ae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1b30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1b80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1bd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1c20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1c70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1cc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1d10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1d60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1db0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1e00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1e50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1ea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1ef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1f40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed1f90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed30e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed31d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed32c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed33b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed34a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed34f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed35e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed36d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed37c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed38b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed39a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed39f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3a40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3a90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3ae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3b30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3b80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3bd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3c20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3c70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3cc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3d10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3d60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3db0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3e00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3e50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3ea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3ef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3f40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed3f90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed50e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed51d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed52c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed53b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed54a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed54f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed55e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed56d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed57c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed58b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed59a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed59f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5a40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5a90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5ae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5b30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5b80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5bd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5c20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5c70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5cc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5d10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5d60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5db0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5e00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5e50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5ea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5ef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5f40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed5f90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed70e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed71d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed72c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed73b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed74a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed74f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed75e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed76d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed77c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed78b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed79a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed79f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7a40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7a90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7ae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7b30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7b80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7bd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7c20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7c70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7cc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7d10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7d60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7db0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7e00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7e50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7ea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7ef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7f40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed7f90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed90e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed91d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed92c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed93b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed94a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed94f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed95e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed96d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed97c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed98b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed99a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed99f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9a40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9a90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9ae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9b30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9b80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9bd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9c20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9c70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9cc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9d10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9d60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9db0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9e00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9e50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9ea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9ef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9f40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ed9f90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc0e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc1d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc2c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc3b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc4a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc4f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc5e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc6d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc7c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc8b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc9a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edc9f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edca40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edca90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edcae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edcb30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edcb80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edcbd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edcc20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edcc70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edccc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edcd10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edcd60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edcdb0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edce00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edce50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edcea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edcef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edcf40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edcf90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede0e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede1d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede2c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede3b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede4a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede4f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede5e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede6d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede7c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede8b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede9a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ede9f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edea40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edea90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edeae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edeb30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edeb80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edebd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edec20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edec70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edecc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eded10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112eded60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ededb0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edee00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edee50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edeea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edeef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edef40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112edef90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee00e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee01d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee02c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee03b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee04a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee04f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee05e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee06d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee07c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee08b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee09a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee09f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0a40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0a90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0ae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0b30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0b80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0bd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0c20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0c70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0cc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0d10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0d60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0db0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0e00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0e50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0ea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0ef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0f40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee0f90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee20e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee21d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee22c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee23b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee24a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee24f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee25e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee26d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee27c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee28b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee29a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee29f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2a40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2a90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2ae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2b30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2b80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2bd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2c20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2c70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2cc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2d10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2d60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2db0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2e00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2e50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2ea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2ef0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2f40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee2f90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4040>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4090>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee40e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4130>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4180>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee41d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4220>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4270>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee42c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4310>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4360>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee43b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4400>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4450>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee44a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee44f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4540>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4590>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee45e0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4630>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4680>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee46d0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4720>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4770>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee47c0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4810>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4860>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee48b0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4900>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4950>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee49a0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee49f0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4a40>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4a90>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4ae0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4b30>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4b80>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4bd0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4c20>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4c70>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4cc0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4d10>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4d60>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4db0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4e00>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4e50>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4ea0>,
#  <pysam.libcalignedsegment.PileupRead at 0x112ee4ef0>,
#  ...]

# %%
pileup_alignments = [pileup_read.alignment for pileup_read in max_pileup_col.pileups]

# %%
output_file = pysam.AlignmentFile('./prova.sam', 'w', template=bam_file)

# %%
for alignment in pileup_alignments:
    output_file.write(alignment)
    
output_file.close()
