# %% [markdown]
# # Introduzione a Pandas
#
# *Data Frame* (oggetto di tipo `DataFrame`): tabella che organizza i dati in righe (*record*) e colonne con un'intestazione.
#
# Ogni colonna contiene dati di tipo omogeneo.
#
# Ad ognuna delle righe viene associato un indice (chiave primaria), che di default è un numero intero progressivo.
#
# Righe e colonne sono oggetti di tipo `Series`.
#
# ### Funzionalità
#
# 1. costruzione
# 1. interrogazione
# 1. aggiornamento
#
# Formati da cui derivare un *data frame*: `csv`, `excel`, `json`.
#
# ---
#
# Importare `Pandas`.

# %%
import pandas as pd

# %% [markdown]
# ---
#
# ## Creazione di un *Data Frame* a partire da un dizionario
#
#        df = pd.DataFrame(data_dictionary)

# %%
data_dictionary = {'Cognome' : ['Rossi', 'Bianchi', 'Verdi', 'Neri'],
                   'Nome' : ['Andrea', 'Sara', 'Tommaso', 'Anna'],
                  'AnnoNascita' : [2000, 2001, 1999, 2004]}

# %%
pd.DataFrame(data_dictionary)
# Out:
#    Cognome     Nome  AnnoNascita
# 0    Rossi   Andrea         2000
# 1  Bianchi     Sara         2001
# 2    Verdi  Tommaso         1999
# 3     Neri     Anna         2004

# %% [markdown]
# ---
#
# ## Creazione di un *Data Frame* a partire da una lista
#
#        df = pd.DataFrame(data_list, columns = column_names)

# %%
data_list = []
data_list.append(['Rossi', 'Andrea', 2000])
data_list.append(['Bianchi', 'Sara', 2001])
data_list.append(['Verdi', 'Tommaso', 1999])
data_list.append(['Neri', 'Anna', 2004])

# %%
pd.DataFrame(data_list, columns = ['Cognome', 'Nome', 'AnnoNascita'])
# Out:
#    Cognome     Nome  AnnoNascita
# 0    Rossi   Andrea         2000
# 1  Bianchi     Sara         2001
# 2    Verdi  Tommaso         1999
# 3     Neri     Anna         2004

# %% [markdown]
# ---
#
# ## Creazione di un *Data Frame* da un file `csv`
#
#     df = pd.read_csv(csv_file_name)

# %% [markdown]
# ### Lettura del file `2017-german-election-overall.csv`

# %%
df = pd.read_csv('./2017-german-election-overall.csv')

# %% [markdown]
# ---
#
# ## Recuperare informazioni sul *Data Frame*
#
#         df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   area_id               299 non-null    int64
#  1   area_names            299 non-null    object
#  2   state                 299 non-null    object
#  3   registered.voters     299 non-null    int64
#  4   total_votes           299 non-null    int64
#  5   invalid_first_votes   299 non-null    int64
#  6   invalid_second_votes  299 non-null    int64
#  7   valid_first_votes     299 non-null    int64
#  8   valid_second_votes    299 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 21.1+ KB

# %% [markdown]
# ---
#
# ## Ottenere le prime/ultime `n` righe
#
#     df.head(n)
#     df.tail(n)

# %%
df.head(10)
# Out:
#    area_id                          area_names               state  \
# 0        1               Flensburg – Schleswig  Schleswig-Holstein
# 1        2   Nordfriesland – Dithmarschen Nord  Schleswig-Holstein
# 2        3        Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 3        4               Rendsburg-Eckernförde  Schleswig-Holstein
# 4        5                                Kiel  Schleswig-Holstein
# 5        6                   Plön – Neumünster  Schleswig-Holstein
# 6        7                           Pinneberg  Schleswig-Holstein
# 7        8           Segeberg – Stormarn-Mitte  Schleswig-Holstein
# 8        9         Ostholstein – Stormarn-Nord  Schleswig-Holstein
# 9       10  Herzogtum Lauenburg – Stormarn-Süd  Schleswig-Holstein
#
#    registered.voters  total_votes  invalid_first_votes  invalid_second_votes  \
# 0             225659       171905                 1647                  1509
# 1             186384       139200                 1299                  1125
# 2             175950       132016                 1133                  1141
# 3             199632       157387                 1285                  1119
# 4             204650       151463                 1657                  1290
# 5             174934       131710                 1221                  1196
# 6             237474       187711                 1616                  1339
# 7             245826       193318                 1628                  1381
# 8             181480       138415                 1151                  1142
# 9             244503       193359                 1597                  1388
#
#    valid_first_votes  valid_second_votes
# 0             170258              170396
# 1             137901              138075
# 2             130883              130875
# 3             156102              156268
# 4             149806              150173
# 5             130489              130514
# 6             186095              186372
# 7             191690              191937
# 8             137264              137273
# 9             191762              191971

# %% [markdown]
# ---
#
# ## Fare una copia di un *data frame*
#
#         df.copy()

# %%
df.copy()
# Out:
#      area_id                         area_names               state  \
# 0          1              Flensburg – Schleswig  Schleswig-Holstein
# 1          2  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein
# 2          3       Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 3          4              Rendsburg-Eckernförde  Schleswig-Holstein
# 4          5                               Kiel  Schleswig-Holstein
# ..       ...                                ...                 ...
# 294      295           Zollernalb – Sigmaringen   Baden-Württemberg
# 295      296                        Saarbrücken            Saarland
# 296      297                          Saarlouis            Saarland
# 297      298                         St. Wendel            Saarland
# 298      299                            Homburg            Saarland
#
#      registered.voters  total_votes  invalid_first_votes  \
# 0               225659       171905                 1647
# 1               186384       139200                 1299
# 2               175950       132016                 1133
# 3               199632       157387                 1285
# 4               204650       151463                 1657
# ..                 ...          ...                  ...
# 294             183202       139544                 2354
# 295             199887       147602                 2304
# 296             207500       160371                 2422
# 297             177468       141378                 2620
# 298             192408       145990                 2668
#
#      invalid_second_votes  valid_first_votes  valid_second_votes
# 0                    1509             170258              170396
# 1                    1125             137901              138075
# 2                    1141             130883              130875
# 3                    1119             156102              156268
# 4                    1290             149806              150173
# ..                    ...                ...                 ...
# 294                  1818             137190              137726
# 295                  2171             145298              145431
# 296                  2831             157949              157540
# 297                  2668             138758              138710
# 298                  2467             143322              143523
#
# [299 rows x 9 columns]

# %% [markdown]
# ---
#
# ## Variabile `shape`

# %%
df.shape
# Out:
# (299, 9)

# %% [markdown]
# ## Variabile  `columns`

# %%
list(df.columns)
# Out:
# ['area_id',
#  'area_names',
#  'state',
#  'registered.voters',
#  'total_votes',
#  'invalid_first_votes',
#  'invalid_second_votes',
#  'valid_first_votes',
#  'valid_second_votes']

# %% [markdown]
# ---
#
# ## Cambiare i nomi delle colonne
#
#     df.rename(columns = name_dict, inplace = False)

# %%
df.rename(columns = {'registered.voters' : 'voters', 'area_names' : 'area'}, inplace = True)

# %%
df
# Out:
#      area_id                               area               state  voters  \
# 0          1              Flensburg – Schleswig  Schleswig-Holstein  225659
# 1          2  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein  186384
# 2          3       Steinburg – Dithmarschen Süd  Schleswig-Holstein  175950
# 3          4              Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 4          5                               Kiel  Schleswig-Holstein  204650
# ..       ...                                ...                 ...     ...
# 294      295           Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 295      296                        Saarbrücken            Saarland  199887
# 296      297                          Saarlouis            Saarland  207500
# 297      298                         St. Wendel            Saarland  177468
# 298      299                            Homburg            Saarland  192408
#
#      total_votes  invalid_first_votes  invalid_second_votes  \
# 0         171905                 1647                  1509
# 1         139200                 1299                  1125
# 2         132016                 1133                  1141
# 3         157387                 1285                  1119
# 4         151463                 1657                  1290
# ..           ...                  ...                   ...
# 294       139544                 2354                  1818
# 295       147602                 2304                  2171
# 296       160371                 2422                  2831
# 297       141378                 2620                  2668
# 298       145990                 2668                  2467
#
#      valid_first_votes  valid_second_votes
# 0               170258              170396
# 1               137901              138075
# 2               130883              130875
# 3               156102              156268
# 4               149806              150173
# ..                 ...                 ...
# 294             137190              137726
# 295             145298              145431
# 296             157949              157540
# 297             138758              138710
# 298             143322              143523
#
# [299 rows x 9 columns]

# %% [markdown]
# ---
#
# ## Rimuovere righe o colonne
#
#     df.drop(list_to_remove, axis = 1|0, inplace = False)
#
# ---

# %% [markdown]
# **ESERCIZIO**: rimuovere le colonne `valid_first_votes` e `invalid_first_votes` e in seguito le righe con indice `2`, `9` e `10`.

# %%
df.drop(['valid_first_votes', 'invalid_first_votes'], axis = 1, inplace = True)

# %%
df
# Out:
#      area_id                               area               state  voters  \
# 0          1              Flensburg – Schleswig  Schleswig-Holstein  225659
# 1          2  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein  186384
# 2          3       Steinburg – Dithmarschen Süd  Schleswig-Holstein  175950
# 3          4              Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 4          5                               Kiel  Schleswig-Holstein  204650
# ..       ...                                ...                 ...     ...
# 294      295           Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 295      296                        Saarbrücken            Saarland  199887
# 296      297                          Saarlouis            Saarland  207500
# 297      298                         St. Wendel            Saarland  177468
# 298      299                            Homburg            Saarland  192408
#
#      total_votes  invalid_second_votes  valid_second_votes
# 0         171905                  1509              170396
# 1         139200                  1125              138075
# 2         132016                  1141              130875
# 3         157387                  1119              156268
# 4         151463                  1290              150173
# ..           ...                   ...                 ...
# 294       139544                  1818              137726
# 295       147602                  2171              145431
# 296       160371                  2831              157540
# 297       141378                  2668              138710
# 298       145990                  2467              143523
#
# [299 rows x 7 columns]

# %%
df.drop([2,9,10], axis = 0, inplace = True)

# %%
df.head(20)
# Out:
#     area_id                                               area  \
# 0         1                              Flensburg – Schleswig
# 1         2                  Nordfriesland – Dithmarschen Nord
# 3         4                              Rendsburg-Eckernförde
# 4         5                                               Kiel
# 5         6                                  Plön – Neumünster
# 6         7                                          Pinneberg
# 7         8                          Segeberg – Stormarn-Mitte
# 8         9                        Ostholstein – Stormarn-Nord
# 11       12  Schwerin – Ludwigslust-Parchim I – Nordwestmec...
# 12       13  Ludwigslust-Parchim II – Nordwestmecklenburg I...
# 13       14                     Rostock – Landkreis Rostock II
# 14       15         Vorpommern-Rügen – Vorpommern-Greifswald I
# 15       16  Mecklenburgische Seenplatte I – Vorpommern-Gre...
# 16       17  Mecklenburgische Seenplatte II – Landkreis Ros...
# 17       18                                      Hamburg-Mitte
# 18       19                                     Hamburg-Altona
# 19       20                                 Hamburg-Eimsbüttel
# 20       21                                       Hamburg-Nord
# 21       22                                   Hamburg-Wandsbek
# 22       23                        Hamburg-Bergedorf – Harburg
#
#                      state  voters  total_votes  invalid_second_votes  \
# 0       Schleswig-Holstein  225659       171905                  1509
# 1       Schleswig-Holstein  186384       139200                  1125
# 3       Schleswig-Holstein  199632       157387                  1119
# 4       Schleswig-Holstein  204650       151463                  1290
# 5       Schleswig-Holstein  174934       131710                  1196
# 6       Schleswig-Holstein  237474       187711                  1339
# 7       Schleswig-Holstein  245826       193318                  1381
# 8       Schleswig-Holstein  181480       138415                  1142
# 11  Mecklenburg-Vorpommern  216743       157070                  1658
# 12  Mecklenburg-Vorpommern  205757       146781                  1673
# 13  Mecklenburg-Vorpommern  222718       164037                  1731
# 14  Mecklenburg-Vorpommern  240887       169526                  2115
# 15  Mecklenburg-Vorpommern  225843       156966                  2159
# 16  Mecklenburg-Vorpommern  212051       144268                  1791
# 17                 Hamburg  243510       175800                  1460
# 18                 Hamburg  185942       146025                   949
# 19                 Hamburg  192399       156001                   860
# 20                 Hamburg  217226       178302                   899
# 21                 Hamburg  235513       172545                  1389
# 22                 Hamburg  222034       155709                  1555
#
#     valid_second_votes
# 0               170396
# 1               138075
# 3               156268
# 4               150173
# 5               130514
# 6               186372
# 7               191937
# 8               137273
# 11              155412
# 12              145108
# 13              162306
# 14              167411
# 15              154807
# 16              142477
# 17              174340
# 18              145076
# 19              155141
# 20              177403
# 21              171156
# 22              154154

# %% [markdown]
# ---
#
# ## Estrarre una colonna
#
#     df[column_name]
#     df.column_name
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre la colonna `voters` e aggiornare a 0 tutti i valori della colonna `area_id`.

# %%
df['voters']
# Out:
# 0      225659
# 1      186384
# 3      199632
# 4      204650
# 5      174934
#         ...
# 294    183202
# 295    199887
# 296    207500
# 297    177468
# 298    192408
# Name: voters, Length: 296, dtype: int64

# %%
df.voters
# Out:
# 0      225659
# 1      186384
# 3      199632
# 4      204650
# 5      174934
#         ...
# 294    183202
# 295    199887
# 296    207500
# 297    177468
# 298    192408
# Name: voters, Length: 296, dtype: int64

# %%
df['area_id'] = 0

# %%
df
# Out:
#      area_id                               area               state  voters  \
# 0          0              Flensburg – Schleswig  Schleswig-Holstein  225659
# 1          0  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein  186384
# 3          0              Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 4          0                               Kiel  Schleswig-Holstein  204650
# 5          0                  Plön – Neumünster  Schleswig-Holstein  174934
# ..       ...                                ...                 ...     ...
# 294        0           Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 295        0                        Saarbrücken            Saarland  199887
# 296        0                          Saarlouis            Saarland  207500
# 297        0                         St. Wendel            Saarland  177468
# 298        0                            Homburg            Saarland  192408
#
#      total_votes  invalid_second_votes  valid_second_votes
# 0         171905                  1509              170396
# 1         139200                  1125              138075
# 3         157387                  1119              156268
# 4         151463                  1290              150173
# 5         131710                  1196              130514
# ..           ...                   ...                 ...
# 294       139544                  1818              137726
# 295       147602                  2171              145431
# 296       160371                  2831              157540
# 297       141378                  2668              138710
# 298       145990                  2467              143523
#
# [296 rows x 7 columns]

# %% [markdown]
# ---
#
# ## Estrarre più colonne
#
#
#     df[column_list]
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre le colonne `voters` e `total_votes`.

# %%
df[['voters', 'total_votes']]
# Out:
#      voters  total_votes
# 0    225659       171905
# 1    186384       139200
# 3    199632       157387
# 4    204650       151463
# 5    174934       131710
# ..      ...          ...
# 294  183202       139544
# 295  199887       147602
# 296  207500       160371
# 297  177468       141378
# 298  192408       145990
#
# [296 rows x 2 columns]

# %%
df[['voters']]
# Out:
#      voters
# 0    225659
# 1    186384
# 3    199632
# 4    204650
# 5    174934
# ..      ...
# 294  183202
# 295  199887
# 296  207500
# 297  177468
# 298  192408
#
# [296 rows x 1 columns]

# %% [markdown]
# ---
#
# ## Ottenere gli indici (chiavi primarie) di un data frame (o di una colonna)
#
#     df.index
#     column.index
#
# ---

# %%
df.state.index
# Out:
# Index([  0,   1,   3,   4,   5,   6,   7,   8,  11,  12,
#        ...
#        289, 290, 291, 292, 293, 294, 295, 296, 297, 298],
#       dtype='int64', length=296)

# %% [markdown]
# ---
#
# ## Aggiornare i valori di una colonna
#
#     df[column_name] = series_obj
#
# ---

# %%
df
# Out:
#      area_id                               area               state  voters  \
# 0          0              Flensburg – Schleswig  Schleswig-Holstein  225659
# 1          0  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein  186384
# 3          0              Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 4          0                               Kiel  Schleswig-Holstein  204650
# 5          0                  Plön – Neumünster  Schleswig-Holstein  174934
# ..       ...                                ...                 ...     ...
# 294        0           Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 295        0                        Saarbrücken            Saarland  199887
# 296        0                          Saarlouis            Saarland  207500
# 297        0                         St. Wendel            Saarland  177468
# 298        0                            Homburg            Saarland  192408
#
#      total_votes  invalid_second_votes  valid_second_votes
# 0         171905                  1509              170396
# 1         139200                  1125              138075
# 3         157387                  1119              156268
# 4         151463                  1290              150173
# 5         131710                  1196              130514
# ..           ...                   ...                 ...
# 294       139544                  1818              137726
# 295       147602                  2171              145431
# 296       160371                  2831              157540
# 297       141378                  2668              138710
# 298       145990                  2467              143523
#
# [296 rows x 7 columns]

# %% [markdown]
# **ESERCIZIO**: aggiornare i valori della colonna `area_id` con il relativo indice.

# %%
df['area_id'] = df.index

# %%
df
# Out:
#      area_id                               area               state  voters  \
# 0          0              Flensburg – Schleswig  Schleswig-Holstein  225659
# 1          1  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein  186384
# 3          3              Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 4          4                               Kiel  Schleswig-Holstein  204650
# 5          5                  Plön – Neumünster  Schleswig-Holstein  174934
# ..       ...                                ...                 ...     ...
# 294      294           Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 295      295                        Saarbrücken            Saarland  199887
# 296      296                          Saarlouis            Saarland  207500
# 297      297                         St. Wendel            Saarland  177468
# 298      298                            Homburg            Saarland  192408
#
#      total_votes  invalid_second_votes  valid_second_votes
# 0         171905                  1509              170396
# 1         139200                  1125              138075
# 3         157387                  1119              156268
# 4         151463                  1290              150173
# 5         131710                  1196              130514
# ..           ...                   ...                 ...
# 294       139544                  1818              137726
# 295       147602                  2171              145431
# 296       160371                  2831              157540
# 297       141378                  2668              138710
# 298       145990                  2467              143523
#
# [296 rows x 7 columns]

# %% [markdown]
# ---
#
# ## Aggiungere una colonna
#
#     df[new_column_name] = series_obj
#
# ---

# %% [markdown]
# **ESERCIZIO**: aggiungere la colonna che contiene la percentuale dei voti totali sui votanti.

# %%
df['vote_percentage'] = (df['total_votes'] / df['voters'] * 100).round(2)

# %%
df
# Out:
#      area_id                               area               state  voters  \
# 0          0              Flensburg – Schleswig  Schleswig-Holstein  225659
# 1          1  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein  186384
# 3          3              Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 4          4                               Kiel  Schleswig-Holstein  204650
# 5          5                  Plön – Neumünster  Schleswig-Holstein  174934
# ..       ...                                ...                 ...     ...
# 294      294           Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 295      295                        Saarbrücken            Saarland  199887
# 296      296                          Saarlouis            Saarland  207500
# 297      297                         St. Wendel            Saarland  177468
# 298      298                            Homburg            Saarland  192408
#
#      total_votes  invalid_second_votes  valid_second_votes  vote_percentage
# 0         171905                  1509              170396            76.18
# 1         139200                  1125              138075            74.68
# 3         157387                  1119              156268            78.84
# 4         151463                  1290              150173            74.01
# 5         131710                  1196              130514            75.29
# ..           ...                   ...                 ...              ...
# 294       139544                  1818              137726            76.17
# 295       147602                  2171              145431            73.84
# 296       160371                  2831              157540            77.29
# 297       141378                  2668              138710            79.66
# 298       145990                  2467              143523            75.88
#
# [296 rows x 8 columns]

# %% [markdown]
# ---
#
# ## Selezionare righe tramite *slicing*
#
#
#     df[start_pos_index:end_pos_index:step]
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre le righe dalla quarta alla undicesima.

# %%
df[3:11]
# Out:
#     area_id                                               area  \
# 4         4                                               Kiel
# 5         5                                  Plön – Neumünster
# 6         6                                          Pinneberg
# 7         7                          Segeberg – Stormarn-Mitte
# 8         8                        Ostholstein – Stormarn-Nord
# 11       11  Schwerin – Ludwigslust-Parchim I – Nordwestmec...
# 12       12  Ludwigslust-Parchim II – Nordwestmecklenburg I...
# 13       13                     Rostock – Landkreis Rostock II
#
#                      state  voters  total_votes  invalid_second_votes  \
# 4       Schleswig-Holstein  204650       151463                  1290
# 5                  unknown  174934       131710                  1196
# 6       Schleswig-Holstein  237474       187711                  1339
# 7       Schleswig-Holstein  245826       193318                  1381
# 8       Schleswig-Holstein  181480       138415                  1142
# 11  Mecklenburg-Vorpommern  216743       157070                  1658
# 12  Mecklenburg-Vorpommern  205757       146781                  1673
# 13  Mecklenburg-Vorpommern  222718       164037                  1731
#
#     valid_second_votes  vote_percentage
# 4               150173            74.01
# 5               130514            75.29
# 6               186372            79.04
# 7               191937            78.64
# 8               137273            76.27
# 11              155412            72.47
# 12              145108            71.34
# 13              162306            73.65

# %% [markdown]
# ---
#
# ## Selezionare righe in base a una condizione
#
#     df[mask]
#
# `mask` è un oggetto di tipo `Series` che contiene valori booleani `True` e `False`.
#
# Viene restituito un *data frame* con le sole righe che corrispondono a un valore `True` di `mask`.
#
# ---

# %%
df
# Out:
#      area_id                               area               state  voters  \
# 0          0              Flensburg – Schleswig  Schleswig-Holstein  225659
# 1          1  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein  186384
# 3          3              Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 4          4                               Kiel  Schleswig-Holstein  204650
# 5          5                  Plön – Neumünster  Schleswig-Holstein  174934
# ..       ...                                ...                 ...     ...
# 294      294           Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 295      295                        Saarbrücken            Saarland  199887
# 296      296                          Saarlouis            Saarland  207500
# 297      297                         St. Wendel            Saarland  177468
# 298      298                            Homburg            Saarland  192408
#
#      total_votes  invalid_second_votes  valid_second_votes  vote_percentage
# 0         171905                  1509              170396            76.18
# 1         139200                  1125              138075            74.68
# 3         157387                  1119              156268            78.84
# 4         151463                  1290              150173            74.01
# 5         131710                  1196              130514            75.29
# ..           ...                   ...                 ...              ...
# 294       139544                  1818              137726            76.17
# 295       147602                  2171              145431            73.84
# 296       160371                  2831              157540            77.29
# 297       141378                  2668              138710            79.66
# 298       145990                  2467              143523            75.88
#
# [296 rows x 8 columns]

# %% [markdown]
# **ESERCIZIO**: estrarre i *records* che si riferiscono a `Berlin`.

# %%
mask = df['state'] == 'Berlin'
df[mask]
# Out:
#     area_id                                               area   state  \
# 74       74                                       Berlin-Mitte  Berlin
# 75       75                                      Berlin-Pankow  Berlin
# 76       76                               Berlin-Reinickendorf  Berlin
# 77       77               Berlin-Spandau – Charlottenburg Nord  Berlin
# 78       78                         Berlin-Steglitz-Zehlendorf  Berlin
# 79       79                  Berlin-Charlottenburg-Wilmersdorf  Berlin
# 80       80                        Berlin-Tempelhof-Schöneberg  Berlin
# 81       81                                    Berlin-Neukölln  Berlin
# 82       82  Berlin-Friedrichshain-Kreuzberg – Prenzlauer B...  Berlin
# 83       83                            Berlin-Treptow-Köpenick  Berlin
# 84       84                         Berlin-Marzahn-Hellersdorf  Berlin
# 85       85                                 Berlin-Lichtenberg  Berlin
#
#     voters  total_votes  invalid_second_votes  valid_second_votes  \
# 74  206706       151634                  2214              149420
# 75  237071       188607                  2198              186409
# 76  182392       137084                  2171              134913
# 77  184602       132934                  2276              130658
# 78  221209       180827                  2110              178717
# 79  198672       158245                  1429              156816
# 80  235250       181259                  2162              179097
# 81  202616       143790                  2980              140810
# 82  223426       173504                  1664              171840
# 83  205105       157461                  2124              155337
# 84  200704       138988                  2064              136924
# 85  205300       149053                  2153              146900
#
#     vote_percentage
# 74            73.36
# 75            79.56
# 76            75.16
# 77            72.01
# 78            81.74
# 79            79.65
# 80            77.05
# 81            70.97
# 82            77.66
# 83            76.77
# 84            69.25
# 85            72.60

# %% [markdown]
# ---
#
# **ESERCIZIO**: estrarre il data frame che contiene solo le aree e il numero dei votanti per `Berlin` e `Bayern`.

# %%
mask = (df['state'] == 'Berlin') | (df['state'] == 'Bayern')
df[mask][['area', 'voters']]
# Out:
#                                                   area  voters
# 74                                        Berlin-Mitte  206706
# 75                                       Berlin-Pankow  237071
# 76                                Berlin-Reinickendorf  182392
# 77                Berlin-Spandau – Charlottenburg Nord  184602
# 78                          Berlin-Steglitz-Zehlendorf  221209
# 79                   Berlin-Charlottenburg-Wilmersdorf  198672
# 80                         Berlin-Tempelhof-Schöneberg  235250
# 81                                     Berlin-Neukölln  202616
# 82   Berlin-Friedrichshain-Kreuzberg – Prenzlauer B...  223426
# 83                             Berlin-Treptow-Köpenick  205105
# 84                          Berlin-Marzahn-Hellersdorf  200704
# 85                                  Berlin-Lichtenberg  205300
# 211                                          Altötting  168222
# 212                                 Erding – Ebersberg  206077
# 213                                           Freising  235603
# 214                                   Fürstenfeldbruck  231971
# 215                                         Ingolstadt  246357
# 216                                       München-Nord  226436
# 217                                        München-Ost  239169
# 218                                        München-Süd  216725
# 219                                 München-West/Mitte  241282
# 220                                       München-Land  233872
# 221                                          Rosenheim  233688
# 222                 Bad Tölz-Wolfratshausen – Miesbach  165228
# 223                      Starnberg – Landsberg am Lech  213619
# 224                                         Traunstein  208525
# 225                                           Weilheim  166804
# 226                                         Deggendorf  166659
# 227                                           Landshut  249185
# 228                                             Passau  176849
# 229                                         Rottal-Inn  168564
# 230                                          Straubing  172975
# 231                                             Amberg  215218
# 232                                         Regensburg  252910
# 233                                         Schwandorf  216003
# 234                                             Weiden  167658
# 235                                            Bamberg  181535
# 236                                           Bayreuth  163610
# 237                                             Coburg  159613
# 238                                                Hof  167279
# 239                                           Kulmbach  170332
# 240                                            Ansbach  243106
# 241                                           Erlangen  180176
# 242                                              Fürth  254300
# 243                                      Nürnberg-Nord  192214
# 244                                       Nürnberg-Süd  181809
# 245                                               Roth  226731
# 246                                      Aschaffenburg  183201
# 247                                      Bad Kissingen  214956
# 248                                      Main-Spessart  195908
# 249                                        Schweinfurt  198521
# 250                                           Würzburg  225057
# 251                                     Augsburg-Stadt  210524
# 252                                      Augsburg-Land  248196
# 253                                         Donau-Ries  190781
# 254                                            Neu-Ulm  239662
# 255                                         Oberallgäu  225952
# 256                                          Ostallgäu  246852

# %% [markdown]
# ---
#
# ## Selezionare una riga tramite `iloc[]`
#
#     df.iloc[pos_index]

# %%
df
# Out:
#      area_id                               area               state  voters  \
# 0          0              Flensburg – Schleswig  Schleswig-Holstein  225659
# 1          1  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein  186384
# 3          3              Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 4          4                               Kiel  Schleswig-Holstein  204650
# 5          5                  Plön – Neumünster  Schleswig-Holstein  174934
# ..       ...                                ...                 ...     ...
# 294      294           Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 295      295                        Saarbrücken            Saarland  199887
# 296      296                          Saarlouis            Saarland  207500
# 297      297                         St. Wendel            Saarland  177468
# 298      298                            Homburg            Saarland  192408
#
#      total_votes  invalid_second_votes  valid_second_votes  vote_percentage
# 0         171905                  1509              170396            76.18
# 1         139200                  1125              138075            74.68
# 3         157387                  1119              156268            78.84
# 4         151463                  1290              150173            74.01
# 5         131710                  1196              130514            75.29
# ..           ...                   ...                 ...              ...
# 294       139544                  1818              137726            76.17
# 295       147602                  2171              145431            73.84
# 296       160371                  2831              157540            77.29
# 297       141378                  2668              138710            79.66
# 298       145990                  2467              143523            75.88
#
# [296 rows x 8 columns]

# %%
third_row = df.iloc[2]
third_row
# Out:
# area_id                                     3
# area                    Rendsburg-Eckernförde
# state                      Schleswig-Holstein
# voters                                 199632
# total_votes                            157387
# invalid_second_votes                     1119
# valid_second_votes                     156268
# vote_percentage                         78.84
# Name: 3, dtype: object

# %% [markdown]
# ---
#
# ## Selezionare righe contigue tramite `iloc[]`
#
#     df.iloc[start_pos_index:end_pos_index]

# %%
df.iloc[3:11]
# Out:
#     area_id                                               area  \
# 4         4                                               Kiel
# 5         5                                  Plön – Neumünster
# 6         6                                          Pinneberg
# 7         7                          Segeberg – Stormarn-Mitte
# 8         8                        Ostholstein – Stormarn-Nord
# 11       11  Schwerin – Ludwigslust-Parchim I – Nordwestmec...
# 12       12  Ludwigslust-Parchim II – Nordwestmecklenburg I...
# 13       13                     Rostock – Landkreis Rostock II
#
#                      state  voters  total_votes  invalid_second_votes  \
# 4       Schleswig-Holstein  204650       151463                  1290
# 5                  unknown  174934       131710                  1196
# 6       Schleswig-Holstein  237474       187711                  1339
# 7       Schleswig-Holstein  245826       193318                  1381
# 8       Schleswig-Holstein  181480       138415                  1142
# 11  Mecklenburg-Vorpommern  216743       157070                  1658
# 12  Mecklenburg-Vorpommern  205757       146781                  1673
# 13  Mecklenburg-Vorpommern  222718       164037                  1731
#
#     valid_second_votes  vote_percentage
# 4               150173            74.01
# 5               130514            75.29
# 6               186372            79.04
# 7               191937            78.64
# 8               137273            76.27
# 11              155412            72.47
# 12              145108            71.34
# 13              162306            73.65

# %% [markdown]
# ---
#
# ## Selezionare righe non contigue tramite `iloc[]`
#
#
#     df.iloc[pos_index_list]
#
# ---

# %%
df.iloc[[0,5,7,10]]
# Out:
#     area_id                            area                   state  voters  \
# 0         0           Flensburg – Schleswig      Schleswig-Holstein  225659
# 6         6                       Pinneberg      Schleswig-Holstein  237474
# 8         8     Ostholstein – Stormarn-Nord      Schleswig-Holstein  181480
# 13       13  Rostock – Landkreis Rostock II  Mecklenburg-Vorpommern  222718
#
#     total_votes  invalid_second_votes  valid_second_votes  vote_percentage
# 0        171905                  1509              170396            76.18
# 6        187711                  1339              186372            79.04
# 8        138415                  1142              137273            76.27
# 13       164037                  1731              162306            73.65

# %% [markdown]
# ---
#
# ## Selezionare una riga tramite `loc[]`
#
#
#         df.loc[index]
#
# ---

# %%
df
# Out:
#      area_id                               area               state  voters  \
# 0          0              Flensburg – Schleswig  Schleswig-Holstein  225659
# 1          1  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein  186384
# 3          3              Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 4          4                               Kiel  Schleswig-Holstein  204650
# 5          5                  Plön – Neumünster  Schleswig-Holstein  174934
# ..       ...                                ...                 ...     ...
# 294      294           Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 295      295                        Saarbrücken            Saarland  199887
# 296      296                          Saarlouis            Saarland  207500
# 297      297                         St. Wendel            Saarland  177468
# 298      298                            Homburg            Saarland  192408
#
#      total_votes  invalid_second_votes  valid_second_votes  vote_percentage
# 0         171905                  1509              170396            76.18
# 1         139200                  1125              138075            74.68
# 3         157387                  1119              156268            78.84
# 4         151463                  1290              150173            74.01
# 5         131710                  1196              130514            75.29
# ..           ...                   ...                 ...              ...
# 294       139544                  1818              137726            76.17
# 295       147602                  2171              145431            73.84
# 296       160371                  2831              157540            77.29
# 297       141378                  2668              138710            79.66
# 298       145990                  2467              143523            75.88
#
# [296 rows x 8 columns]

# %% [markdown]
# **ESERCIZIO**: estrarre il campo `area` della riga con indice `4`.

# %%
df.loc[4]['area']
# Out:
# 'Kiel'

# %% [markdown]
# ---
#
# ## Selezionare righe tramite `loc[]`
#
#
#     df.loc[index_list]
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre le righe con indici `5`, `8` e `10`.

# %%
df.loc[[5,8]]
# Out:
#    area_id                         area               state  voters  \
# 5        5            Plön – Neumünster  Schleswig-Holstein  174934
# 8        8  Ostholstein – Stormarn-Nord  Schleswig-Holstein  181480
#
#    total_votes  invalid_second_votes  valid_second_votes  vote_percentage
# 5       131710                  1196              130514            75.29
# 8       138415                  1142              137273            76.27

# %% [markdown]
# ---
#
# ## Selezionare righe che rispettano una condizione tramite `loc[]`
#
#
#         df.loc[mask]
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre le righe corrispondenti al valore `Berlin` della colonna `state`.

# %%
df.loc[df['state'] == 'Berlin']
# Out:
#     area_id                                               area   state  \
# 74       74                                       Berlin-Mitte  Berlin
# 75       75                                      Berlin-Pankow  Berlin
# 76       76                               Berlin-Reinickendorf  Berlin
# 77       77               Berlin-Spandau – Charlottenburg Nord  Berlin
# 78       78                         Berlin-Steglitz-Zehlendorf  Berlin
# 79       79                  Berlin-Charlottenburg-Wilmersdorf  Berlin
# 80       80                        Berlin-Tempelhof-Schöneberg  Berlin
# 81       81                                    Berlin-Neukölln  Berlin
# 82       82  Berlin-Friedrichshain-Kreuzberg – Prenzlauer B...  Berlin
# 83       83                            Berlin-Treptow-Köpenick  Berlin
# 84       84                         Berlin-Marzahn-Hellersdorf  Berlin
# 85       85                                 Berlin-Lichtenberg  Berlin
#
#     voters  total_votes  invalid_second_votes  valid_second_votes  \
# 74  206706       151634                  2214              149420
# 75  237071       188607                  2198              186409
# 76  182392       137084                  2171              134913
# 77  184602       132934                  2276              130658
# 78  221209       180827                  2110              178717
# 79  198672       158245                  1429              156816
# 80  235250       181259                  2162              179097
# 81  202616       143790                  2980              140810
# 82  223426       173504                  1664              171840
# 83  205105       157461                  2124              155337
# 84  200704       138988                  2064              136924
# 85  205300       149053                  2153              146900
#
#     vote_percentage
# 74            73.36
# 75            79.56
# 76            75.16
# 77            72.01
# 78            81.74
# 79            79.65
# 80            77.05
# 81            70.97
# 82            77.66
# 83            76.77
# 84            69.25
# 85            72.60

# %% [markdown]
# ---
#
# ## Selezionare il campo di una riga tramite `loc[]`
#
#
#     df.loc[index, column_name]
#
# ---

# %%
df.loc[5, 'state'] = 'unknown'

# %%
df
# Out:
#      area_id                               area               state  voters  \
# 0          0              Flensburg – Schleswig  Schleswig-Holstein  225659
# 1          1  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein  186384
# 3          3              Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 4          4                               Kiel  Schleswig-Holstein  204650
# 5          5                  Plön – Neumünster             unknown  174934
# ..       ...                                ...                 ...     ...
# 294      294           Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 295      295                        Saarbrücken            Saarland  199887
# 296      296                          Saarlouis            Saarland  207500
# 297      297                         St. Wendel            Saarland  177468
# 298      298                            Homburg            Saarland  192408
#
#      total_votes  invalid_second_votes  valid_second_votes  vote_percentage
# 0         171905                  1509              170396            76.18
# 1         139200                  1125              138075            74.68
# 3         157387                  1119              156268            78.84
# 4         151463                  1290              150173            74.01
# 5         131710                  1196              130514            75.29
# ..           ...                   ...                 ...              ...
# 294       139544                  1818              137726            76.17
# 295       147602                  2171              145431            73.84
# 296       160371                  2831              157540            77.29
# 297       141378                  2668              138710            79.66
# 298       145990                  2467              143523            75.88
#
# [296 rows x 8 columns]

# %% [markdown]
# ---
#
# ## Selezionare un campo di più righe tramite `loc[]`
#
#
#     df.loc[index_list, column_name]
#
# ---

# %%
df.loc[[5,11], 'area']
# Out:
# 5                                     Plön – Neumünster
# 11    Schwerin – Ludwigslust-Parchim I – Nordwestmec...
# Name: area, dtype: object

# %% [markdown]
# ---
#
# **ESERCIZIO**: aggiornare a 0 tutti i valori inferiori a 1000 relativi alla colonna `invalid_second_votes`.

# %%
mask = df['invalid_second_votes'] < 1000
df.loc[df[mask].index, 'invalid_second_votes'] = 0

# %%
df[mask]
# Out:
#      area_id                                area                state  voters  \
# 18        18                      Hamburg-Altona              Hamburg  185942
# 19        19                  Hamburg-Eimsbüttel              Hamburg  192399
# 20        20                        Hamburg-Nord              Hamburg  217226
# 29        29              Stade I – Rotenburg II        Niedersachsen  197298
# 30        30                           Mittelems        Niedersachsen  230151
# 34        34            Rotenburg I – Heidekreis        Niedersachsen  168081
# 35        35                             Harburg        Niedersachsen  199081
# 36        36        Lüchow-Dannenberg – Lüneburg        Niedersachsen  180866
# 38        38                     Stadt Osnabrück        Niedersachsen  196475
# 40        40                    Stadt Hannover I        Niedersachsen  179883
# 41        41                   Stadt Hannover II        Niedersachsen  193433
# 86        86                            Aachen I  Nordrhein-Westfalen  179273
# 93        93                             Köln II  Nordrhein-Westfalen  240982
# 119      119                           Essen III  Nordrhein-Westfalen  192918
# 126      126             Coesfeld – Steinfurt II  Nordrhein-Westfalen  192946
# 211      211                           Altötting               Bayern  168222
# 212      212                  Erding – Ebersberg               Bayern  206077
# 214      214                    Fürstenfeldbruck               Bayern  231971
# 216      216                        München-Nord               Bayern  226436
# 217      217                         München-Ost               Bayern  239169
# 218      218                         München-Süd               Bayern  216725
# 219      219                  München-West/Mitte               Bayern  241282
# 220      220                        München-Land               Bayern  233872
# 222      222  Bad Tölz-Wolfratshausen – Miesbach               Bayern  165228
# 223      223       Starnberg – Landsberg am Lech               Bayern  213619
# 225      225                            Weilheim               Bayern  166804
# 226      226                          Deggendorf               Bayern  166659
# 228      228                              Passau               Bayern  176849
# 229      229                          Rottal-Inn               Bayern  168564
# 235      235                             Bamberg               Bayern  181535
# 236      236                            Bayreuth               Bayern  163610
# 241      241                            Erlangen               Bayern  180176
# 243      243                       Nürnberg-Nord               Bayern  192214
# 257      257                         Stuttgart I    Baden-Württemberg  194368
#
#      total_votes  invalid_second_votes  valid_second_votes  vote_percentage
# 18        146025                     0              145076            78.53
# 19        156001                     0              155141            81.08
# 20        178302                     0              177403            82.08
# 29        152485                     0              151639            77.29
# 30        179790                     0              178827            78.12
# 34        127071                     0              126097            75.60
# 35        161838                     0              160858            81.29
# 36        141000                     0              140138            77.96
# 38        151988                     0              151006            77.36
# 40        134842                     0              133867            74.96
# 41        149030                     0              148090            77.04
# 86        140628                     0              139784            78.44
# 93        197979                     0              197078            82.16
# 119       153336                     0              152409            79.48
# 126       156811                     0              155826            81.27
# 211       126774                     0              125909            75.36
# 212       163366                     0              162608            79.27
# 214       190809                     0              189842            82.26
# 216       173781                     0              173092            76.75
# 217       186882                     0              186047            78.14
# 218       170440                     0              169770            78.64
# 219       193426                     0              192595            80.17
# 220       197288                     0              196362            84.36
# 222       132621                     0              131817            80.27
# 223       177007                     0              176259            82.86
# 225       134339                     0              133560            80.54
# 226       119459                     0              118755            71.68
# 228       131355                     0              130571            74.28
# 229       124323                     0              123504            73.75
# 235       145235                     0              144418            80.00
# 236       127225                     0              126522            77.76
# 241       148057                     0              147370            82.17
# 243       146205                     0              145304            76.06
# 257       160832                     0              159974            82.75

# %% [markdown]
# ---
#
# ## Selezionare più campi di più righe tramite `loc[]`
#
#
#         df.loc[index_list, column_list]
#
# ---

# %% [markdown]
# ---
#
# ## Ottenere un valore tramite `at[]`
#
#     df.at[index, column_name]
#
# ---

# %% [markdown]
# ---
#
# ## Controllare la presenza di valori nulli
#
#
#     pd.isnull(df|column)
#
# ---

# %% [markdown]
# ---
#
# ## Ottenere statistiche generali
#
#     df.describe()
#     column.describe()

# %% [markdown]
# ---
#
# ## Alcuni metodi utili...
#
# Gli oggetti `DataFrame` e `Series` dispongono di metodi come `max()`, `min()`, `count()`, `var()`, `std()`, `mean()`, `sum()`.

# %% [markdown]
# Gli oggetti `DataFrame` dispongono del metodo `corr()` per calcolare la matrice di covarianza.

# %% [markdown]
# ---
#
# ### Metodo  `unique()`
#
# Il metodo `unique()` degli oggetti `Series` restituisce l'array dei valori distinti presenti nell'oggetto invocante.
#
# ---
#
# **ESERCIZIO**: determinare i valori distinti della colonna `state`.

# %% [markdown]
# ### Metodo `value_counts()`
#
#     column|df.value_counts(normalize=False, sort=True, ascending=False, bins=None, dropna=True)

# %% [markdown]
# ---
#
# **ESERCIZIO**: determinare le frequenze relative del campo `state` e produrle in ordine crescente.

# %% [markdown]
# ### Metodo `sort_values()`
#
#
#     df.sort_values(column|column_list, ascending = True, inplace = False)
#
# ---

# %% [markdown]
# **ESERCIZIO**: ordinare le righe per colonne `state` e `area`, in ordine discendente (senza aggiornare il *data frame* invocante).

# %% [markdown]
# ---
#
# **ESERCIZIO**: ordinare le righe per numero di voti totali, in ordine discendente (senza aggiornare il *data frame* invocante).

# %% [markdown]
# ---
#
# ## Raggruppare valori
#
#     df.groupby(column_list)
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre il numero di votanti totali per campo `state`.

# %% [markdown]
# ---
#
# **ESERCIZIO**: visualizzare il numero dei votanti per ogni area raggruppandole per campo `state`.

# %% [markdown]
# ---
#
# ## Applicare una funzione con il metodo `apply()`
#
#         df.apply(function)
#         column.apply(function)

# %% [markdown]
# ---
#
# **ESERCIZIO**: estrarre il *data frame* con le due colonne contenenti il numero dei votanti e dei voti totali, con tutti i valori decrementati di 1000 unità.

# %% [markdown]
# ---
#
# **ESERCIZIO**: estrarre la colonna del numero dei votanti convertito in numero decimale.

# %% [markdown]
# ---
#
# ## Iterare lungo le righe di un *data frame*
#
#
#     for (index, record) in df.iterrows():
#         block

# %% [markdown]
# ---
#
# ## Salvare un *data frame* in formato `csv`
#
#
#         df.to_csv(file_name, index = False)
#
# ---

# %% [markdown]
# ---
#
# ## Richiamare `matplotlib` da Pandas

# %% [markdown]
# ---
#
# ## Cambiare gli indici (chiavi primarie)
#
#     df.set_index(column|columns, drop = True, inplace = False)

# %% [markdown]
# ---
#
# **ESERCIZIO**: produrre una copia del data frame che ha indice dato dal campo `area` seguito da un `-` e dall'attuale indice.
