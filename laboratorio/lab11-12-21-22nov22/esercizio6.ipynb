# %% [markdown]
# ## Manipolazione di un file GTF (Gene Transfer Format) attraverso la libreria `Pandas`

# %% [markdown]
# #### 1) Importare `Pandas`

# %%
import pandas as pd

# %% [markdown]
# #### 2) Leggere il file GTF
#
#     df = pd.read_csv(gtf_file_name, sep='\t', header = None)

# %%
df = pd.read_csv('./input.gtf', sep='\t', header = None)

# %%
df
# Out:
#           0           1     2      3      4  5  6  7  \
# 0    ENm006  VEGA_Known  exon  71783  71788  .  -  .
# 1    ENm006  VEGA_Known   CDS  71783  71788  .  -  0
# 2    ENm006  VEGA_Known  exon  70312  70440  .  -  .
# 3    ENm006  VEGA_Known   CDS  70312  70440  .  -  0
# 4    ENm006  VEGA_Known  exon  69989  70210  .  -  .
# ..      ...         ...   ...    ...    ... .. .. ..
# 405  ENm006  VEGA_Known   CDS  56303  56327  .  +  0
# 406  ENm006  VEGA_Known  exon  56689  57573  .  +  .
# 407  ENm006  VEGA_Known   CDS  56689  57573  .  +  2
# 408  ENm006  VEGA_Known  exon  57680  58323  .  +  .
# 409  ENm006  VEGA_Known   CDS  57680  57885  .  +  2
#
#                                                      8
# 0     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# 1     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# 2     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# 3     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# 4     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# ..                                                 ...
# 405  transcript_id "U52112.2-001"; gene_id "AVPR2";...
# 406  transcript_id "U52112.2-001"; gene_id "AVPR2";...
# 407  transcript_id "U52112.2-001"; gene_id "AVPR2";...
# 408  transcript_id "U52112.2-001"; gene_id "AVPR2";...
# 409  transcript_id "U52112.2-001"; gene_id "AVPR2";...
#
# [410 rows x 9 columns]

# %% [markdown]
# **NB**: `read_csv()` ha un attributo `names` che permette di specificare la lista dei nomi delle colonne del data frame restituito.

# %% [markdown]
# #### 3) Cambiare i nomi delle colonne
#
# I nomi delle colonne devono essere:
# - reference
# - source
# - feature
# - start
# - end
# - score
# - strand
# - frame
# - attributes

# %%
replace_dict = {0 : 'reference', 1 : 'source', 2 : 'feature', 3 : 'start', 4 : 'end', 5 : 'score', 6 : 'strand', 7 : 'frame', 8 : 'attributes'}
df.rename(columns = replace_dict, inplace = True)

# %%
df
# Out:
#     reference      source feature  start    end score strand frame  \
# 0      ENm006  VEGA_Known    exon  71783  71788     .      -     .
# 1      ENm006  VEGA_Known     CDS  71783  71788     .      -     0
# 2      ENm006  VEGA_Known    exon  70312  70440     .      -     .
# 3      ENm006  VEGA_Known     CDS  70312  70440     .      -     0
# 4      ENm006  VEGA_Known    exon  69989  70210     .      -     .
# ..        ...         ...     ...    ...    ...   ...    ...   ...
# 405    ENm006  VEGA_Known     CDS  56303  56327     .      +     0
# 406    ENm006  VEGA_Known    exon  56689  57573     .      +     .
# 407    ENm006  VEGA_Known     CDS  56689  57573     .      +     2
# 408    ENm006  VEGA_Known    exon  57680  58323     .      +     .
# 409    ENm006  VEGA_Known     CDS  57680  57885     .      +     2
#
#                                             attributes
# 0     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# 1     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# 2     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# 3     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# 4     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# ..                                                 ...
# 405  transcript_id "U52112.2-001"; gene_id "AVPR2";...
# 406  transcript_id "U52112.2-001"; gene_id "AVPR2";...
# 407  transcript_id "U52112.2-001"; gene_id "AVPR2";...
# 408  transcript_id "U52112.2-001"; gene_id "AVPR2";...
# 409  transcript_id "U52112.2-001"; gene_id "AVPR2";...
#
# [410 rows x 9 columns]

# %% [markdown]
# #### 4) Eliminare le colonne `source` e `score` e sostituire l'identificatore `ENm006` con l'identificatore `ENCODE_REGION` in tutti i campi della colonna `reference`

# %%
df.drop(['source', 'score'], axis=1, inplace = True)

# %%
df['reference'] = 'ENCODE_REGION'

# %%
df
# Out:
#          reference feature  start    end strand frame  \
# 0    ENCODE_REGION    exon  71783  71788      -     .
# 1    ENCODE_REGION     CDS  71783  71788      -     0
# 2    ENCODE_REGION    exon  70312  70440      -     .
# 3    ENCODE_REGION     CDS  70312  70440      -     0
# 4    ENCODE_REGION    exon  69989  70210      -     .
# ..             ...     ...    ...    ...    ...   ...
# 405  ENCODE_REGION     CDS  56303  56327      +     0
# 406  ENCODE_REGION    exon  56689  57573      +     .
# 407  ENCODE_REGION     CDS  56689  57573      +     2
# 408  ENCODE_REGION    exon  57680  58323      +     .
# 409  ENCODE_REGION     CDS  57680  57885      +     2
#
#                                             attributes
# 0     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# 1     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# 2     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# 3     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# 4     transcript_id "U52112.4-005"; gene_id "ARHGAP4";
# ..                                                 ...
# 405  transcript_id "U52112.2-001"; gene_id "AVPR2";...
# 406  transcript_id "U52112.2-001"; gene_id "AVPR2";...
# 407  transcript_id "U52112.2-001"; gene_id "AVPR2";...
# 408  transcript_id "U52112.2-001"; gene_id "AVPR2";...
# 409  transcript_id "U52112.2-001"; gene_id "AVPR2";...
#
# [410 rows x 7 columns]

# %% [markdown]
# #### 5) Sostituire la colonna degli attributi con le due colonne  `transcript` e `gene`
#
# La colonne `transcript` e `gene` dovranno contenere solo l'ID del trascritto e del gene.

# %%
import re

# %%
df['gene'] = ''
df['transcript'] = ''

# %%
for (index, record) in df.iterrows():
    transcript_id = re.search('transcript_id\s+(.+?);', record['attributes']).group(1).replace('"', '')
    gene_id = re.search('gene_id\s+(.+?);', record['attributes']).group(1).replace('"', '')
    df.loc[index, 'transcript'] =  transcript_id
    df.loc[index, 'gene'] =  gene_id

# %%
df.drop('attributes', axis=1, inplace=True)

# %%
df
# Out:
#          reference feature  start    end strand frame     gene    transcript
# 0    ENCODE_REGION    exon  71783  71788      -     .  ARHGAP4  U52112.4-005
# 1    ENCODE_REGION     CDS  71783  71788      -     0  ARHGAP4  U52112.4-005
# 2    ENCODE_REGION    exon  70312  70440      -     .  ARHGAP4  U52112.4-005
# 3    ENCODE_REGION     CDS  70312  70440      -     0  ARHGAP4  U52112.4-005
# 4    ENCODE_REGION    exon  69989  70210      -     .  ARHGAP4  U52112.4-005
# ..             ...     ...    ...    ...    ...   ...      ...           ...
# 405  ENCODE_REGION     CDS  56303  56327      +     0    AVPR2  U52112.2-001
# 406  ENCODE_REGION    exon  56689  57573      +     .    AVPR2  U52112.2-001
# 407  ENCODE_REGION     CDS  56689  57573      +     2    AVPR2  U52112.2-001
# 408  ENCODE_REGION    exon  57680  58323      +     .    AVPR2  U52112.2-001
# 409  ENCODE_REGION     CDS  57680  57885      +     2    AVPR2  U52112.2-001
#
# [410 rows x 8 columns]

# %% [markdown]
# #### 6) Aggiungere la colonna `length` contenente la lunghezza della feature

# %%
df['length'] = df['end'] - df['start'] + 1

# %% [markdown]
# Reindicizzazione delle colonne:

# %%
df = df.reindex(columns = ['reference', 'feature', 'start', 'end', 'length', 'strand', 'frame', 'gene', 'transcript'])

# %%
df
# Out:
#          reference feature  start    end  length strand frame     gene  \
# 0    ENCODE_REGION    exon  71783  71788       6      -     .  ARHGAP4
# 1    ENCODE_REGION     CDS  71783  71788       6      -     0  ARHGAP4
# 2    ENCODE_REGION    exon  70312  70440     129      -     .  ARHGAP4
# 3    ENCODE_REGION     CDS  70312  70440     129      -     0  ARHGAP4
# 4    ENCODE_REGION    exon  69989  70210     222      -     .  ARHGAP4
# ..             ...     ...    ...    ...     ...    ...   ...      ...
# 405  ENCODE_REGION     CDS  56303  56327      25      +     0    AVPR2
# 406  ENCODE_REGION    exon  56689  57573     885      +     .    AVPR2
# 407  ENCODE_REGION     CDS  56689  57573     885      +     2    AVPR2
# 408  ENCODE_REGION    exon  57680  58323     644      +     .    AVPR2
# 409  ENCODE_REGION     CDS  57680  57885     206      +     2    AVPR2
#
#        transcript
# 0    U52112.4-005
# 1    U52112.4-005
# 2    U52112.4-005
# 3    U52112.4-005
# 4    U52112.4-005
# ..            ...
# 405  U52112.2-001
# 406  U52112.2-001
# 407  U52112.2-001
# 408  U52112.2-001
# 409  U52112.2-001
#
# [410 rows x 9 columns]

# %% [markdown]
# #### 7) Rimuovere dal *data frame* tutte le features di lunghezza minore o uguale a 6 basi

# %%
mask = df['length'] > 6
df[mask]
# Out:
#          reference feature  start    end  length strand frame     gene  \
# 2    ENCODE_REGION    exon  70312  70440     129      -     .  ARHGAP4
# 3    ENCODE_REGION     CDS  70312  70440     129      -     0  ARHGAP4
# 4    ENCODE_REGION    exon  69989  70210     222      -     .  ARHGAP4
# 5    ENCODE_REGION     CDS  69989  70210     222      -     0  ARHGAP4
# 6    ENCODE_REGION    exon  64935  65036     102      -     .  ARHGAP4
# ..             ...     ...    ...    ...     ...    ...   ...      ...
# 405  ENCODE_REGION     CDS  56303  56327      25      +     0    AVPR2
# 406  ENCODE_REGION    exon  56689  57573     885      +     .    AVPR2
# 407  ENCODE_REGION     CDS  56689  57573     885      +     2    AVPR2
# 408  ENCODE_REGION    exon  57680  58323     644      +     .    AVPR2
# 409  ENCODE_REGION     CDS  57680  57885     206      +     2    AVPR2
#
#        transcript
# 2    U52112.4-005
# 3    U52112.4-005
# 4    U52112.4-005
# 5    U52112.4-005
# 6    U52112.4-005
# ..            ...
# 405  U52112.2-001
# 406  U52112.2-001
# 407  U52112.2-001
# 408  U52112.2-001
# 409  U52112.2-001
#
# [408 rows x 9 columns]

# %% [markdown]
# In alternativa, con il metodo `drop()`:

# %%
mask = df['length'] <= 6
df.drop(df[mask].index, axis = 0, inplace = True)

# %%
df
# Out:
#          reference feature  start    end  length strand frame     gene  \
# 2    ENCODE_REGION    exon  70312  70440     129      -     .  ARHGAP4
# 3    ENCODE_REGION     CDS  70312  70440     129      -     0  ARHGAP4
# 4    ENCODE_REGION    exon  69989  70210     222      -     .  ARHGAP4
# 5    ENCODE_REGION     CDS  69989  70210     222      -     0  ARHGAP4
# 6    ENCODE_REGION    exon  64935  65036     102      -     .  ARHGAP4
# ..             ...     ...    ...    ...     ...    ...   ...      ...
# 405  ENCODE_REGION     CDS  56303  56327      25      +     0    AVPR2
# 406  ENCODE_REGION    exon  56689  57573     885      +     .    AVPR2
# 407  ENCODE_REGION     CDS  56689  57573     885      +     2    AVPR2
# 408  ENCODE_REGION    exon  57680  58323     644      +     .    AVPR2
# 409  ENCODE_REGION     CDS  57680  57885     206      +     2    AVPR2
#
#        transcript
# 2    U52112.4-005
# 3    U52112.4-005
# 4    U52112.4-005
# 5    U52112.4-005
# 6    U52112.4-005
# ..            ...
# 405  U52112.2-001
# 406  U52112.2-001
# 407  U52112.2-001
# 408  U52112.2-001
# 409  U52112.2-001
#
# [408 rows x 9 columns]

# %% [markdown]
# #### 8) Estrarre il *data frame* dei primi 20 esoni più lunghi e degli ultimi 20 esoni localizzati sul *reference*
#
# *SUGGERIMENTO*: usare la funzione:
#
#     pd.merge(first_df, second_df, how='outer')
#
# per unire verticalmente due *data frame* con le stesse colonne.

# %%
esoni_df = df[df.feature == 'exon']

# %%
first_df = esoni_df.sort_values('length', ascending = False, inplace = False).head(20)

# %%
second_df = esoni_df.sort_values('start', ascending = False, inplace = False).head(20)

# %%
pd.merge(first_df, second_df, how='outer')
# Out:
#         reference feature   start     end  length strand frame     gene  \
# 0   ENCODE_REGION    exon  543097  545706    2610      +     .  ATP6AP1
# 1   ENCODE_REGION    exon   56689   57938    1250      +     .    AVPR2
# 2   ENCODE_REGION    exon   56689   57573     885      +     .    AVPR2
# 3   ENCODE_REGION    exon   57680   58323     644      +     .    AVPR2
# 4   ENCODE_REGION    exon   57680   58322     643      +     .    AVPR2
# 5   ENCODE_REGION    exon   58524   59119     596      -     .  ARHGAP4
# 6   ENCODE_REGION    exon   58533   59119     587      -     .  ARHGAP4
# 7   ENCODE_REGION    exon   58534   59119     586      -     .  ARHGAP4
# 8   ENCODE_REGION    exon   58534   59119     586      -     .  ARHGAP4
# 9   ENCODE_REGION    exon   58572   59119     548      -     .  ARHGAP4
# 10  ENCODE_REGION    exon   58596   59119     524      -     .  ARHGAP4
# 11  ENCODE_REGION    exon   58611   59119     509      -     .  ARHGAP4
# 12  ENCODE_REGION    exon   58611   59119     509      -     .  ARHGAP4
# 13  ENCODE_REGION    exon   58611   59119     509      -     .  ARHGAP4
# 14  ENCODE_REGION    exon   61169   61676     508      -     .  ARHGAP4
# 15  ENCODE_REGION    exon   58626   59119     494      -     .  ARHGAP4
# 16  ENCODE_REGION    exon   64935   65410     476      -     .  ARHGAP4
# 17  ENCODE_REGION    exon   61328   61768     441      -     .  ARHGAP4
# 18  ENCODE_REGION    exon   57176   57573     398      +     .    AVPR2
# 19  ENCODE_REGION    exon   71569   71965     397      -     .  ARHGAP4
# 20  ENCODE_REGION    exon  548257  548495     239      +     .  ATP6AP1
# 21  ENCODE_REGION    exon  548257  548495     239      +     .  ATP6AP1
# 22  ENCODE_REGION    exon  548257  548495     239      +     .  ATP6AP1
# 23  ENCODE_REGION    exon  548257  548495     239      +     .  ATP6AP1
# 24  ENCODE_REGION    exon  548257  548495     239      +     .  ATP6AP1
# 25  ENCODE_REGION    exon  547709  547769      61      +     .  ATP6AP1
# 26  ENCODE_REGION    exon  547684  547769      86      +     .  ATP6AP1
# 27  ENCODE_REGION    exon  547684  547769      86      +     .  ATP6AP1
# 28  ENCODE_REGION    exon  547684  547769      86      +     .  ATP6AP1
# 29  ENCODE_REGION    exon  546980  547020      41      +     .  ATP6AP1
# 30  ENCODE_REGION    exon  546980  547020      41      +     .  ATP6AP1
# 31  ENCODE_REGION    exon  546980  547020      41      +     .  ATP6AP1
# 32  ENCODE_REGION    exon  546315  546508     194      +     .  ATP6AP1
# 33  ENCODE_REGION    exon  546315  546508     194      +     .  ATP6AP1
# 34  ENCODE_REGION    exon  546315  546425     111      +     .  ATP6AP1
# 35  ENCODE_REGION    exon  546315  546508     194      +     .  ATP6AP1
# 36  ENCODE_REGION    exon  545879  545953      75      +     .  ATP6AP1
# 37  ENCODE_REGION    exon  545879  545953      75      +     .  ATP6AP1
# 38  ENCODE_REGION    exon  545879  545953      75      +     .  ATP6AP1
# 39  ENCODE_REGION    exon  545879  545953      75      +     .  ATP6AP1
#
#             transcript
# 0   XX-FW83563B9.4-002
# 1         U52112.2-003
# 2         U52112.2-001
# 3         U52112.2-001
# 4         U52112.2-002
# 5         U52112.4-024
# 6         U52112.4-001
# 7         U52112.4-003
# 8         U52112.4-002
# 9         U52112.4-016
# 10        U52112.4-006
# 11        U52112.4-011
# 12        U52112.4-013
# 13        U52112.4-012
# 14        U52112.4-007
# 15        U52112.4-014
# 16        U52112.4-023
# 17        U52112.4-016
# 18        U52112.2-002
# 19        U52112.4-021
# 20  XX-FW83563B9.4-006
# 21  XX-FW83563B9.4-004
# 22  XX-FW83563B9.4-001
# 23  XX-FW83563B9.4-003
# 24  XX-FW83563B9.4-002
# 25  XX-FW83563B9.4-006
# 26  XX-FW83563B9.4-004
# 27  XX-FW83563B9.4-001
# 28  XX-FW83563B9.4-002
# 29  XX-FW83563B9.4-004
# 30  XX-FW83563B9.4-001
# 31  XX-FW83563B9.4-002
# 32  XX-FW83563B9.4-004
# 33  XX-FW83563B9.4-001
# 34  XX-FW83563B9.4-003
# 35  XX-FW83563B9.4-002
# 36  XX-FW83563B9.4-004
# 37  XX-FW83563B9.4-001
# 38  XX-FW83563B9.4-003
# 39  XX-FW83563B9.4-002

# %% [markdown]
# #### 9) Estrarre la lista dei geni presenti nel file GTF

# %%
list(df['gene'].unique())
# Out:
# ['ARHGAP4', 'ATP6AP1', 'AVPR2']

# %% [markdown]
# #### 10) Estrarre la lista dei trascritti presenti nel file GTF

# %%
list(df['transcript'].unique())
# Out:
# ['U52112.4-005',
#  'U52112.4-018',
#  'U52112.4-014',
#  'U52112.4-022',
#  'U52112.4-021',
#  'U52112.4-006',
#  'U52112.4-019',
#  'U52112.4-017',
#  'U52112.4-013',
#  'U52112.4-002',
#  'U52112.4-016',
#  'U52112.4-010',
#  'U52112.4-009',
#  'U52112.4-020',
#  'U52112.4-003',
#  'U52112.4-012',
#  'U52112.4-001',
#  'U52112.4-024',
#  'U52112.4-007',
#  'U52112.4-015',
#  'U52112.4-008',
#  'U52112.4-004',
#  'U52112.4-011',
#  'U52112.4-023',
#  'XX-FW83563B9.4-002',
#  'XX-FW83563B9.4-003',
#  'XX-FW83563B9.4-004',
#  'XX-FW83563B9.4-006',
#  'XX-FW83563B9.4-001',
#  'U52112.2-003',
#  'U52112.2-002',
#  'U52112.2-001']

# %% [markdown]
# #### 11) Determinare, per ogni gene, la lunghezza media, massima e minima degli esoni (considerando anche gli esoni duplicati dovuti al fatto che un esone può appartenere a trascritti diversi)

# %%
mask = df.feature == 'exon'
gb = df[mask].groupby('gene')['length']

# %%
gb.mean()
# Out:
# gene
# ARHGAP4    149.16996
# ATP6AP1    224.00000
# AVPR2      467.00000
# Name: length, dtype: float64

# %%
gb.min()
# Out:
# gene
# ARHGAP4    28
# ATP6AP1    41
# AVPR2      37
# Name: length, dtype: int64

# %%
gb.max()
# Out:
# gene
# ARHGAP4     596
# ATP6AP1    2610
# AVPR2      1250
# Name: length, dtype: int64

# %% [markdown]
# #### 12) Determinare la lunghezza minima degli esoni ed estrarre tutti i trascritti che contengono un esone di lunghezza minima

# %%
min_length = df[df.feature == 'exon'].length.min()

# %%
mask = (df.feature == 'exon') & (df.length == min_length)

# %%
list(df[mask]['transcript'].unique())
# Out:
# ['U52112.4-018',
#  'U52112.4-014',
#  'U52112.4-013',
#  'U52112.4-002',
#  'U52112.4-003',
#  'U52112.4-012',
#  'U52112.4-001',
#  'U52112.4-024',
#  'U52112.4-008',
#  'U52112.4-011']

# %% [markdown]
# #### 13) Contare quanti trascritti sono annotati per il gene `ARHGAP4`

# %%
mask = (df.feature == 'exon') & (df.gene == 'ARHGAP4')
len(df[mask]['transcript'].unique())
# Out:
# 24

# %% [markdown]
# #### 14) Estrarre la lista dei geni con strand `+`

# %%
list(df[df.strand == '+']['gene'].unique())
# Out:
# ['ATP6AP1', 'AVPR2']

# %% [markdown]
# #### 15) Estrarre gli esoni (distinti) del gene `ATP6AP1` in una lista di tuple (start, end)

# %%
df_temp = df[(df.gene == 'ATP6AP1') & (df.feature == 'exon')]

# %%
df_temp = df_temp[['start', 'end']].drop_duplicates()

# %%
list(zip(df_temp['start'], df_temp['end']))
# Out:
# [(542747, 542902),
#  (543097, 545706),
#  (545879, 545953),
#  (546315, 546508),
#  (546980, 547020),
#  (547684, 547769),
#  (548257, 548495),
#  (542694, 542902),
#  (543097, 543223),
#  (546315, 546425),
#  (542894, 543223),
#  (542790, 542902),
#  (547709, 547769),
#  (542687, 542902)]

# %% [markdown]
# #### 16) Contare i trascritti del gene `ARHGAP4` che hanno una CDS annotata

# %%
len(df[(df.gene == 'ARHGAP4') & (df.feature == 'CDS')]['transcript'].unique())
# Out:
# 9

# %% [markdown]
# #### 17) Estrarre lo strand del gene  `ATP6AP1`

# %%
df[df.gene == 'ATP6AP1']['strand'].unique()[0]
# Out:
# '+'

# %% [markdown]
# #### 18) Determinare il trascritto che ha più esoni

# %%
exon_df = df[df.feature == 'exon']

# %%
exon_df.groupby('transcript')['feature'].count().max()
# Out:
# 23

# %%
list_of_transcripts = list(exon_df['transcript'].unique())
list_of_transcripts
# Out:
# ['U52112.4-005',
#  'U52112.4-018',
#  'U52112.4-014',
#  'U52112.4-022',
#  'U52112.4-021',
#  'U52112.4-006',
#  'U52112.4-019',
#  'U52112.4-017',
#  'U52112.4-013',
#  'U52112.4-002',
#  'U52112.4-016',
#  'U52112.4-010',
#  'U52112.4-009',
#  'U52112.4-020',
#  'U52112.4-003',
#  'U52112.4-012',
#  'U52112.4-001',
#  'U52112.4-024',
#  'U52112.4-007',
#  'U52112.4-015',
#  'U52112.4-008',
#  'U52112.4-004',
#  'U52112.4-011',
#  'U52112.4-023',
#  'XX-FW83563B9.4-002',
#  'XX-FW83563B9.4-003',
#  'XX-FW83563B9.4-004',
#  'XX-FW83563B9.4-006',
#  'XX-FW83563B9.4-001',
#  'U52112.2-003',
#  'U52112.2-002',
#  'U52112.2-001']

# %%
max_value = 0
res = ''

# %%
for transcript in list_of_transcripts:
    value = exon_df[exon_df.transcript == transcript]['feature'].count()
    if value > max_value:
        max_value = value
        res = transcript

# %%
res
# Out:
# 'U52112.4-001'

# %% [markdown]
# In alternativa:

# %%
groups_by_transcript = exon_df.groupby('transcript').groups

# %%
sorted(map(lambda x: (len(x[1]), x[0]), groups_by_transcript.items()), reverse = True).pop(0)[1]
# Out:
# 'U52112.4-001'

# %% [markdown]
# #### 19) Estrarre per ogni trascritto del gene  `ARHGAP4` la lista delle tuple (start, end) dei suoi esoni ordinate per start crescente

# %%
mask = (df.feature == 'exon') & (df.gene == 'ARHGAP4')

# %%
groups_by_transcript = df[mask].groupby('transcript').groups

# %%
for transcript_id in groups_by_transcript:
    print(transcript_id)
    index_list = groups_by_transcript[transcript_id]
    
    start_list = df.loc[index_list]['start']
    end_list = df.loc[index_list]['end']
    
    t_list = sorted(list(zip(start_list, end_list)))
    print(t_list)
# Out:
# U52112.4-001
# [(58533, 59119), (60227, 60326), (60600, 60692), (60898, 61081), (61169, 61242), (61328, 61561), (61663, 61768), (61857, 61991), (62079, 62156), (62286, 62346), (63857, 63959), (64181, 64208), (64375, 64459), (64566, 64757), (64935, 65036), (69989, 70210), (70312, 70440), (70724, 70843), (71783, 71965), (72253, 72315), (72521, 72683), (72761, 72965), (77293, 77417)]
# U52112.4-002
# [(58534, 59119), (60227, 60326), (60600, 60692), (60898, 61081), (61169, 61242), (61857, 61991), (62286, 62346), (63857, 63959), (64181, 64208), (64375, 64459), (64566, 64757), (64935, 65036), (69989, 70210), (70312, 70440), (71783, 71965), (72253, 72315), (72521, 72683), (72761, 72965), (77293, 77401)]
# U52112.4-003
# [(58534, 59119), (60227, 60326), (60600, 60692), (60898, 61081), (61169, 61242), (61328, 61561), (61663, 61768), (61857, 61991), (62079, 62156), (62286, 62346), (63857, 63959), (64181, 64208), (64375, 64459), (64566, 64757), (64935, 65036), (69989, 70210), (70312, 70440), (71783, 71965), (72253, 72315), (72521, 72683), (72761, 72965), (77293, 77401)]
# U52112.4-004
# [(70119, 70210), (70312, 70440), (71783, 71965), (72253, 72315), (72521, 72683), (72761, 72965), (73280, 73404)]
# U52112.4-005
# [(64385, 64459), (64566, 64673), (64935, 65036), (69989, 70210), (70312, 70440)]
# U52112.4-006
# [(58596, 59119), (60227, 60326), (60600, 60815)]
# U52112.4-007
# [(60976, 61081), (61169, 61676)]
# U52112.4-008
# [(60665, 60692), (60898, 61081), (61169, 61242), (61328, 61561), (61663, 61768), (61857, 62028)]
# U52112.4-009
# [(60625, 60692), (60898, 61081), (61169, 61242), (61663, 61768), (61857, 61991), (62079, 62258)]
# U52112.4-010
# [(60898, 61081), (61169, 61242), (61328, 61561), (61663, 61768), (61857, 61991), (62286, 62346), (63857, 63942)]
# U52112.4-011
# [(58611, 59119), (60227, 60326), (60600, 60692), (60898, 61081), (61169, 61242), (61328, 61561), (61663, 61768), (61857, 61991), (62079, 62156), (62286, 62346), (63857, 63959), (64181, 64208), (64375, 64459), (64566, 64757), (64935, 65036), (69989, 70210), (70312, 70440), (71783, 71965), (72521, 72683), (72761, 72965), (77293, 77401)]
# U52112.4-012
# [(58611, 59119), (60227, 60326), (60600, 60692), (60898, 61081), (61169, 61242), (61328, 61561), (61663, 61768), (61857, 61991), (62079, 62156), (62286, 62346), (63857, 63959), (64181, 64208), (64375, 64757), (64935, 65036), (69989, 70210), (72521, 72683), (72761, 72965), (77293, 77401)]
# U52112.4-013
# [(58611, 59119), (60227, 60326), (60600, 60692), (60898, 61081), (61169, 61242), (61328, 61561), (61663, 61768), (61857, 61991), (62079, 62156), (62286, 62346), (63857, 63959), (64181, 64208), (64375, 64757), (64935, 65036), (72521, 72683), (72761, 72965), (77293, 77401)]
# U52112.4-014
# [(58626, 59119), (60227, 60326), (60600, 60692), (60898, 61081), (61169, 61242), (61328, 61561), (61663, 61768), (61857, 61991), (62079, 62156), (62286, 62346), (63857, 63959), (64181, 64208), (64375, 64459), (64566, 64757), (64935, 65036), (69989, 70210), (70312, 70440), (71783, 71993), (72253, 72315), (72521, 72683), (72761, 72965), (77293, 77462)]
# U52112.4-015
# [(69999, 70210), (70312, 70440), (71783, 71965), (72253, 72315), (72521, 72683), (72761, 72965), (77747, 77914)]
# U52112.4-016
# [(58572, 59119), (60227, 60326), (60600, 60692), (60898, 61081), (61169, 61242), (61328, 61768), (61857, 61991), (62079, 62156), (62286, 62346), (63857, 63894)]
# U52112.4-017
# [(71865, 71965), (72253, 72315), (72521, 72683), (72761, 72965), (79484, 79576)]
# U52112.4-018
# [(71896, 71965), (72253, 72379), (72521, 72683), (72761, 72965), (79484, 79511)]
# U52112.4-019
# [(71872, 71965), (72253, 72315), (72521, 72683), (72761, 72965), (77973, 78017)]
# U52112.4-020
# [(70097, 70210), (70312, 70440), (70724, 70843), (71783, 71965), (72521, 72560)]
# U52112.4-021
# [(71569, 71965), (72253, 72315), (72521, 72556)]
# U52112.4-022
# [(64367, 64757), (64935, 65036), (69989, 70210), (70312, 70440), (71783, 71965), (72253, 72315), (72521, 72683), (72761, 72965), (83227, 83271), (83472, 83587), (83695, 83740), (85099, 85157), (85533, 85631), (86040, 86155)]
# U52112.4-023
# [(64681, 64757), (64935, 65410)]
# U52112.4-024
# [(58524, 59119), (60227, 60326), (60600, 60692), (60898, 61081), (61169, 61242), (61328, 61561), (61663, 61768), (61857, 61991), (62079, 62156), (62286, 62346), (63857, 63959), (64181, 64208), (64375, 64459), (64566, 64757), (64935, 65036), (72253, 72315), (72521, 72683), (72761, 72965), (77293, 77411)]

# %% [markdown]
# #### 20) Determinare, per ogni gene e ogni trascritto il numero di esoni che lo compongono

# %%
df[df.feature == 'exon'].groupby(['gene', 'transcript'])['feature'].count()
# Out:
# gene     transcript
# ARHGAP4  U52112.4-001          23
#          U52112.4-002          19
#          U52112.4-003          22
#          U52112.4-004           7
#          U52112.4-005           5
#          U52112.4-006           3
#          U52112.4-007           2
#          U52112.4-008           6
#          U52112.4-009           6
#          U52112.4-010           7
#          U52112.4-011          21
#          U52112.4-012          18
#          U52112.4-013          17
#          U52112.4-014          22
#          U52112.4-015           7
#          U52112.4-016          10
#          U52112.4-017           5
#          U52112.4-018           5
#          U52112.4-019           5
#          U52112.4-020           5
#          U52112.4-021           3
#          U52112.4-022          14
#          U52112.4-023           2
#          U52112.4-024          19
# ATP6AP1  XX-FW83563B9.4-001     7
#          XX-FW83563B9.4-002     7
#          XX-FW83563B9.4-003     5
#          XX-FW83563B9.4-004     6
#          XX-FW83563B9.4-006     5
# AVPR2    U52112.2-001           4
#          U52112.2-002           4
#          U52112.2-003           2
# Name: feature, dtype: int64
