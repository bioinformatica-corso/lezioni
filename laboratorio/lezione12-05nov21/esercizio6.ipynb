# %% [markdown]
# ## Manipolazione di un file GTF (Gene Transfer Format) attraverso la libreria `Pandas`

# %% [markdown]
# #### 1) Importare `Pandas`

# %% [markdown]
# #### 2) Leggere il file GTF
#
#     df = pd.read_csv(gtf_file_name, sep='\t', header = None)

# %% [markdown]
# **NB**: `read_csv()` ha un attributo `names` che permette di specificare la lista dei nomi delle colonne del data frame restituito.

# %% [markdown]
# #### 3) Cambiare i nomi delle colonne
#
# I nomi delle colonne devono essere:
# - reference
# - source
# - feature
# - start
# - end
# - score
# - strand
# - frame
# - attributes

# %% [markdown]
# #### 4) Eliminare le colonne `source` e `score` e sostituire l'identificatore `ENm006` con l'identificatore `ENCODE_REGION` in tutti i campi della colonna `reference`

# %% [markdown]
# #### 5) Sostituire la colonna degli attributi con le due colonne  `transcript` e `gene`
#
# La colonne `transcript` e `gene` dovranno contenere solo l'ID del trascritto e del gene.

# %%
# Out:
#          reference feature   start     end strand frame     gene  \
# 0    ENCODE_REGION    exon   71783   71788      -     .  ARHGAP4
# 1    ENCODE_REGION     CDS   71783   71788      -     0  ARHGAP4
# 2    ENCODE_REGION    exon   70312   70440      -     .  ARHGAP4
# 3    ENCODE_REGION     CDS   70312   70440      -     0  ARHGAP4
# 4    ENCODE_REGION    exon   69989   70210      -     .  ARHGAP4
# 5    ENCODE_REGION     CDS   69989   70210      -     0  ARHGAP4
# 6    ENCODE_REGION    exon   64935   65036      -     .  ARHGAP4
# 7    ENCODE_REGION     CDS   64935   65036      -     0  ARHGAP4
# 8    ENCODE_REGION    exon   64566   64673      -     .  ARHGAP4
# 9    ENCODE_REGION     CDS   64566   64673      -     0  ARHGAP4
# 10   ENCODE_REGION    exon   64385   64459      -     .  ARHGAP4
# 11   ENCODE_REGION     CDS   64385   64459      -     0  ARHGAP4
# 12   ENCODE_REGION    exon   79484   79511      -     .  ARHGAP4
# 13   ENCODE_REGION    exon   72761   72965      -     .  ARHGAP4
# 14   ENCODE_REGION    exon   72521   72683      -     .  ARHGAP4
# 15   ENCODE_REGION    exon   72253   72379      -     .  ARHGAP4
# 16   ENCODE_REGION    exon   71896   71965      -     .  ARHGAP4
# 17   ENCODE_REGION    exon   77293   77462      -     .  ARHGAP4
# 18   ENCODE_REGION    exon   72761   72965      -     .  ARHGAP4
# 19   ENCODE_REGION    exon   72521   72683      -     .  ARHGAP4
# 20   ENCODE_REGION    exon   72253   72315      -     .  ARHGAP4
# 21   ENCODE_REGION    exon   71783   71993      -     .  ARHGAP4
# 22   ENCODE_REGION    exon   70312   70440      -     .  ARHGAP4
# 23   ENCODE_REGION    exon   69989   70210      -     .  ARHGAP4
# 24   ENCODE_REGION    exon   64935   65036      -     .  ARHGAP4
# 25   ENCODE_REGION    exon   64566   64757      -     .  ARHGAP4
# 26   ENCODE_REGION    exon   64375   64459      -     .  ARHGAP4
# 27   ENCODE_REGION    exon   64181   64208      -     .  ARHGAP4
# 28   ENCODE_REGION    exon   63857   63959      -     .  ARHGAP4
# 29   ENCODE_REGION    exon   62286   62346      -     .  ARHGAP4
# ..             ...     ...     ...     ...    ...   ...      ...
# 380  ENCODE_REGION    exon  546980  547020      +     .  ATP6AP1
# 381  ENCODE_REGION    exon  547684  547769      +     .  ATP6AP1
# 382  ENCODE_REGION    exon  548257  548495      +     .  ATP6AP1
# 383  ENCODE_REGION    exon  542790  542902      +     .  ATP6AP1
# 384  ENCODE_REGION    exon  543097  543223      +     .  ATP6AP1
# 385  ENCODE_REGION    exon  545879  545953      +     .  ATP6AP1
# 386  ENCODE_REGION    exon  547709  547769      +     .  ATP6AP1
# 387  ENCODE_REGION    exon  548257  548495      +     .  ATP6AP1
# 388  ENCODE_REGION    exon  542687  542902      +     .  ATP6AP1
# 389  ENCODE_REGION    exon  543097  543223      +     .  ATP6AP1
# 390  ENCODE_REGION    exon  545879  545953      +     .  ATP6AP1
# 391  ENCODE_REGION    exon  546315  546508      +     .  ATP6AP1
# 392  ENCODE_REGION    exon  546980  547020      +     .  ATP6AP1
# 393  ENCODE_REGION    exon  547684  547769      +     .  ATP6AP1
# 394  ENCODE_REGION    exon  548257  548495      +     .  ATP6AP1
# 395  ENCODE_REGION    exon   56271   56327      +     .    AVPR2
# 396  ENCODE_REGION     CDS   56303   56327      +     0    AVPR2
# 397  ENCODE_REGION    exon   56689   57938      +     .    AVPR2
# 398  ENCODE_REGION     CDS   56689   57593      +     2    AVPR2
# 399  ENCODE_REGION    exon   53688   54049      +     .    AVPR2
# 400  ENCODE_REGION    exon   56131   56327      +     .    AVPR2
# 401  ENCODE_REGION    exon   57176   57573      +     .    AVPR2
# 402  ENCODE_REGION    exon   57680   58322      +     .    AVPR2
# 403  ENCODE_REGION    exon   55892   55928      +     .    AVPR2
# 404  ENCODE_REGION    exon   56131   56327      +     .    AVPR2
# 405  ENCODE_REGION     CDS   56303   56327      +     0    AVPR2
# 406  ENCODE_REGION    exon   56689   57573      +     .    AVPR2
# 407  ENCODE_REGION     CDS   56689   57573      +     2    AVPR2
# 408  ENCODE_REGION    exon   57680   58323      +     .    AVPR2
# 409  ENCODE_REGION     CDS   57680   57885      +     2    AVPR2
#
#              transcript
# 0          U52112.4-005
# 1          U52112.4-005
# 2          U52112.4-005
# 3          U52112.4-005
# 4          U52112.4-005
# 5          U52112.4-005
# 6          U52112.4-005
# 7          U52112.4-005
# 8          U52112.4-005
# 9          U52112.4-005
# 10         U52112.4-005
# 11         U52112.4-005
# 12         U52112.4-018
# 13         U52112.4-018
# 14         U52112.4-018
# 15         U52112.4-018
# 16         U52112.4-018
# 17         U52112.4-014
# 18         U52112.4-014
# 19         U52112.4-014
# 20         U52112.4-014
# 21         U52112.4-014
# 22         U52112.4-014
# 23         U52112.4-014
# 24         U52112.4-014
# 25         U52112.4-014
# 26         U52112.4-014
# 27         U52112.4-014
# 28         U52112.4-014
# 29         U52112.4-014
# ..                  ...
# 380  XX-FW83563B9.4-004
# 381  XX-FW83563B9.4-004
# 382  XX-FW83563B9.4-004
# 383  XX-FW83563B9.4-006
# 384  XX-FW83563B9.4-006
# 385  XX-FW83563B9.4-006
# 386  XX-FW83563B9.4-006
# 387  XX-FW83563B9.4-006
# 388  XX-FW83563B9.4-001
# 389  XX-FW83563B9.4-001
# 390  XX-FW83563B9.4-001
# 391  XX-FW83563B9.4-001
# 392  XX-FW83563B9.4-001
# 393  XX-FW83563B9.4-001
# 394  XX-FW83563B9.4-001
# 395        U52112.2-003
# 396        U52112.2-003
# 397        U52112.2-003
# 398        U52112.2-003
# 399        U52112.2-002
# 400        U52112.2-002
# 401        U52112.2-002
# 402        U52112.2-002
# 403        U52112.2-001
# 404        U52112.2-001
# 405        U52112.2-001
# 406        U52112.2-001
# 407        U52112.2-001
# 408        U52112.2-001
# 409        U52112.2-001
#
# [410 rows x 8 columns]

# %% [markdown]
# #### 6) Aggiungere la colonna `length` contenente la lunghezza della feature

# %% [markdown]
# #### 7) Rimuovere tutte le features di lunghezza minore o uguale a 6 basi

# %% [markdown]
# #### 8) Ottenere un data frame ordinato per coordinate crescenti delle features

# %% [markdown]
# #### 9) Ottenere un data frame ordinato per lunghezza crescente delle features

# %% [markdown]
# #### 10) Determinare la lista dei geni annotati

# %% [markdown]
# #### 11) Determinare la lista degli identificatori dei trascritti annotati

# %% [markdown]
# #### 12) Calcolare la lunghezza media delle features

# %% [markdown]
# #### 13) Determinare l'esone più corto e i trascritti che lo contengono
#
# a) Determinare la lunghezza minina degli esoni

# %% [markdown]
# b) Estrarre la lista dei trascritti che corrispondono agli esoni di lunghezza minima

# %% [markdown]
# #### 14) Contare quanti trascritti sono annotati per il gene `ARHGAP4`

# %% [markdown]
# #### 15) Estrarre la lista dei geni con strand `+`

# %% [markdown]
# #### 16) Estrarre il set degli esoni (distinti) del gene `ATP6AP1`
#
# **NB**: il set deve essere composto da tuple (start, end).

# %% [markdown]
# #### 17) Contare il numero di trascritti del gene `ARHGAP4` che hanno una CDS annotata (MODIFICA)

# %% [markdown]
# #### 18) Estrarre lo strand del gene  `ATP6AP1`

# %% [markdown]
# #### 19) Estrarre per ogni trascritto del gene  `ATP6AP1` la lista delle tuple (start, end) dei suoi esoni

# %% [markdown]
# a) Estrarre il data frame delle sole righe relative alle features `exon` dei trascritti del gene `ATP6AP1` e delle sole colonne `start`, `end` e `transcript`.

# %%
# Out:
#       start     end          transcript
# 366  543097  545706  XX-FW83563B9.4-002
# 377  542894  543223  XX-FW83563B9.4-004
# 387  548257  548495  XX-FW83563B9.4-006
# 382  548257  548495  XX-FW83563B9.4-004
# 376  548257  548495  XX-FW83563B9.4-003
# 371  548257  548495  XX-FW83563B9.4-002
# 394  548257  548495  XX-FW83563B9.4-001
# 388  542687  542902  XX-FW83563B9.4-001
# 372  542694  542902  XX-FW83563B9.4-003
# 379  546315  546508  XX-FW83563B9.4-004
# 368  546315  546508  XX-FW83563B9.4-002
# 391  546315  546508  XX-FW83563B9.4-001
# 365  542747  542902  XX-FW83563B9.4-002
# 384  543097  543223  XX-FW83563B9.4-006
# 373  543097  543223  XX-FW83563B9.4-003
# 389  543097  543223  XX-FW83563B9.4-001
# 383  542790  542902  XX-FW83563B9.4-006
# 375  546315  546425  XX-FW83563B9.4-003
# 393  547684  547769  XX-FW83563B9.4-001
# 381  547684  547769  XX-FW83563B9.4-004
# 370  547684  547769  XX-FW83563B9.4-002
# 385  545879  545953  XX-FW83563B9.4-006
# 367  545879  545953  XX-FW83563B9.4-002
# 378  545879  545953  XX-FW83563B9.4-004
# 390  545879  545953  XX-FW83563B9.4-001
# 374  545879  545953  XX-FW83563B9.4-003
# 386  547709  547769  XX-FW83563B9.4-006
# 369  546980  547020  XX-FW83563B9.4-002
# 380  546980  547020  XX-FW83563B9.4-004
# 392  546980  547020  XX-FW83563B9.4-001

# %% [markdown]
# b) Estrarre la lista dei trascritti

# %% [markdown]
# c) Estrarre per ogni trascritto la lista delle sue features (start, end)

# %% [markdown]
# d) Produrre in output per ogni trascritto la lista delle sue features (start, end)

# %%
)
# Out:
# XX-FW83563B9.4-002
# [(543097, 543097), (548257, 548257), (546315, 546315), (542747, 542747), (547684, 547684), (545879, 545879), (546980, 546980)]
# XX-FW83563B9.4-004
# [(542894, 542894), (548257, 548257), (546315, 546315), (547684, 547684), (545879, 545879), (546980, 546980)]
# XX-FW83563B9.4-006
# [(548257, 548257), (543097, 543097), (542790, 542790), (545879, 545879), (547709, 547709)]
# XX-FW83563B9.4-003
# [(548257, 548257), (542694, 542694), (543097, 543097), (546315, 546315), (545879, 545879)]
# XX-FW83563B9.4-001
# [(548257, 548257), (542687, 542687), (546315, 546315), (543097, 543097), (547684, 547684), (545879, 545879), (546980, 546980)]

# %% [markdown]
# #### 20) Contare per ogni gene quante sono le features annotate per ognuno dei tipi presenti nel GTF

# %%
df.groupby(['gene', 'feature'])['transcript'].count()
# Out:
# gene     feature
# ARHGAP4  CDS        110
#          exon       253
# ATP6AP1  exon        30
# AVPR2    CDS          5
#          exon        10
# Name: transcript, dtype: int64
