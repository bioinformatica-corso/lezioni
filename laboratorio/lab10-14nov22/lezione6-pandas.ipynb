# %% [markdown]
# # Introduzione a Pandas
#
# `Pandas` è una libreria basata sulla libreria `numpy`, che ha lo scopo di manipolare *Data Frames*.
#
# *Data Frame* (oggetto di tipo `DataFrame`): tabella che organizza i dati in righe (*record*) e colonne intestate (tabella di un base di dati relazionale).
#
# Le singole righe (*record*) e le singole colonne di un *data frame* vengono considerate oggetti di tipo `Series`, che sono fondamentalmente liste di valori con indice.
#
# Ogni colonna contiene dati omogenei. Ad ognuno delle righe del *data frame* viene associato un indice (chiave primaria) che di dafault è un indice intero progressivo.
#
# `Pandas` offre tre funzionalità principali:
#
# 1. costruzione
# 1. interrogazione
# 1. aggiornamento
#
# Formati da cui derivare un *data frame*: `csv`, `excel`, `json`.
#
# ---
#
# Importare `Pandas`:

# %%
import pandas as pd

# %% [markdown]
# ### Creazione di un *Data Frame* a partire da un dizionario
#
#        df = pd.DataFrame(data_dictionary)
#
# Le chiavi sono le intestazioni delle colonne e il valore di una chiave (colonna) è una lista dei valori. Tutti le liste devono avere lo stesso numero di elementi.

# %%
dati = {'Cognome':['Rossi', 'Bianchi', 'Verdi', 'Neri'],
           'Nome': ['Andrea', 'Sara', 'Tommaso', 'Anna'],
           'AnnoNascita': [2000, 2001, 1999, 2004]}

# %%
df = pd.DataFrame(dati)
df
# Out:
#    Cognome     Nome  AnnoNascita
# 0    Rossi   Andrea         2000
# 1  Bianchi     Sara         2001
# 2    Verdi  Tommaso         1999
# 3     Neri     Anna         2004

# %% [markdown]
# ### Creazione di un *Data Frame* a partire da una lista
#
#        df = pd.DataFrame(data_list, columns = column_names)
#
# Ogni lista interna corrisponde a una riga del *Data Frame*.

# %%
dati = []
dati.append(['Rossi', 'Andrea', 2000])
dati.append(['Bianchi', 'Sara', 2001])
dati.append(['Verdi', 'Tommaso', 1999])
dati.append(['Neri', 'Anna', 2004])
dati
# Out:
# [['Rossi', 'Andrea', 2000],
#  ['Bianchi', 'Sara', 2001],
#  ['Verdi', 'Tommaso', 1999],
#  ['Neri', 'Anna', 2004]]

# %%
df = pd.DataFrame(dati, columns=['Cognome', 'Nome', 'AnnoNascita'])
df
# Out:
#    Cognome     Nome  AnnoNascita
# 0    Rossi   Andrea         2000
# 1  Bianchi     Sara         2001
# 2    Verdi  Tommaso         1999
# 3     Neri     Anna         2004

# %% [markdown]
# ### Creazione di un *Data Frame* da un file `csv`
#
#     df = pd.read_csv(csv_file_name)

# %% [markdown]
# Il file di input viene riconosciuto come file `csv`, i tipi di dati contenuti nel file vengono automaticamente riconosciuti e il relativo *Data Frame* viene restituito.

# %% [markdown]
# ### Lettura del file `2017-german-election-overall.csv`

# %%
df = pd.read_csv("./2017-german-election-overall.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      area_id                         area_names               state  \
# 0          1              Flensburg – Schleswig  Schleswig-Holstein
# 1          2  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein
# 2          3       Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 3          4              Rendsburg-Eckernförde  Schleswig-Holstein
# 4          5                               Kiel  Schleswig-Holstein
# ..       ...                                ...                 ...
# 294      295           Zollernalb – Sigmaringen   Baden-Württemberg
# 295      296                        Saarbrücken            Saarland
# 296      297                          Saarlouis            Saarland
# 297      298                         St. Wendel            Saarland
# 298      299                            Homburg            Saarland
#
#      registered.voters  total_votes  invalid_first_votes  \
# 0               225659       171905                 1647
# 1               186384       139200                 1299
# 2               175950       132016                 1133
# 3               199632       157387                 1285
# 4               204650       151463                 1657
# ..                 ...          ...                  ...
# 294             183202       139544                 2354
# 295             199887       147602                 2304
# 296             207500       160371                 2422
# 297             177468       141378                 2620
# 298             192408       145990                 2668
#
#      invalid_second_votes  valid_first_votes  valid_second_votes
# 0                    1509             170258              170396
# 1                    1125             137901              138075
# 2                    1141             130883              130875
# 3                    1119             156102              156268
# 4                    1290             149806              150173
# ..                    ...                ...                 ...
# 294                  1818             137190              137726
# 295                  2171             145298              145431
# 296                  2831             157949              157540
# 297                  2668             138758              138710
# 298                  2467             143322              143523
#
# [299 rows x 9 columns]

# %% [markdown]
# ### Informazioni sul *Data Frame*
#
# - informazioni generali sul data frame
#
#         df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   area_id               299 non-null    int64
#  1   area_names            299 non-null    object
#  2   state                 299 non-null    object
#  3   registered.voters     299 non-null    int64
#  4   total_votes           299 non-null    int64
#  5   invalid_first_votes   299 non-null    int64
#  6   invalid_second_votes  299 non-null    int64
#  7   valid_first_votes     299 non-null    int64
#  8   valid_second_votes    299 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 21.1+ KB

# %% [markdown]
# ### Ottenere le prime/ultime `n` righe
#
#     df.head(n)
#     df.tail(n)

# %%
df.head(8)
# Out:
#    area_id                         area_names               state  \
# 0        1              Flensburg – Schleswig  Schleswig-Holstein
# 1        2  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein
# 2        3       Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 3        4              Rendsburg-Eckernförde  Schleswig-Holstein
# 4        5                               Kiel  Schleswig-Holstein
# 5        6                  Plön – Neumünster  Schleswig-Holstein
# 6        7                          Pinneberg  Schleswig-Holstein
# 7        8          Segeberg – Stormarn-Mitte  Schleswig-Holstein
#
#    registered.voters  total_votes  invalid_first_votes  invalid_second_votes  \
# 0             225659       171905                 1647                  1509
# 1             186384       139200                 1299                  1125
# 2             175950       132016                 1133                  1141
# 3             199632       157387                 1285                  1119
# 4             204650       151463                 1657                  1290
# 5             174934       131710                 1221                  1196
# 6             237474       187711                 1616                  1339
# 7             245826       193318                 1628                  1381
#
#    valid_first_votes  valid_second_votes
# 0             170258              170396
# 1             137901              138075
# 2             130883              130875
# 3             156102              156268
# 4             149806              150173
# 5             130489              130514
# 6             186095              186372
# 7             191690              191937

# %%
df.tail(8)
# Out:
#      area_id                area_names              state  registered.voters  \
# 291      292                  Biberach  Baden-Württemberg             167025
# 292      293                  Bodensee  Baden-Württemberg             172783
# 293      294                Ravensburg  Baden-Württemberg             186901
# 294      295  Zollernalb – Sigmaringen  Baden-Württemberg             183202
# 295      296               Saarbrücken           Saarland             199887
# 296      297                 Saarlouis           Saarland             207500
# 297      298                St. Wendel           Saarland             177468
# 298      299                   Homburg           Saarland             192408
#
#      total_votes  invalid_first_votes  invalid_second_votes  \
# 291       131713                 1635                  1441
# 292       137152                 1361                  1218
# 293       146174                 1524                  1389
# 294       139544                 2354                  1818
# 295       147602                 2304                  2171
# 296       160371                 2422                  2831
# 297       141378                 2620                  2668
# 298       145990                 2668                  2467
#
#      valid_first_votes  valid_second_votes
# 291             130078              130272
# 292             135791              135934
# 293             144650              144785
# 294             137190              137726
# 295             145298              145431
# 296             157949              157540
# 297             138758              138710
# 298             143322              143523

# %%
df.head()
# Out:
#    area_id                         area_names               state  \
# 0        1              Flensburg – Schleswig  Schleswig-Holstein
# 1        2  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein
# 2        3       Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 3        4              Rendsburg-Eckernförde  Schleswig-Holstein
# 4        5                               Kiel  Schleswig-Holstein
#
#    registered.voters  total_votes  invalid_first_votes  invalid_second_votes  \
# 0             225659       171905                 1647                  1509
# 1             186384       139200                 1299                  1125
# 2             175950       132016                 1133                  1141
# 3             199632       157387                 1285                  1119
# 4             204650       151463                 1657                  1290
#
#    valid_first_votes  valid_second_votes
# 0             170258              170396
# 1             137901              138075
# 2             130883              130875
# 3             156102              156268
# 4             149806              150173

# %%
df.tail()
# Out:
#      area_id                area_names              state  registered.voters  \
# 294      295  Zollernalb – Sigmaringen  Baden-Württemberg             183202
# 295      296               Saarbrücken           Saarland             199887
# 296      297                 Saarlouis           Saarland             207500
# 297      298                St. Wendel           Saarland             177468
# 298      299                   Homburg           Saarland             192408
#
#      total_votes  invalid_first_votes  invalid_second_votes  \
# 294       139544                 2354                  1818
# 295       147602                 2304                  2171
# 296       160371                 2422                  2831
# 297       141378                 2620                  2668
# 298       145990                 2668                  2467
#
#      valid_first_votes  valid_second_votes
# 294             137190              137726
# 295             145298              145431
# 296             157949              157540
# 297             138758              138710
# 298             143322              143523

# %% [markdown]
# ### Fare una copia di un *data frame*
#
#         df.copy()

# %%
df.copy()
# Out:
#      area_id                         area_names               state  \
# 0          1              Flensburg – Schleswig  Schleswig-Holstein
# 1          2  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein
# 2          3       Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 3          4              Rendsburg-Eckernförde  Schleswig-Holstein
# 4          5                               Kiel  Schleswig-Holstein
# ..       ...                                ...                 ...
# 294      295           Zollernalb – Sigmaringen   Baden-Württemberg
# 295      296                        Saarbrücken            Saarland
# 296      297                          Saarlouis            Saarland
# 297      298                         St. Wendel            Saarland
# 298      299                            Homburg            Saarland
#
#      registered.voters  total_votes  invalid_first_votes  \
# 0               225659       171905                 1647
# 1               186384       139200                 1299
# 2               175950       132016                 1133
# 3               199632       157387                 1285
# 4               204650       151463                 1657
# ..                 ...          ...                  ...
# 294             183202       139544                 2354
# 295             199887       147602                 2304
# 296             207500       160371                 2422
# 297             177468       141378                 2620
# 298             192408       145990                 2668
#
#      invalid_second_votes  valid_first_votes  valid_second_votes
# 0                    1509             170258              170396
# 1                    1125             137901              138075
# 2                    1141             130883              130875
# 3                    1119             156102              156268
# 4                    1290             149806              150173
# ..                    ...                ...                 ...
# 294                  1818             137190              137726
# 295                  2171             145298              145431
# 296                  2831             157949              157540
# 297                  2668             138758              138710
# 298                  2467             143322              143523
#
# [299 rows x 9 columns]

# %% [markdown]
# ### Variabili `shape` e `columns`
#
# - `shape`: numero di righe e di colonne del *Data Frame*
# - `columns`: nomi delle colonne del *Data Frame* (oggetto di tipo `Index`)

# %%
df.shape
# Out:
# (299, 9)

# %%
list(df.columns)
# Out:
# ['area_id',
#  'area_names',
#  'state',
#  'registered.voters',
#  'total_votes',
#  'invalid_first_votes',
#  'invalid_second_votes',
#  'valid_first_votes',
#  'valid_second_votes']

# %% [markdown]
# ### Cambiare nomi alle colonne
#
#     df.rename(columns = name_dict, inplace = True|False)
#
# - `name_dict`: dizionario fornisce il *mapping* tra vecchi nomi (chiavi) e nuovi nomi (valori)
# - se `inplace` è `True`, allora il *Data Frame* invocante viene aggiornato, altrimenti viene restituita una copia del *Data Frame* invocante con i nuovi nomi delle colonne. Il valore di default è `False`

# %%
df.rename(columns = {'registered.voters':'voters', 'area_names':'area'}, inplace = True)
df
# Out:
#                                       area               state  voters  \
# area_id
# 1                    Flensburg – Schleswig  Schleswig-Holstein  225659
# 2        Nordfriesland – Dithmarschen Nord  Schleswig-Holstein  186384
# 3             Steinburg – Dithmarschen Süd  Schleswig-Holstein  175950
# 4                    Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 5                                     Kiel  Schleswig-Holstein  204650
# ...                                    ...                 ...     ...
# 295               Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 296                            Saarbrücken            Saarland  199887
# 297                              Saarlouis            Saarland  207500
# 298                             St. Wendel            Saarland  177468
# 299                                Homburg            Saarland  192408
#
#          total_votes  invalid_first_votes  invalid_second_votes  \
# area_id
# 1             171905                 1647                  1509
# 2             139200                 1299                  1125
# 3             132016                 1133                  1141
# 4             157387                 1285                  1119
# 5             151463                 1657                  1290
# ...              ...                  ...                   ...
# 295           139544                 2354                  1818
# 296           147602                 2304                  2171
# 297           160371                 2422                  2831
# 298           141378                 2620                  2668
# 299           145990                 2668                  2467
#
#          valid_first_votes  valid_second_votes
# area_id
# 1                   170258              170396
# 2                   137901              138075
# 3                   130883              130875
# 4                   156102              156268
# 5                   149806              150173
# ...                    ...                 ...
# 295                 137190              137726
# 296                 145298              145431
# 297                 157949              157540
# 298                 138758              138710
# 299                 143322              143523
#
# [299 rows x 8 columns]

# %% [markdown]
# ### Rimuovere righe e colonne
#
# Il metodo `drop()`:
#
#     df.drop(list_to_remove, axis = 1|0, inplace = True|False)
#
# rimuove le colonne (`axis = 1`) o le righe (`axis = 0`) specificate in nella lista `list_to_remove` che è la lista dei nomi delle colonne da rimuovere nel primo caso e la lista degli indici (chiavi primarie) delle righe da rimuovere nel secondo caso.
#
# Se le colonne/righe specificate non sono presenti nel *Data Frame*, viene lanciato un `KeyError`.
#
# `inplace = True` significa che il *data frame* invocante viene aggiornato, mentre per `inplace = False` viene restituita una copia aggiornata.
#
# **NB**: per rimuovere una sola riga/colonna si può mettere il solo indice/nome di colonna al posto della lista.
#
# ---

# %% [markdown]
# **ESERCIZIO**: rimuovere le colonne `valid_first_votes` e `invalid_first_votes` e in seguito le righe con indici `2`, `9` e `10`.

# %%
df.drop(['valid_first_votes', 'invalid_first_votes'], axis=1, inplace = True)
df
# Out:
#                                       area               state  voters  \
# area_id
# 1                    Flensburg – Schleswig  Schleswig-Holstein  225659
# 2        Nordfriesland – Dithmarschen Nord  Schleswig-Holstein  186384
# 3             Steinburg – Dithmarschen Süd  Schleswig-Holstein  175950
# 4                    Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 5                                     Kiel  Schleswig-Holstein  204650
# ...                                    ...                 ...     ...
# 295               Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 296                            Saarbrücken            Saarland  199887
# 297                              Saarlouis            Saarland  207500
# 298                             St. Wendel            Saarland  177468
# 299                                Homburg            Saarland  192408
#
#          total_votes  invalid_second_votes  valid_second_votes
# area_id
# 1             171905                  1509              170396
# 2             139200                  1125              138075
# 3             132016                  1141              130875
# 4             157387                  1119              156268
# 5             151463                  1290              150173
# ...              ...                   ...                 ...
# 295           139544                  1818              137726
# 296           147602                  2171              145431
# 297           160371                  2831              157540
# 298           141378                  2668              138710
# 299           145990                  2467              143523
#
# [299 rows x 6 columns]

# %%
df.drop([2,9,12], axis=0, inplace = True)
df.head(15)
# Out:
#                                                       area  \
# area_id
# 1                                    Flensburg – Schleswig
# 3                             Steinburg – Dithmarschen Süd
# 4                                    Rendsburg-Eckernförde
# 5                                                     Kiel
# 6                                        Plön – Neumünster
# 7                                                Pinneberg
# 8                                Segeberg – Stormarn-Mitte
# 10                      Herzogtum Lauenburg – Stormarn-Süd
# 11                                                  Lübeck
# 13       Ludwigslust-Parchim II – Nordwestmecklenburg I...
# 14                          Rostock – Landkreis Rostock II
# 15              Vorpommern-Rügen – Vorpommern-Greifswald I
# 16       Mecklenburgische Seenplatte I – Vorpommern-Gre...
# 17       Mecklenburgische Seenplatte II – Landkreis Ros...
# 18                                           Hamburg-Mitte
#
#                           state  voters  total_votes  invalid_second_votes  \
# area_id
# 1            Schleswig-Holstein  225659       171905                  1509
# 3            Schleswig-Holstein  175950       132016                  1141
# 4            Schleswig-Holstein  199632       157387                  1119
# 5            Schleswig-Holstein  204650       151463                  1290
# 6            Schleswig-Holstein  174934       131710                  1196
# 7            Schleswig-Holstein  237474       187711                  1339
# 8            Schleswig-Holstein  245826       193318                  1381
# 10           Schleswig-Holstein  244503       193359                  1388
# 11           Schleswig-Holstein  181637       130976                  1171
# 13       Mecklenburg-Vorpommern  205757       146781                  1673
# 14       Mecklenburg-Vorpommern  222718       164037                  1731
# 15       Mecklenburg-Vorpommern  240887       169526                  2115
# 16       Mecklenburg-Vorpommern  225843       156966                  2159
# 17       Mecklenburg-Vorpommern  212051       144268                  1791
# 18                      Hamburg  243510       175800                  1460
#
#          valid_second_votes
# area_id
# 1                    170396
# 3                    130875
# 4                    156268
# 5                    150173
# 6                    130514
# 7                    186372
# 8                    191937
# 10                   191971
# 11                   129805
# 13                   145108
# 14                   162306
# 15                   167411
# 16                   154807
# 17                   142477
# 18                   174340

# %% [markdown]
# ### Selezionare una colonna
#
# Le espressioni:
#
#     df[column_name]
#     df.column_name
#
# restituiscono la colonna avente nome `column_name`, in un oggetto di tipo `Series`.
#
# ---
#
# **NB**: le espressioni:
#
#     df[column_name] = new_value
#     df.column_name = new_value
#
# aggiornano tutti i valori della colonna, restituita dall'espressione a sinistra dell'assegnamento, con il nuovo valore `new_value`.
#
# Analogo è il comportamento degli altri costrutti di accesso al *data frame*.
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre la colonna `voters`.

# %%
df['voters']
# Out:
# area_id
# 1      225659
# 3      175950
# 4      199632
# 5      204650
# 6      174934
#         ...
# 295    183202
# 296    199887
# 297    207500
# 298    177468
# 299    192408
# Name: voters, Length: 296, dtype: int64

# %%
df.voters
# Out:
# area_id
# 1      225659
# 3      175950
# 4      199632
# 5      204650
# 6      174934
#         ...
# 295    183202
# 296    199887
# 297    207500
# 298    177468
# 299    192408
# Name: voters, Length: 296, dtype: int64

# %% [markdown]
# **NB**: i singoli valori in una colonna mantengono l'indice associato alla riga a cui appartengono.

# %%
list(df.voters)
# Out:
# [225659,
#  175950,
#  199632,
#  204650,
#  174934,
#  237474,
#  245826,
#  244503,
#  181637,
#  205757,
#  222718,
#  240887,
#  225843,
#  212051,
#  243510,
#  185942,
#  192399,
#  217226,
#  235513,
#  222034,
#  191560,
#  235233,
#  189344,
#  226253,
#  227695,
#  187679,
#  197298,
#  230151,
#  220042,
#  193959,
#  196136,
#  168081,
#  199081,
#  180866,
#  199131,
#  196475,
#  194800,
#  179883,
#  193433,
#  233242,
#  214617,
#  217905,
#  187377,
#  240015,
#  218349,
#  206133,
#  192041,
#  183963,
#  202963,
#  220420,
#  252461,
#  221636,
#  176001,
#  184714,
#  243106,
#  226413,
#  183181,
#  247441,
#  248676,
#  194757,
#  178676,
#  168542,
#  165625,
#  220787,
#  215606,
#  238060,
#  177004,
#  224494,
#  214668,
#  191636,
#  207102,
#  206706,
#  237071,
#  182392,
#  184602,
#  221209,
#  198672,
#  235250,
#  202616,
#  223426,
#  205105,
#  200704,
#  205300,
#  179273,
#  228247,
#  190051,
#  199675,
#  248982,
#  246753,
#  192571,
#  240982,
#  203644,
#  227583,
#  237415,
#  216020,
#  208418,
#  217422,
#  212208,
#  208129,
#  222845,
#  205238,
#  163228,
#  220762,
#  193175,
#  214779,
#  190552,
#  201450,
#  227423,
#  226096,
#  207178,
#  179117,
#  167998,
#  160204,
#  204816,
#  187746,
#  163326,
#  192918,
#  169267,
#  189375,
#  175210,
#  202202,
#  202793,
#  199978,
#  192946,
#  195571,
#  232294,
#  209604,
#  234272,
#  246216,
#  228976,
#  204203,
#  170501,
#  211026,
#  249359,
#  207384,
#  178506,
#  206460,
#  179247,
#  211316,
#  203300,
#  197873,
#  235213,
#  232300,
#  202768,
#  212818,
#  206716,
#  200562,
#  163765,
#  220654,
#  227718,
#  215522,
#  201205,
#  214033,
#  212796,
#  202524,
#  232636,
#  235455,
#  201560,
#  195929,
#  183307,
#  220896,
#  207606,
#  193063,
#  186825,
#  222451,
#  175992,
#  188074,
#  183296,
#  208740,
#  217806,
#  209966,
#  179307,
#  181516,
#  176435,
#  220341,
#  189372,
#  177469,
#  197291,
#  199775,
#  223942,
#  174727,
#  220194,
#  242622,
#  234421,
#  198679,
#  216673,
#  222558,
#  202063,
#  198344,
#  221922,
#  240683,
#  229126,
#  234445,
#  239317,
#  195622,
#  197045,
#  172776,
#  185172,
#  164685,
#  192846,
#  210117,
#  248996,
#  213650,
#  215749,
#  220597,
#  229169,
#  177697,
#  217624,
#  168222,
#  206077,
#  235603,
#  231971,
#  246357,
#  226436,
#  239169,
#  216725,
#  241282,
#  233872,
#  233688,
#  165228,
#  213619,
#  208525,
#  166804,
#  166659,
#  249185,
#  176849,
#  168564,
#  172975,
#  215218,
#  252910,
#  216003,
#  167658,
#  181535,
#  163610,
#  159613,
#  167279,
#  170332,
#  243106,
#  180176,
#  254300,
#  192214,
#  181809,
#  226731,
#  183201,
#  214956,
#  195908,
#  198521,
#  225057,
#  210524,
#  248196,
#  190781,
#  239662,
#  225952,
#  246852,
#  194368,
#  182501,
#  245680,
#  168715,
#  206806,
#  178409,
#  223264,
#  218071,
#  229280,
#  242555,
#  225601,
#  176967,
#  221916,
#  208868,
#  209741,
#  206651,
#  217934,
#  197283,
#  211065,
#  197972,
#  196426,
#  219577,
#  198020,
#  222308,
#  231734,
#  218613,
#  205551,
#  199227,
#  165041,
#  205618,
#  177805,
#  199932,
#  196487,
#  222673,
#  167025,
#  172783,
#  186901,
#  183202,
#  199887,
#  207500,
#  177468,
#  192408]

# %% [markdown]
# **ESERCIZIO**: aggiornare a 0 tutti i valori della colonna `area_id`.

# %%
df['area_id'] = 0

# %%
df
# Out:
#                                  area               state  voters  \
# area_id
# 1               Flensburg – Schleswig  Schleswig-Holstein  225659
# 3        Steinburg – Dithmarschen Süd  Schleswig-Holstein  175950
# 4               Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 5                                Kiel  Schleswig-Holstein  204650
# 6                   Plön – Neumünster  Schleswig-Holstein  174934
# ...                               ...                 ...     ...
# 295          Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 296                       Saarbrücken            Saarland  199887
# 297                         Saarlouis            Saarland  207500
# 298                        St. Wendel            Saarland  177468
# 299                           Homburg            Saarland  192408
#
#          total_votes  invalid_second_votes  valid_second_votes  area_id
# area_id
# 1             171905                  1509              170396        0
# 3             132016                  1141              130875        0
# 4             157387                  1119              156268        0
# 5             151463                  1290              150173        0
# 6             131710                  1196              130514        0
# ...              ...                   ...                 ...      ...
# 295           139544                  1818              137726        0
# 296           147602                  2171              145431        0
# 297           160371                  2831              157540        0
# 298           141378                  2668              138710        0
# 299           145990                  2467              143523        0
#
# [296 rows x 7 columns]

# %% [markdown]
# ### Selezionare più colonne
#
# L'espressione:
#
#     df[column_list]
#
# restituisce le colonne della lista `column_list`, in un oggetto di tipo `DataFrame`.
#
# ---
#
# L'espressione:
#
#     df[column_list] = new_value
#
# aggiorna tutti i valori del *data frame*, restituito dall'espressione a sinistra dell'assegnamento, con il nuovo valore `new_value`.
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre le colonne `voters` e `total_votes`.

# %%
column_list = ['voters', 'total_votes']

selected_columns_df = df[column_list]
selected_columns_df
# Out:
#          voters  total_votes
# area_id
# 1        225659       171905
# 3        175950       132016
# 4        199632       157387
# 5        204650       151463
# 6        174934       131710
# ...         ...          ...
# 295      183202       139544
# 296      199887       147602
# 297      207500       160371
# 298      177468       141378
# 299      192408       145990
#
# [296 rows x 2 columns]

# %% [markdown]
# **NB:** se `column_list` contiene un'unica stringa, il *data frame* sarà composto da un'unica colonna.

# %%
column_list = ['total_votes']

selected_columns_df = df[column_list]
selected_columns_df
# Out:
#          total_votes
# area_id
# 1             171905
# 3             132016
# 4             157387
# 5             151463
# 6             131710
# ...              ...
# 295           139544
# 296           147602
# 297           160371
# 298           141378
# 299           145990
#
# [296 rows x 1 columns]

# %% [markdown]
# ### Ottenere gli indici di riga (chiavi primarie)
#
# L'espressione:
#
#     df.index
#
# restituisce gli indici delle righe del *data frame* invocante.
#
# **NB**: gli indici possono anche essere ottenuti da un oggetto di tipo `Series` (riga o colonna).
#
# ---

# %%
df.index
# Out:
# Int64Index([  1,   3,   4,   5,   6,   7,   8,  10,  11,  13,
#             ...
#             290, 291, 292, 293, 294, 295, 296, 297, 298, 299],
#            dtype='int64', name='area_id', length=296)

# %%
df.state.index
# Out:
# Int64Index([  1,   3,   4,   5,   6,   7,   8,  10,  11,  13,
#             ...
#             290, 291, 292, 293, 294, 295, 296, 297, 298, 299],
#            dtype='int64', name='area_id', length=296)

# %% [markdown]
# ### Aggiornare una colonna
#
# L'istruzione di assegnamento:
#
#     df[column_name] = series_obj
#
# aggiorna la colonna `column_name` con i valori dell'oggetto `series_obj` che deve essere della stessa dimensione del *data frame*.
#
# **NB**: `series_obj` può essere il risultato di un'espressione.
#
# ---

# %% [markdown]
# **ESERCIZIO**: aggiornare i valori della colonna `area` con i relativi indici (chiave primaria).

# %%
df['area_id'] = df.index

# %%
df
# Out:
#                                  area               state  voters  \
# area_id
# 1               Flensburg – Schleswig  Schleswig-Holstein  225659
# 3        Steinburg – Dithmarschen Süd  Schleswig-Holstein  175950
# 4               Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 5                                Kiel  Schleswig-Holstein  204650
# 6                   Plön – Neumünster  Schleswig-Holstein  174934
# ...                               ...                 ...     ...
# 295          Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 296                       Saarbrücken            Saarland  199887
# 297                         Saarlouis            Saarland  207500
# 298                        St. Wendel            Saarland  177468
# 299                           Homburg            Saarland  192408
#
#          total_votes  invalid_second_votes  valid_second_votes  area_id
# area_id
# 1             171905                  1509              170396        1
# 3             132016                  1141              130875        3
# 4             157387                  1119              156268        4
# 5             151463                  1290              150173        5
# 6             131710                  1196              130514        6
# ...              ...                   ...                 ...      ...
# 295           139544                  1818              137726      295
# 296           147602                  2171              145431      296
# 297           160371                  2831              157540      297
# 298           141378                  2668              138710      298
# 299           145990                  2467              143523      299
#
# [296 rows x 7 columns]

# %% [markdown]
# ### Aggiungere una colonna
#
# L'istruzione di assegnamento:
#
#     df[new_column_name] = series_obj
#
# aggiunge la colonna `new_column_name` con i valori dell'oggetto `series_obj` che deve essere della stessa dimensione del *data frame*.
#
# **NB**: `series_obj` può essere il risultato di un'espressione.
#
# ---

# %% [markdown]
# **ESERCIZIO**: aggiungere la colonna che contiene la differenza tra le colonne `total_votes` e `invalid_second_votes`

# %%
df['check_valid'] = df['total_votes'] - df['invalid_second_votes']
df
# Out:
#                                  area               state  voters  \
# area_id
# 1               Flensburg – Schleswig  Schleswig-Holstein  225659
# 3        Steinburg – Dithmarschen Süd  Schleswig-Holstein  175950
# 4               Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 5                                Kiel  Schleswig-Holstein  204650
# 6                   Plön – Neumünster  Schleswig-Holstein  174934
# ...                               ...                 ...     ...
# 295          Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 296                       Saarbrücken            Saarland  199887
# 297                         Saarlouis            Saarland  207500
# 298                        St. Wendel            Saarland  177468
# 299                           Homburg            Saarland  192408
#
#          total_votes  invalid_second_votes  valid_second_votes  area_id  \
# area_id
# 1             171905                  1509              170396        1
# 3             132016                  1141              130875        3
# 4             157387                  1119              156268        4
# 5             151463                  1290              150173        5
# 6             131710                  1196              130514        6
# ...              ...                   ...                 ...      ...
# 295           139544                  1818              137726      295
# 296           147602                  2171              145431      296
# 297           160371                  2831              157540      297
# 298           141378                  2668              138710      298
# 299           145990                  2467              143523      299
#
#          check_valid
# area_id
# 1             170396
# 3             130875
# 4             156268
# 5             150173
# 6             130514
# ...              ...
# 295           137726
# 296           145431
# 297           157540
# 298           138710
# 299           143523
#
# [296 rows x 8 columns]

# %% [markdown]
# ### Selezionare le righe tramite *slicing*
#
# L'espressione:
#
#     df[start_pos_index:end_pos_index:step]
#
# restituisce le righe che hanno indice di posizione compreso tra `start_pos_index` e `end_pos_index` secondo lo step indicato, in un oggetto `DataFrame`.
#
# ---
#
# L'espressione:
#
#     df[start_pos_index:end_pos_index:step] = new_value
#
# aggiorna tutti i valori dell'oggetto, restituito dall'espressione a sinistra dell'assegnamento, con il nuovo valore `new_value`.
#
# ---
#
# **NB**: lo *slicing* può essere applicato anche a un oggetto di tipo `Series` (riga o colonna).
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre le righe dalla quarta alla undicesima.

# %%
df[3:11]
# Out:
#                                                       area  \
# area_id
# 5                                                     Kiel
# 6                                        Plön – Neumünster
# 7                                                Pinneberg
# 8                                Segeberg – Stormarn-Mitte
# 10                      Herzogtum Lauenburg – Stormarn-Süd
# 11                                                  Lübeck
# 13       Ludwigslust-Parchim II – Nordwestmecklenburg I...
# 14                          Rostock – Landkreis Rostock II
#
#                           state  voters  total_votes  invalid_second_votes  \
# area_id
# 5            Schleswig-Holstein  204650       151463                  1290
# 6            Schleswig-Holstein  174934       131710                  1196
# 7            Schleswig-Holstein  237474       187711                  1339
# 8            Schleswig-Holstein  245826       193318                  1381
# 10           Schleswig-Holstein  244503       193359                  1388
# 11           Schleswig-Holstein  181637       130976                  1171
# 13       Mecklenburg-Vorpommern  205757       146781                  1673
# 14       Mecklenburg-Vorpommern  222718       164037                  1731
#
#          valid_second_votes  area_id  check_valid
# area_id
# 5                    150173        5       150173
# 6                    130514        6       130514
# 7                    186372        7       186372
# 8                    191937        8       191937
# 10                   191971       10       191971
# 11                   129805       11       129805
# 13                   145108       13       145108
# 14                   162306       14       162306

# %% [markdown]
# ### Selezionare le righe in base a una condizione
#
# Una maschera è un oggetto di tipo `Series` che contiene valori booleani `True` e `False` e che può essere utilizzata per selezionare le righe di un *data frame*.
#
# L'espressione:
#
#     df[mask]
#
# restituisce un *data frame* con le sole righe che corrispondono a un valore `True` di `mask`.
#
# La dimensione di `mask` deve essere uguale al numero di righe in `df`ed è il risultato di un'espressione booleana.
#
# ---
#
# L'espressione:
#
#     df[mask] = new_value
#
# aggiorna tutti i valori del *data frame* restituito a sinistra con il nuovo valore `new_value`.
#
# ---
#
# **NB**: la maschera può essere applicata anche a un oggetto di tipo `Series` (riga o colonna).
#
# ---

# %% [markdown]
# **ESERCIZIO**: selezionare le righe del *data frame* che hanno valore `Berlin` nella colonna `state`.

# %%
mask = df.state == 'Berlin'
mask
# Out:
# area_id
# 1      False
# 3      False
# 4      False
# 5      False
# 6      False
#        ...
# 295    False
# 296    False
# 297    False
# 298    False
# 299    False
# Name: state, Length: 296, dtype: bool

# %%
df[mask]
# Out:
#                                                       area   state  voters  \
# area_id
# 75                                            Berlin-Mitte  Berlin  206706
# 76                                           Berlin-Pankow  Berlin  237071
# 77                                    Berlin-Reinickendorf  Berlin  182392
# 78                    Berlin-Spandau – Charlottenburg Nord  Berlin  184602
# 79                              Berlin-Steglitz-Zehlendorf  Berlin  221209
# 80                       Berlin-Charlottenburg-Wilmersdorf  Berlin  198672
# 81                             Berlin-Tempelhof-Schöneberg  Berlin  235250
# 82                                         Berlin-Neukölln  Berlin  202616
# 83       Berlin-Friedrichshain-Kreuzberg – Prenzlauer B...  Berlin  223426
# 84                                 Berlin-Treptow-Köpenick  Berlin  205105
# 85                              Berlin-Marzahn-Hellersdorf  Berlin  200704
# 86                                      Berlin-Lichtenberg  Berlin  205300
#
#          total_votes  invalid_second_votes  valid_second_votes  area_id  \
# area_id
# 75            151634                  2214              149420       75
# 76            188607                  2198              186409       76
# 77            137084                  2171              134913       77
# 78            132934                  2276              130658       78
# 79            180827                  2110              178717       79
# 80            158245                  1429              156816       80
# 81            181259                  2162              179097       81
# 82            143790                  2980              140810       82
# 83            173504                  1664              171840       83
# 84            157461                  2124              155337       84
# 85            138988                  2064              136924       85
# 86            149053                  2153              146900       86
#
#          check_valid
# area_id
# 75            149420
# 76            186409
# 77            134913
# 78            130658
# 79            178717
# 80            156816
# 81            179097
# 82            140810
# 83            171840
# 84            155337
# 85            136924
# 86            146900

# %% [markdown]
# ---
#
# **ESERCIZIO**: produrre le aree e il numero dei votanti per gli stati `Berlin` e `Bayern`.

# %%
mask = (df['state'] == 'Berlin') | (df['state'] == 'Bayern')
df[mask]
# Out:
#                                                       area   state  voters  \
# area_id
# 75                                            Berlin-Mitte  Berlin  206706
# 76                                           Berlin-Pankow  Berlin  237071
# 77                                    Berlin-Reinickendorf  Berlin  182392
# 78                    Berlin-Spandau – Charlottenburg Nord  Berlin  184602
# 79                              Berlin-Steglitz-Zehlendorf  Berlin  221209
# 80                       Berlin-Charlottenburg-Wilmersdorf  Berlin  198672
# 81                             Berlin-Tempelhof-Schöneberg  Berlin  235250
# 82                                         Berlin-Neukölln  Berlin  202616
# 83       Berlin-Friedrichshain-Kreuzberg – Prenzlauer B...  Berlin  223426
# 84                                 Berlin-Treptow-Köpenick  Berlin  205105
# 85                              Berlin-Marzahn-Hellersdorf  Berlin  200704
# 86                                      Berlin-Lichtenberg  Berlin  205300
# 212                                              Altötting  Bayern  168222
# 213                                     Erding – Ebersberg  Bayern  206077
# 214                                               Freising  Bayern  235603
# 215                                       Fürstenfeldbruck  Bayern  231971
# 216                                             Ingolstadt  Bayern  246357
# 217                                           München-Nord  Bayern  226436
# 218                                            München-Ost  Bayern  239169
# 219                                            München-Süd  Bayern  216725
# 220                                     München-West/Mitte  Bayern  241282
# 221                                           München-Land  Bayern  233872
# 222                                              Rosenheim  Bayern  233688
# 223                     Bad Tölz-Wolfratshausen – Miesbach  Bayern  165228
# 224                          Starnberg – Landsberg am Lech  Bayern  213619
# 225                                             Traunstein  Bayern  208525
# 226                                               Weilheim  Bayern  166804
# 227                                             Deggendorf  Bayern  166659
# 228                                               Landshut  Bayern  249185
# 229                                                 Passau  Bayern  176849
# 230                                             Rottal-Inn  Bayern  168564
# 231                                              Straubing  Bayern  172975
# 232                                                 Amberg  Bayern  215218
# 233                                             Regensburg  Bayern  252910
# 234                                             Schwandorf  Bayern  216003
# 235                                                 Weiden  Bayern  167658
# 236                                                Bamberg  Bayern  181535
# 237                                               Bayreuth  Bayern  163610
# 238                                                 Coburg  Bayern  159613
# 239                                                    Hof  Bayern  167279
# 240                                               Kulmbach  Bayern  170332
# 241                                                Ansbach  Bayern  243106
# 242                                               Erlangen  Bayern  180176
# 243                                                  Fürth  Bayern  254300
# 244                                          Nürnberg-Nord  Bayern  192214
# 245                                           Nürnberg-Süd  Bayern  181809
# 246                                                   Roth  Bayern  226731
# 247                                          Aschaffenburg  Bayern  183201
# 248                                          Bad Kissingen  Bayern  214956
# 249                                          Main-Spessart  Bayern  195908
# 250                                            Schweinfurt  Bayern  198521
# 251                                               Würzburg  Bayern  225057
# 252                                         Augsburg-Stadt  Bayern  210524
# 253                                          Augsburg-Land  Bayern  248196
# 254                                             Donau-Ries  Bayern  190781
# 255                                                Neu-Ulm  Bayern  239662
# 256                                             Oberallgäu  Bayern  225952
# 257                                              Ostallgäu  Bayern  246852
#
#          total_votes  invalid_second_votes  valid_second_votes  area_id  \
# area_id
# 75            151634                  2214              149420       75
# 76            188607                  2198              186409       76
# 77            137084                  2171              134913       77
# 78            132934                  2276              130658       78
# 79            180827                  2110              178717       79
# 80            158245                  1429              156816       80
# 81            181259                  2162              179097       81
# 82            143790                  2980              140810       82
# 83            173504                  1664              171840       83
# 84            157461                  2124              155337       84
# 85            138988                  2064              136924       85
# 86            149053                  2153              146900       86
# 212           126774                   865              125909      212
# 213           163366                   758              162608      213
# 214           186680                  1046              185634      214
# 215           190809                   967              189842      215
# 216           184087                  1247              182840      216
# 217           173781                   689              173092      217
# 218           186882                   835              186047      218
# 219           170440                   670              169770      219
# 220           193426                   831              192595      220
# 221           197288                   926              196362      221
# 222           186501                  1045              185456      222
# 223           132621                   804              131817      223
# 224           177007                   748              176259      224
# 225           160611                  1043              159568      225
# 226           134339                   779              133560      226
# 227           119459                   704              118755      227
# 228           192967                  1273              191694      228
# 229           131355                   784              130571      229
# 230           124323                   819              123504      230
# 231           129426                  1219              128207      231
# 232           169499                  1296              168203      232
# 233           198800                  1137              197663      233
# 234           162561                  1279              161282      234
# 235           130522                  1183              129339      235
# 236           145235                   817              144418      236
# 237           127225                   703              126522      237
# 238           123215                  1036              122179      238
# 239           126945                  1154              125791      239
# 240           135075                  1164              133911      240
# 241           185988                  1567              184421      241
# 242           148057                   687              147370      242
# 243           198764                  1421              197343      243
# 244           146205                   901              145304      244
# 245           132085                  1107              130978      245
# 246           185907                  1362              184545      246
# 247           144896                  1518              143378      247
# 248           171210                  1307              169903      248
# 249           157180                  1221              155959      249
# 250           156173                  1233              154940      250
# 251           182986                  1084              181902      251
# 252           153230                  1173              152057      252
# 253           199076                  1238              197838      253
# 254           147865                  1039              146826      254
# 255           182035                  1273              180762      255
# 256           176432                  1091              175341      256
# 257           191581                  1422              190159      257
#
#          check_valid
# area_id
# 75            149420
# 76            186409
# 77            134913
# 78            130658
# 79            178717
# 80            156816
# 81            179097
# 82            140810
# 83            171840
# 84            155337
# 85            136924
# 86            146900
# 212           125909
# 213           162608
# 214           185634
# 215           189842
# 216           182840
# 217           173092
# 218           186047
# 219           169770
# 220           192595
# 221           196362
# 222           185456
# 223           131817
# 224           176259
# 225           159568
# 226           133560
# 227           118755
# 228           191694
# 229           130571
# 230           123504
# 231           128207
# 232           168203
# 233           197663
# 234           161282
# 235           129339
# 236           144418
# 237           126522
# 238           122179
# 239           125791
# 240           133911
# 241           184421
# 242           147370
# 243           197343
# 244           145304
# 245           130978
# 246           184545
# 247           143378
# 248           169903
# 249           155959
# 250           154940
# 251           181902
# 252           152057
# 253           197838
# 254           146826
# 255           180762
# 256           175341
# 257           190159

# %%
df[mask][['area', 'voters']]
# Out:
#                                                       area  voters
# area_id
# 75                                            Berlin-Mitte  206706
# 76                                           Berlin-Pankow  237071
# 77                                    Berlin-Reinickendorf  182392
# 78                    Berlin-Spandau – Charlottenburg Nord  184602
# 79                              Berlin-Steglitz-Zehlendorf  221209
# 80                       Berlin-Charlottenburg-Wilmersdorf  198672
# 81                             Berlin-Tempelhof-Schöneberg  235250
# 82                                         Berlin-Neukölln  202616
# 83       Berlin-Friedrichshain-Kreuzberg – Prenzlauer B...  223426
# 84                                 Berlin-Treptow-Köpenick  205105
# 85                              Berlin-Marzahn-Hellersdorf  200704
# 86                                      Berlin-Lichtenberg  205300
# 212                                              Altötting  168222
# 213                                     Erding – Ebersberg  206077
# 214                                               Freising  235603
# 215                                       Fürstenfeldbruck  231971
# 216                                             Ingolstadt  246357
# 217                                           München-Nord  226436
# 218                                            München-Ost  239169
# 219                                            München-Süd  216725
# 220                                     München-West/Mitte  241282
# 221                                           München-Land  233872
# 222                                              Rosenheim  233688
# 223                     Bad Tölz-Wolfratshausen – Miesbach  165228
# 224                          Starnberg – Landsberg am Lech  213619
# 225                                             Traunstein  208525
# 226                                               Weilheim  166804
# 227                                             Deggendorf  166659
# 228                                               Landshut  249185
# 229                                                 Passau  176849
# 230                                             Rottal-Inn  168564
# 231                                              Straubing  172975
# 232                                                 Amberg  215218
# 233                                             Regensburg  252910
# 234                                             Schwandorf  216003
# 235                                                 Weiden  167658
# 236                                                Bamberg  181535
# 237                                               Bayreuth  163610
# 238                                                 Coburg  159613
# 239                                                    Hof  167279
# 240                                               Kulmbach  170332
# 241                                                Ansbach  243106
# 242                                               Erlangen  180176
# 243                                                  Fürth  254300
# 244                                          Nürnberg-Nord  192214
# 245                                           Nürnberg-Süd  181809
# 246                                                   Roth  226731
# 247                                          Aschaffenburg  183201
# 248                                          Bad Kissingen  214956
# 249                                          Main-Spessart  195908
# 250                                            Schweinfurt  198521
# 251                                               Würzburg  225057
# 252                                         Augsburg-Stadt  210524
# 253                                          Augsburg-Land  248196
# 254                                             Donau-Ries  190781
# 255                                                Neu-Ulm  239662
# 256                                             Oberallgäu  225952
# 257                                              Ostallgäu  246852

# %% [markdown]
# ---
#
# **ESERCIZIO**: estrarre gli indici delle righe che corrispondono agli stati `Berlin` e `Bayern`.

# %%
mask = (df['state'] == 'Berlin') | (df['state'] == 'Bayern')
df[mask].index
# Out:
# Int64Index([ 75,  76,  77,  78,  79,  80,  81,  82,  83,  84,  85,  86, 212,
#             213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225,
#             226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238,
#             239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251,
#             252, 253, 254, 255, 256, 257],
#            dtype='int64', name='area_id')

# %% [markdown]
# ### Selezionare una riga tramite `iloc[]`
#
# Il metodo:
#
#     df.iloc[pos_index]
#
# prende in input e restituisce la riga che ha indice di posizione `pos_index`, in un oggetto di tipo `Series`.
#
# ---
#
# L'espressione:
#
#     df.iloc[pos_index] = new_value
#
# aggiorna tutti i valori della riga restituita a sinistra con il nuovo valore `new_value`.
#
# ---
#
# **NB**: `iloc[pos_index]` può essere invocato anche da un oggetto di tipo `Series` (riga o colonna).

# %% [markdown]
# ---
#
# **ESERCIZIO**: estrarre l'area della riga con indice di posizione `2` (cioé la terza riga del *data frame*).

# %%
df
# Out:
#                                  area               state  voters  \
# area_id
# 1               Flensburg – Schleswig  Schleswig-Holstein  225659
# 3        Steinburg – Dithmarschen Süd  Schleswig-Holstein  175950
# 4               Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 5                                Kiel  Schleswig-Holstein  204650
# 6                   Plön – Neumünster  Schleswig-Holstein  174934
# ...                               ...                 ...     ...
# 295          Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 296                       Saarbrücken            Saarland  199887
# 297                         Saarlouis            Saarland  207500
# 298                        St. Wendel            Saarland  177468
# 299                           Homburg            Saarland  192408
#
#          total_votes  invalid_second_votes  valid_second_votes  area_id  \
# area_id
# 1             171905                  1509              170396        1
# 3             132016                  1141              130875        3
# 4             157387                  1119              156268        4
# 5             151463                  1290              150173        5
# 6             131710                  1196              130514        6
# ...              ...                   ...                 ...      ...
# 295           139544                  1818              137726      295
# 296           147602                  2171              145431      296
# 297           160371                  2831              157540      297
# 298           141378                  2668              138710      298
# 299           145990                  2467              143523      299
#
#          check_valid
# area_id
# 1             170396
# 3             130875
# 4             156268
# 5             150173
# 6             130514
# ...              ...
# 295           137726
# 296           145431
# 297           157540
# 298           138710
# 299           143523
#
# [296 rows x 8 columns]

# %%
third_row = df.iloc[2]
third_row
# Out:
# area                    Rendsburg-Eckernförde
# state                      Schleswig-Holstein
# voters                                 199632
# total_votes                            157387
# invalid_second_votes                     1119
# valid_second_votes                     156268
# area_id                                     4
# check_valid                            156268
# Name: 4, dtype: object

# %% [markdown]
# **NB**: anche un oggetto `Series` che contiene una riga di un *data frame* può essere sottoposto a selezione di colonne (esattamente come per un *data frame*).

# %%
third_row['area']
# Out:
# 'Rendsburg-Eckernförde'

# %% [markdown]
# ### Selezionare righe contigue tramite `iloc[]`
#
# L'espressione:
#
#     df.iloc[start_pos_index:end_pos_index]
#
# restituisce tutte le righe dalla posizione di indice `start_pos_index` a quella di indice `end_pos_index-1`, in un oggetto di tipo `DataFrame`.
#
# ---
#
# L'espressione:
#
#     df.iloc[start_pos_index:end_pos_index] = new_value
#
# aggiorna tutti i valori delle righe restituite a sinistra con il nuovo valore `new_value`.
#
# ---
#
# **NB**: `iloc[start_pos_index:end_pos_index]` può essere invocato anche da un oggetto di tipo `Series` (riga o colonna).
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre la lista delle aree delle righe dalla ottava alla dodicesima.

# %%
rows = df.iloc[7:12]
rows
# Out:
#                                                       area  \
# area_id
# 10                      Herzogtum Lauenburg – Stormarn-Süd
# 11                                                  Lübeck
# 13       Ludwigslust-Parchim II – Nordwestmecklenburg I...
# 14                          Rostock – Landkreis Rostock II
# 15              Vorpommern-Rügen – Vorpommern-Greifswald I
#
#                           state  voters  total_votes  invalid_second_votes  \
# area_id
# 10           Schleswig-Holstein  244503       193359                  1388
# 11           Schleswig-Holstein  181637       130976                  1171
# 13       Mecklenburg-Vorpommern  205757       146781                  1673
# 14       Mecklenburg-Vorpommern  222718       164037                  1731
# 15       Mecklenburg-Vorpommern  240887       169526                  2115
#
#          valid_second_votes  area_id  check_valid
# area_id
# 10                   191971       10       191971
# 11                   129805       11       129805
# 13                   145108       13       145108
# 14                   162306       14       162306
# 15                   167411       15       167411

# %%
list(rows['area'])
# Out:
# ['Herzogtum Lauenburg – Stormarn-Süd',
#  'Lübeck',
#  'Ludwigslust-Parchim II – Nordwestmecklenburg II – Landkreis Rostock I',
#  'Rostock – Landkreis Rostock II',
#  'Vorpommern-Rügen – Vorpommern-Greifswald I']

# %% [markdown]
# ---
#
# ### Selezionare righe (anche non contigue) tramite `iloc[]`
#
# L'espressione:
#
#     df.iloc[pos_index_list]
#
# restituisce tutte le righe nelle posizioni indicate nella lista `pos_index_list`, in un oggetto di tipo `DataFrame`.
#
# ---
#
# L'espressione:
#
#     df.iloc[pos_index_list] = new_value
#
# aggiorna tutti i valori delle righe restituite a sinistra con il nuovo valore `new_value`.
#
# ---
#
# **NB**: `iloc[pos_index_list]` può essere invocato anche da un oggetto di tipo `Series` (riga o colonna).
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre i valori relativi alla colonna `area` per tutte l'ottava, la nona, la dodicesima e la quattordicesima riga.

# %%
rows = df.iloc[[7, 8, 11, 13]]
rows
# Out:
#                                                       area  \
# area_id
# 10                      Herzogtum Lauenburg – Stormarn-Süd
# 11                                                  Lübeck
# 15              Vorpommern-Rügen – Vorpommern-Greifswald I
# 17       Mecklenburgische Seenplatte II – Landkreis Ros...
#
#                           state  voters  total_votes  invalid_second_votes  \
# area_id
# 10           Schleswig-Holstein  244503       193359                  1388
# 11           Schleswig-Holstein  181637       130976                  1171
# 15       Mecklenburg-Vorpommern  240887       169526                  2115
# 17       Mecklenburg-Vorpommern  212051       144268                  1791
#
#          valid_second_votes  area_id  check_valid
# area_id
# 10                   191971       10       191971
# 11                   129805       11       129805
# 15                   167411       15       167411
# 17                   142477       17       142477

# %%
rows['area']
# Out:
# area_id
# 10                   Herzogtum Lauenburg – Stormarn-Süd
# 11                                               Lübeck
# 15           Vorpommern-Rügen – Vorpommern-Greifswald I
# 17    Mecklenburgische Seenplatte II – Landkreis Ros...
# Name: area, dtype: object

# %% [markdown]
# ### Selezionare una riga tramite `loc[]`
#
# L'espressione:
#
#         df.loc[index]
#
# restituisce la riga che ha indice `index`, in un oggetto `Series` (se non esiste, viene lanciato un `KeyError`).
#
# ---
#
# L'espressione:
#
#         df.loc[index] = new_value
#
# aggiorna tutti i valori della riga che ha indice `index` con il nuovo valore `new_value`.
#
# ---
#
# **NB**: `loc[index]` può essere invocato anche da un oggetto di tipo `Series` (riga o colonna).
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre lo stato della riga di indice `3`.

# %%
df
# Out:
#                                  area               state  voters  \
# area_id
# 1               Flensburg – Schleswig  Schleswig-Holstein  225659
# 3        Steinburg – Dithmarschen Süd  Schleswig-Holstein  175950
# 4               Rendsburg-Eckernförde  Schleswig-Holstein  199632
# 5                                Kiel  Schleswig-Holstein  204650
# 6                   Plön – Neumünster  Schleswig-Holstein  174934
# ...                               ...                 ...     ...
# 295          Zollernalb – Sigmaringen   Baden-Württemberg  183202
# 296                       Saarbrücken            Saarland  199887
# 297                         Saarlouis            Saarland  207500
# 298                        St. Wendel            Saarland  177468
# 299                           Homburg            Saarland  192408
#
#          total_votes  invalid_second_votes  valid_second_votes  area_id  \
# area_id
# 1             171905                  1509              170396        1
# 3             132016                  1141              130875        3
# 4             157387                  1119              156268        4
# 5             151463                  1290              150173        5
# 6             131710                  1196              130514        6
# ...              ...                   ...                 ...      ...
# 295           139544                  1818              137726      295
# 296           147602                  2171              145431      296
# 297           160371                  2831              157540      297
# 298           141378                  2668              138710      298
# 299           145990                  2467              143523      299
#
#          check_valid
# area_id
# 1             170396
# 3             130875
# 4             156268
# 5             150173
# 6             130514
# ...              ...
# 295           137726
# 296           145431
# 297           157540
# 298           138710
# 299           143523
#
# [296 rows x 8 columns]

# %%
df.loc[3]['state']
# Out:
# 'Schleswig-Holstein'

# %% [markdown]
# ### Selezionare righe (anche non contigue) tramite `loc[]`
#
# L'espressione:
#
#     df.loc[index_list]
#
# restituisce tutte le righe che hanno gli indici presenti nella lista `index_list`, in un oggetto di tipo `DataFrame`.
#
# ---
#
# L'espressione:
#
#     df.loc[index_list] = new_value
#
# aggiorna tutti i valori delle righe che hanno indice in `index_list` con il nuovo valore `new_value`.
#
# ---
#
# **NB**: `loc[index_list]` può essere invocato anche da un oggetto di tipo `Series` (riga o colonna).
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre le righe di indice `3`, `8` e `10`.

# %%
df.loc[[5,8,10]]
# Out:
#                                        area               state  voters  \
# area_id
# 5                                      Kiel  Schleswig-Holstein  204650
# 8                 Segeberg – Stormarn-Mitte  Schleswig-Holstein  245826
# 10       Herzogtum Lauenburg – Stormarn-Süd  Schleswig-Holstein  244503
#
#          total_votes  invalid_second_votes  valid_second_votes  area_id  \
# area_id
# 5             151463                  1290              150173        5
# 8             193318                  1381              191937        8
# 10            193359                  1388              191971       10
#
#          check_valid
# area_id
# 5             150173
# 8             191937
# 10            191971

# %% [markdown]
# ### Selezionare le righe che rispettano una condizione tramite `loc[]`
#
# L'espressione:
#
#         df.loc[mask]
#
# restituisce le righe che verificano la condizione rappresentata da `mask`.
#
# ---
#
# L'espressione:
#
#         df.loc[mask] = new_value
#
# aggiorna tutti i valori delle righe che verificano la condizione rappresentata da `mask` con il nuovo valore `new_value`.
#
# ---
#
# **NB**: `loc[mask]` può essere invocato anche da un oggetto di tipo `Series` (riga o colonna).
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre le righe corrispondenti a `Berlin` nella colonna `state`.

# %%
mask = df['state'] == 'Berlin'

df.loc[mask]
# Out:
#                                                       area   state  voters  \
# area_id
# 75                                            Berlin-Mitte  Berlin  206706
# 76                                           Berlin-Pankow  Berlin  237071
# 77                                    Berlin-Reinickendorf  Berlin  182392
# 78                    Berlin-Spandau – Charlottenburg Nord  Berlin  184602
# 79                              Berlin-Steglitz-Zehlendorf  Berlin  221209
# 80                       Berlin-Charlottenburg-Wilmersdorf  Berlin  198672
# 81                             Berlin-Tempelhof-Schöneberg  Berlin  235250
# 82                                         Berlin-Neukölln  Berlin  202616
# 83       Berlin-Friedrichshain-Kreuzberg – Prenzlauer B...  Berlin  223426
# 84                                 Berlin-Treptow-Köpenick  Berlin  205105
# 85                              Berlin-Marzahn-Hellersdorf  Berlin  200704
# 86                                      Berlin-Lichtenberg  Berlin  205300
#
#          total_votes  invalid_second_votes  valid_second_votes  area_id  \
# area_id
# 75            151634                  2214              149420       75
# 76            188607                  2198              186409       76
# 77            137084                  2171              134913       77
# 78            132934                  2276              130658       78
# 79            180827                  2110              178717       79
# 80            158245                  1429              156816       80
# 81            181259                  2162              179097       81
# 82            143790                  2980              140810       82
# 83            173504                  1664              171840       83
# 84            157461                  2124              155337       84
# 85            138988                  2064              136924       85
# 86            149053                  2153              146900       86
#
#          check_valid
# area_id
# 75            149420
# 76            186409
# 77            134913
# 78            130658
# 79            178717
# 80            156816
# 81            179097
# 82            140810
# 83            171840
# 84            155337
# 85            136924
# 86            146900

# %% [markdown]
# ### Selezionare una colonna di una riga tramite `loc[]`
#
# L'espressione:
#
#     df.loc[index, column_name]
#
# restituisce il valore della riga che ha indice `index` relativo alla colonna `column_name`.
#
# ---
#
# L'espressione:
#
#     df.loc[index, column_name] = new_value
#
# aggiorna il valore della riga che ha indice `index` relativo alla colonna `column_name` con il nuovo valore `new_value`.
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre il valore relativo alla colonna `state` della riga di indice `5` e aggiornarlo con la stringa `unknown`.

# %%
df.loc[[5]]
# Out:
#          area               state  voters  total_votes  invalid_second_votes  \
# area_id
# 5        Kiel  Schleswig-Holstein  204650       151463                  1290
#
#          valid_second_votes  area_id  check_valid
# area_id
# 5                    150173        5       150173

# %%
df.loc[5, 'state'] = 'unknown'

# %%
df.loc[[5]]
# Out:
#          area    state  voters  total_votes  invalid_second_votes  \
# area_id
# 5        Kiel  unknown  204650       151463                  1290
#
#          valid_second_votes  area_id  check_valid
# area_id
# 5                    150173        5       150173

# %% [markdown]
# ### Selezionare una colonna per più righe tramite `loc[]`
#
# L'espressione:
#
#     df.loc[index_list, column_name]
#
# restituisce i valori delle righe che hanno indici nella lista `index_list` relativi alla colonna `column_name`, in un oggetto di tipo `Series`.
#
# ---
#
# L'espressione:
#
#     df.loc[index_list, column_name] = new_value
#
# aggiorna i valori delle righe che hanno indici nella lista `index_list` relativi alla colonna `column_name`, con il nuovo valore .`new_value`.
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre i valori relativi alla colonna `state` delle righe di indici `5`, `10` e `11` e aggiornarli con la stringa `unknown`.

# %%
df.loc[[5,10,11]]
# Out:
#                                        area               state  voters  \
# area_id
# 5                                      Kiel             unknown  204650
# 10       Herzogtum Lauenburg – Stormarn-Süd  Schleswig-Holstein  244503
# 11                                   Lübeck  Schleswig-Holstein  181637
#
#          total_votes  invalid_second_votes  valid_second_votes  area_id  \
# area_id
# 5             151463                  1290              150173        5
# 10            193359                  1388              191971       10
# 11            130976                  1171              129805       11
#
#          check_valid
# area_id
# 5             150173
# 10            191971
# 11            129805

# %%
df.loc[[5,10,11], 'state']
# Out:
# area_id
# 5                unknown
# 10    Schleswig-Holstein
# 11    Schleswig-Holstein
# Name: state, dtype: object

# %%
df.loc[[5,10,11], 'state'] = 'unknown'

# %%
df.loc[[5,10,11]]
# Out:
#                                        area    state  voters  total_votes  \
# area_id
# 5                                      Kiel  unknown  204650       151463
# 10       Herzogtum Lauenburg – Stormarn-Süd  unknown  244503       193359
# 11                                   Lübeck  unknown  181637       130976
#
#          invalid_second_votes  valid_second_votes  area_id  check_valid
# area_id
# 5                        1290              150173        5       150173
# 10                       1388              191971       10       191971
# 11                       1171              129805       11       129805

# %% [markdown]
# ---
#
# **ESERCIZIO**: aggiornare a 0 tutti i valori relativi della colonna `invalid_second_votes` che sono inferiori a 200.

# %%
mask = df['invalid_second_votes'] < 1000

df.loc[df[mask].index, 'invalid_second_votes'] = 0

# %%
df[mask]
# Out:
#                                        area                state  voters  \
# area_id
# 19                           Hamburg-Altona              Hamburg  185942
# 20                       Hamburg-Eimsbüttel              Hamburg  192399
# 21                             Hamburg-Nord              Hamburg  217226
# 30                   Stade I – Rotenburg II        Niedersachsen  197298
# 31                                Mittelems        Niedersachsen  230151
# 35                 Rotenburg I – Heidekreis        Niedersachsen  168081
# 36                                  Harburg        Niedersachsen  199081
# 37             Lüchow-Dannenberg – Lüneburg        Niedersachsen  180866
# 39                          Stadt Osnabrück        Niedersachsen  196475
# 41                         Stadt Hannover I        Niedersachsen  179883
# 42                        Stadt Hannover II        Niedersachsen  193433
# 87                                 Aachen I  Nordrhein-Westfalen  179273
# 94                                  Köln II  Nordrhein-Westfalen  240982
# 120                               Essen III  Nordrhein-Westfalen  192918
# 127                 Coesfeld – Steinfurt II  Nordrhein-Westfalen  192946
# 212                               Altötting               Bayern  168222
# 213                      Erding – Ebersberg               Bayern  206077
# 215                        Fürstenfeldbruck               Bayern  231971
# 217                            München-Nord               Bayern  226436
# 218                             München-Ost               Bayern  239169
# 219                             München-Süd               Bayern  216725
# 220                      München-West/Mitte               Bayern  241282
# 221                            München-Land               Bayern  233872
# 223      Bad Tölz-Wolfratshausen – Miesbach               Bayern  165228
# 224           Starnberg – Landsberg am Lech               Bayern  213619
# 226                                Weilheim               Bayern  166804
# 227                              Deggendorf               Bayern  166659
# 229                                  Passau               Bayern  176849
# 230                              Rottal-Inn               Bayern  168564
# 236                                 Bamberg               Bayern  181535
# 237                                Bayreuth               Bayern  163610
# 242                                Erlangen               Bayern  180176
# 244                           Nürnberg-Nord               Bayern  192214
# 258                             Stuttgart I    Baden-Württemberg  194368
#
#          total_votes  invalid_second_votes  valid_second_votes  area_id  \
# area_id
# 19            146025                     0              145076       19
# 20            156001                     0              155141       20
# 21            178302                     0              177403       21
# 30            152485                     0              151639       30
# 31            179790                     0              178827       31
# 35            127071                     0              126097       35
# 36            161838                     0              160858       36
# 37            141000                     0              140138       37
# 39            151988                     0              151006       39
# 41            134842                     0              133867       41
# 42            149030                     0              148090       42
# 87            140628                     0              139784       87
# 94            197979                     0              197078       94
# 120           153336                     0              152409      120
# 127           156811                     0              155826      127
# 212           126774                     0              125909      212
# 213           163366                     0              162608      213
# 215           190809                     0              189842      215
# 217           173781                     0              173092      217
# 218           186882                     0              186047      218
# 219           170440                     0              169770      219
# 220           193426                     0              192595      220
# 221           197288                     0              196362      221
# 223           132621                     0              131817      223
# 224           177007                     0              176259      224
# 226           134339                     0              133560      226
# 227           119459                     0              118755      227
# 229           131355                     0              130571      229
# 230           124323                     0              123504      230
# 236           145235                     0              144418      236
# 237           127225                     0              126522      237
# 242           148057                     0              147370      242
# 244           146205                     0              145304      244
# 258           160832                     0              159974      258
#
#          check_valid
# area_id
# 19            145076
# 20            155141
# 21            177403
# 30            151639
# 31            178827
# 35            126097
# 36            160858
# 37            140138
# 39            151006
# 41            133867
# 42            148090
# 87            139784
# 94            197078
# 120           152409
# 127           155826
# 212           125909
# 213           162608
# 215           189842
# 217           173092
# 218           186047
# 219           169770
# 220           192595
# 221           196362
# 223           131817
# 224           176259
# 226           133560
# 227           118755
# 229           130571
# 230           123504
# 236           144418
# 237           126522
# 242           147370
# 244           145304
# 258           159974

# %% [markdown]
# ### Selezionare più colonne per più righe tramite `loc[]`
#
# L'espressione:
#
#         df.loc[index_list, column_list]
#
# restituisce i valori delle righe che hanno indici nella lista `index_list` relativi alle colonne presenti nella lista `column_list`, in un oggetto di tipo `DataFrame`.
#
# ---
#
# L'espressione:
#
#     df.loc[index_list, column_list] = new_value
#
# aggiorna i valori delle righe che hanno indici nella lista `index_list` relativi alle colonne nella lista `column_list`, con il nuovo valore .`new_value`.
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre i valori relativi alle colonne `area` e `state` per le righe di indice `100`, `150` e `200`.

# %%
df.loc[[100,150,200], ['area', 'state']]
# Out:
#                                area                state
# area_id
# 100      Rheinisch-Bergischer Kreis  Nordrhein-Westfalen
# 150             Märkischer Kreis II  Nordrhein-Westfalen
# 200            Mosel/Rhein-Hunsrück      Rheinland-Pfalz

# %% [markdown]
# ### Ottenere un valore tramite `at[]`
#
# L'espressione:
#
#     df.at[index, column_name]
#
# restituisce il valore della riga con indice `index` in corrispondenza della colonna `column_name`.
#
# ---
#
# L'espressione:
#
#     df.at[index, column_name] = new_value
#
# aggiorna il valore della riga con indice `index` in corrispondenza della colonna `column_name` con il nuovo valore `new_value`.
#
# ---

# %% [markdown]
# **ESEMPIO**:

# %%
df.at[11, 'area']
# Out:
# 'Lübeck'

# %% [markdown]
# ### Controllare la presenza di valori nulli
#
# La funzione:
#
#     pd.isnull(df|column)
#
# prende come argomento un *data frame* oppure una colonna e restituisce un oggetto `DataFrame` o `Series` contenente valori booleani.
#
# ---
#
# Il metodo:
#
#     df|column.isnull()
#
# viene invocato su un *data frame* oppure su una colonna e restituisce un oggetto `DataFrame` o `Series` contenente valori booleani.
#
# ---

# %%
column = df.state
column.isnull()
# Out:
# area_id
# 1      False
# 3      False
# 4      False
# 5      False
# 6      False
#        ...
# 295    False
# 296    False
# 297    False
# 298    False
# 299    False
# Name: state, Length: 296, dtype: bool

# %%
pd.isnull(df)
# Out:
#           area  state  voters  total_votes  invalid_second_votes  \
# area_id
# 1        False  False   False        False                 False
# 3        False  False   False        False                 False
# 4        False  False   False        False                 False
# 5        False  False   False        False                 False
# 6        False  False   False        False                 False
# ...        ...    ...     ...          ...                   ...
# 295      False  False   False        False                 False
# 296      False  False   False        False                 False
# 297      False  False   False        False                 False
# 298      False  False   False        False                 False
# 299      False  False   False        False                 False
#
#          valid_second_votes  area_id  check_valid
# area_id
# 1                     False    False        False
# 3                     False    False        False
# 4                     False    False        False
# 5                     False    False        False
# 6                     False    False        False
# ...                     ...      ...          ...
# 295                   False    False        False
# 296                   False    False        False
# 297                   False    False        False
# 298                   False    False        False
# 299                   False    False        False
#
# [296 rows x 8 columns]

# %% [markdown]
# ### Ottenere valori unici con il metodo  `unique()`
#
# Il metodo `unique()` degli oggetti `Series` restituisce l'array dei valori distinti presenti nell'oggetto invocante.
#
# ---
#
# **ESERCIZIO**: determinare la lista dei valori unici della colonna `state`.

# %%
list(df.state.unique())
# Out:
# ['Schleswig-Holstein',
#  'unknown',
#  'Mecklenburg-Vorpommern',
#  'Hamburg',
#  'Niedersachsen',
#  'Bremen',
#  'Brandenburg',
#  'Sachsen-Anhalt',
#  'Berlin',
#  'Nordrhein-Westfalen',
#  'Sachsen',
#  'Hessen',
#  'Thüringen',
#  'Rheinland-Pfalz',
#  'Bayern',
#  'Baden-Württemberg',
#  'Saarland']

# %% [markdown]
# ### Ottenere statistiche generali
#
#
# Gli oggetti `DataFrame` e `Series` dispongono del metodo `describe()` per ottenere statistiche generali su *data frame* e colonne.

# %%
df.describe()
# Out:
#              voters    total_votes  invalid_second_votes  valid_second_votes  \
# count     296.00000     296.000000            296.000000          296.000000
# mean   206388.25000  157226.736486           1466.165541       155662.489865
# std     23293.88437   20088.410473            684.318255        20065.507057
# min    159613.00000  103815.000000              0.000000       101888.000000
# 25%    189365.00000  142595.250000           1186.750000       140803.500000
# 50%    206105.00000  156092.000000           1468.000000       154511.500000
# 75%    223304.50000  172304.500000           1939.750000       170397.250000
# max    254300.00000  202546.000000           3311.000000       200879.000000
#
#           area_id    check_valid
# count  296.000000     296.000000
# mean   151.442568  155662.489865
# std     85.689725   20065.507057
# min      1.000000  101888.000000
# 25%     77.750000  140803.500000
# 50%    151.500000  154511.500000
# 75%    225.250000  170397.250000
# max    299.000000  200879.000000

# %%
df.total_votes.describe()
# Out:
# count       296.000000
# mean     157226.736486
# std       20088.410473
# min      103815.000000
# 25%      142595.250000
# 50%      156092.000000
# 75%      172304.500000
# max      202546.000000
# Name: total_votes, dtype: float64

# %%
df.state.describe()
# Out:
# count                     296
# unique                     17
# top       Nordrhein-Westfalen
# freq                       64
# Name: state, dtype: object

# %% [markdown]
# ### Alcuni metodi...
#
# Gli oggetti `DataFrame` e `Series` dispongono di metodi come `max()`, `min()`, `count()`, `var()`, `std()`, `mean()`, `sum()`.
#
# ---
#
# **ESEMPI**:

# %%
df[['voters', 'total_votes']].mean()
# Out:
# voters         206388.250000
# total_votes    157226.736486
# dtype: float64

# %%
df.total_votes.mean()
# Out:
# 157226.73648648648

# %% [markdown]
# I *data frame* hanno inoltre il metodo `corr()` per calcolare la matrice di covarianza.

# %%
df[['invalid_second_votes', 'total_votes']].corr()
# Out:
#                       invalid_second_votes  total_votes
# invalid_second_votes              1.000000     0.054448
# total_votes                       0.054448     1.000000

# %% [markdown]
# ### Ordinare valori
#
# Il metodo `sort_values()`:
#
#     df.sort_values(column_list, ascending = True|False, inplace = True|False)
#
# ordina le righe secondo le colonne specificate in nella lista `column_list` in senso ascendente o discendente.
#
# `inplace = True` significa che il *data frame* invocante viene aggiornato, mentre per `inplace = False` viene restituita una copia aggiornata.
#
# **NB**: al posto di `column_list` si puo anche mettere un solo nome di colonna.
#
# ---

# %% [markdown]
# **ESERCIZIO**: ordinare le righe per colonne `state` e `area` in ordine ascendente (senza aggiornare il *data frame* invocante).

# %%
df.sort_values(['state', 'area'], ascending = True)
# Out:
#                                                       area              state  \
# area_id
# 270                                     Aalen – Heidenheim  Baden-Württemberg
# 269                            Backnang – Schwäbisch Gmünd  Baden-Württemberg
# 292                                               Biberach  Baden-Württemberg
# 293                                               Bodensee  Baden-Württemberg
# 278                                Bruchsal – Schwetzingen  Baden-Württemberg
# ...                                                    ...                ...
# 195      Saalfeld-Rudolstadt – Saale-Holzland-Kreis – S...          Thüringen
# 196      Suhl – Schmalkalden-Meiningen – Hildburghausen...          Thüringen
# 10                      Herzogtum Lauenburg – Stormarn-Süd            unknown
# 5                                                     Kiel            unknown
# 11                                                  Lübeck            unknown
#
#          voters  total_votes  invalid_second_votes  valid_second_votes  \
# area_id
# 270      221916       170201                  1991              168210
# 269      176967       136725                  1421              135304
# 292      167025       131713                  1441              130272
# 293      172783       137152                  1218              135934
# 278      196426       154621                  1927              152694
# ...         ...          ...                   ...                 ...
# 195      229126       171882                  2166              169716
# 196      234445       170165                  2158              168007
# 10       244503       193359                  1388              191971
# 5        204650       151463                  1290              150173
# 11       181637       130976                  1171              129805
#
#          area_id  check_valid
# area_id
# 270          270       168210
# 269          269       135304
# 292          292       130272
# 293          293       135934
# 278          278       152694
# ...          ...          ...
# 195          195       169716
# 196          196       168007
# 10            10       191971
# 5              5       150173
# 11            11       129805
#
# [296 rows x 8 columns]

# %% [markdown]
# ---
#
# **ESERCIZIO**: ordinare le righe per numero di voti totali in ordine discendente (senza aggiornare il *data frame* invocante).

# %%
df.sort_values('total_votes', ascending = False)
# Out:
#                   area                state  voters  total_votes  \
# area_id
# 205              Mainz      Rheinland-Pfalz  248996       202546
# 253      Augsburg-Land               Bayern  248196       199076
# 233         Regensburg               Bayern  252910       198800
# 243              Fürth               Bayern  254300       198764
# 94             Köln II  Nordrhein-Westfalen  240982       197979
# ...                ...                  ...     ...          ...
# 123      Gelsenkirchen  Nordrhein-Westfalen  175210       119414
# 151        Nordsachsen              Sachsen  163765       118176
# 66             Altmark       Sachsen-Anhalt  165625       111201
# 119           Essen II  Nordrhein-Westfalen  163326       110369
# 116        Duisburg II  Nordrhein-Westfalen  160204       103815
#
#          invalid_second_votes  valid_second_votes  area_id  check_valid
# area_id
# 205                      1667              200879      205       200879
# 253                      1238              197838      253       197838
# 233                      1137              197663      233       197663
# 243                      1421              197343      243       197343
# 94                          0              197078       94       197078
# ...                       ...                 ...      ...          ...
# 123                      1348              118066      123       118066
# 151                      1620              116556      151       116556
# 66                       1337              109864       66       109864
# 119                      1154              109215      119       109215
# 116                      1927              101888      116       101888
#
# [296 rows x 8 columns]

# %% [markdown]
# ### Raggruppare i valori
#
# Il metodo `groupby()`:
#
#     df.groupby(column_list)
#
# restituisce un oggetto `DataFrameGroupBy` che raggruppa i valori secondo le colonne specificate nella lista `column_list`, a cui può essere applicata un'operazione.
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre il numero di votanti totali per "stato".

# %%
df.groupby('state')['voters'].sum()
# Out:
# state
# Baden-Württemberg          7732570
# Bayern                     9519914
# Berlin                     2503053
# Brandenburg                2051507
# Bremen                      474097
# Hamburg                    1296624
# Hessen                     4409241
# Mecklenburg-Vorpommern     1107256
# Niedersachsen              6124125
# Nordrhein-Westfalen       13174480
# Rheinland-Pfalz            3081062
# Saarland                    777263
# Sachsen                    3328669
# Sachsen-Anhalt             1854982
# Schleswig-Holstein         1259475
# Thüringen                  1765814
# unknown                     630790
# Name: voters, dtype: int64

# %% [markdown]
# ---
#
# **ESERCIZIO**: visualizzare il numero dei votanti per ogni area raggruppandole per "stato".

# %%
df.groupby(['state', 'area'])['voters']

# %%
df.groupby(['state', 'area'])['voters'].sum()
# Out:
# state              area
# Baden-Württemberg  Aalen – Heidenheim                                               221916
#                    Backnang – Schwäbisch Gmünd                                      176967
#                    Biberach                                                         167025
#                    Bodensee                                                         172783
#                    Bruchsal – Schwetzingen                                          196426
#                                                                                      ...
# Thüringen          Saalfeld-Rudolstadt – Saale-Holzland-Kreis – Saale-Orla-Kreis    229126
#                    Suhl – Schmalkalden-Meiningen – Hildburghausen – Sonneberg       234445
# unknown            Herzogtum Lauenburg – Stormarn-Süd                               244503
#                    Kiel                                                             204650
#                    Lübeck                                                           181637
# Name: voters, Length: 296, dtype: int64

# %% [markdown]
# ### Applicare una funzione a un *data frame* con il metodo `apply()`
#
# Il metodo:
#
#         df.apply(function)
#
# applica la funzione `function` a tutti i valori del *data frame* invocante e restituisce un *data frame* con la stessa struttura che contiene i valori restituiti dalla funzione.
#
# **NB**: `apply()` è un metodo anche degli oggetti `Series`.
#
# ---

# %% [markdown]
# **ESERCIZIO**: estrarre il *data frame* del numero totale dei votanti e dei voti totali decrementati di 1000 unità.

# %%
df[['voters', 'total_votes']].apply(lambda x: x-1000)
# Out:
#          voters  total_votes
# area_id
# 1        224659       170905
# 3        174950       131016
# 4        198632       156387
# 5        203650       150463
# 6        173934       130710
# ...         ...          ...
# 295      182202       138544
# 296      198887       146602
# 297      206500       159371
# 298      176468       140378
# 299      191408       144990
#
# [296 rows x 2 columns]

# %% [markdown]
# ---
#
# **ESERCIZIO**: estrarre la colonna del numero totale dei votanti convertito in numero decimale.

# %%
df['voters'].apply(lambda x: float(x))
# Out:
# area_id
# 1      225659.0
# 3      175950.0
# 4      199632.0
# 5      204650.0
# 6      174934.0
#          ...
# 295    183202.0
# 296    199887.0
# 297    207500.0
# 298    177468.0
# 299    192408.0
# Name: voters, Length: 296, dtype: float64

# %% [markdown]
# ### Iterare lungo le righe di un *data frame*
#
# Il metodo `iterrows()` permette di iterare lungo le righe di un *data frame*.
#
#     for (index, record) in df.iterrows():
#         block

# %%
for (index, record) in df.iterrows():
        print(str(index) + ' ' + record['state'])
# Out:
# 1 Schleswig-Holstein
# 3 Schleswig-Holstein
# 4 Schleswig-Holstein
# 5 unknown
# 6 Schleswig-Holstein
# 7 Schleswig-Holstein
# 8 Schleswig-Holstein
# 10 unknown
# 11 unknown
# 13 Mecklenburg-Vorpommern
# 14 Mecklenburg-Vorpommern
# 15 Mecklenburg-Vorpommern
# 16 Mecklenburg-Vorpommern
# 17 Mecklenburg-Vorpommern
# 18 Hamburg
# 19 Hamburg
# 20 Hamburg
# 21 Hamburg
# 22 Hamburg
# 23 Hamburg
# 24 Niedersachsen
# 25 Niedersachsen
# 26 Niedersachsen
# 27 Niedersachsen
# 28 Niedersachsen
# 29 Niedersachsen
# 30 Niedersachsen
# 31 Niedersachsen
# 32 Niedersachsen
# 33 Niedersachsen
# 34 Niedersachsen
# 35 Niedersachsen
# 36 Niedersachsen
# 37 Niedersachsen
# 38 Niedersachsen
# 39 Niedersachsen
# 40 Niedersachsen
# 41 Niedersachsen
# 42 Niedersachsen
# 43 Niedersachsen
# 44 Niedersachsen
# 45 Niedersachsen
# 46 Niedersachsen
# 47 Niedersachsen
# 48 Niedersachsen
# 49 Niedersachsen
# 50 Niedersachsen
# 51 Niedersachsen
# 52 Niedersachsen
# 53 Niedersachsen
# 54 Bremen
# 55 Bremen
# 56 Brandenburg
# 57 Brandenburg
# 58 Brandenburg
# 59 Brandenburg
# 60 Brandenburg
# 61 Brandenburg
# 62 Brandenburg
# 63 Brandenburg
# 64 Brandenburg
# 65 Brandenburg
# 66 Sachsen-Anhalt
# 67 Sachsen-Anhalt
# 68 Sachsen-Anhalt
# 69 Sachsen-Anhalt
# 70 Sachsen-Anhalt
# 71 Sachsen-Anhalt
# 72 Sachsen-Anhalt
# 73 Sachsen-Anhalt
# 74 Sachsen-Anhalt
# 75 Berlin
# 76 Berlin
# 77 Berlin
# 78 Berlin
# 79 Berlin
# 80 Berlin
# 81 Berlin
# 82 Berlin
# 83 Berlin
# 84 Berlin
# 85 Berlin
# 86 Berlin
# 87 Nordrhein-Westfalen
# 88 Nordrhein-Westfalen
# 89 Nordrhein-Westfalen
# 90 Nordrhein-Westfalen
# 91 Nordrhein-Westfalen
# 92 Nordrhein-Westfalen
# 93 Nordrhein-Westfalen
# 94 Nordrhein-Westfalen
# 95 Nordrhein-Westfalen
# 96 Nordrhein-Westfalen
# 97 Nordrhein-Westfalen
# 98 Nordrhein-Westfalen
# 99 Nordrhein-Westfalen
# 100 Nordrhein-Westfalen
# 101 Nordrhein-Westfalen
# 102 Nordrhein-Westfalen
# 103 Nordrhein-Westfalen
# 104 Nordrhein-Westfalen
# 105 Nordrhein-Westfalen
# 106 Nordrhein-Westfalen
# 107 Nordrhein-Westfalen
# 108 Nordrhein-Westfalen
# 109 Nordrhein-Westfalen
# 110 Nordrhein-Westfalen
# 111 Nordrhein-Westfalen
# 112 Nordrhein-Westfalen
# 113 Nordrhein-Westfalen
# 114 Nordrhein-Westfalen
# 115 Nordrhein-Westfalen
# 116 Nordrhein-Westfalen
# 117 Nordrhein-Westfalen
# 118 Nordrhein-Westfalen
# 119 Nordrhein-Westfalen
# 120 Nordrhein-Westfalen
# 121 Nordrhein-Westfalen
# 122 Nordrhein-Westfalen
# 123 Nordrhein-Westfalen
# 124 Nordrhein-Westfalen
# 125 Nordrhein-Westfalen
# 126 Nordrhein-Westfalen
# 127 Nordrhein-Westfalen
# 128 Nordrhein-Westfalen
# 129 Nordrhein-Westfalen
# 130 Nordrhein-Westfalen
# 131 Nordrhein-Westfalen
# 132 Nordrhein-Westfalen
# 133 Nordrhein-Westfalen
# 134 Nordrhein-Westfalen
# 135 Nordrhein-Westfalen
# 136 Nordrhein-Westfalen
# 137 Nordrhein-Westfalen
# 138 Nordrhein-Westfalen
# 139 Nordrhein-Westfalen
# 140 Nordrhein-Westfalen
# 141 Nordrhein-Westfalen
# 142 Nordrhein-Westfalen
# 143 Nordrhein-Westfalen
# 144 Nordrhein-Westfalen
# 145 Nordrhein-Westfalen
# 146 Nordrhein-Westfalen
# 147 Nordrhein-Westfalen
# 148 Nordrhein-Westfalen
# 149 Nordrhein-Westfalen
# 150 Nordrhein-Westfalen
# 151 Sachsen
# 152 Sachsen
# 153 Sachsen
# 154 Sachsen
# 155 Sachsen
# 156 Sachsen
# 157 Sachsen
# 158 Sachsen
# 159 Sachsen
# 160 Sachsen
# 161 Sachsen
# 162 Sachsen
# 163 Sachsen
# 164 Sachsen
# 165 Sachsen
# 166 Sachsen
# 167 Hessen
# 168 Hessen
# 169 Hessen
# 170 Hessen
# 171 Hessen
# 172 Hessen
# 173 Hessen
# 174 Hessen
# 175 Hessen
# 176 Hessen
# 177 Hessen
# 178 Hessen
# 179 Hessen
# 180 Hessen
# 181 Hessen
# 182 Hessen
# 183 Hessen
# 184 Hessen
# 185 Hessen
# 186 Hessen
# 187 Hessen
# 188 Hessen
# 189 Thüringen
# 190 Thüringen
# 191 Thüringen
# 192 Thüringen
# 193 Thüringen
# 194 Thüringen
# 195 Thüringen
# 196 Thüringen
# 197 Rheinland-Pfalz
# 198 Rheinland-Pfalz
# 199 Rheinland-Pfalz
# 200 Rheinland-Pfalz
# 201 Rheinland-Pfalz
# 202 Rheinland-Pfalz
# 203 Rheinland-Pfalz
# 204 Rheinland-Pfalz
# 205 Rheinland-Pfalz
# 206 Rheinland-Pfalz
# 207 Rheinland-Pfalz
# 208 Rheinland-Pfalz
# 209 Rheinland-Pfalz
# 210 Rheinland-Pfalz
# 211 Rheinland-Pfalz
# 212 Bayern
# 213 Bayern
# 214 Bayern
# 215 Bayern
# 216 Bayern
# 217 Bayern
# 218 Bayern
# 219 Bayern
# 220 Bayern
# 221 Bayern
# 222 Bayern
# 223 Bayern
# 224 Bayern
# 225 Bayern
# 226 Bayern
# 227 Bayern
# 228 Bayern
# 229 Bayern
# 230 Bayern
# 231 Bayern
# 232 Bayern
# 233 Bayern
# 234 Bayern
# 235 Bayern
# 236 Bayern
# 237 Bayern
# 238 Bayern
# 239 Bayern
# 240 Bayern
# 241 Bayern
# 242 Bayern
# 243 Bayern
# 244 Bayern
# 245 Bayern
# 246 Bayern
# 247 Bayern
# 248 Bayern
# 249 Bayern
# 250 Bayern
# 251 Bayern
# 252 Bayern
# 253 Bayern
# 254 Bayern
# 255 Bayern
# 256 Bayern
# 257 Bayern
# 258 Baden-Württemberg
# 259 Baden-Württemberg
# 260 Baden-Württemberg
# 261 Baden-Württemberg
# 262 Baden-Württemberg
# 263 Baden-Württemberg
# 264 Baden-Württemberg
# 265 Baden-Württemberg
# 266 Baden-Württemberg
# 267 Baden-Württemberg
# 268 Baden-Württemberg
# 269 Baden-Württemberg
# 270 Baden-Württemberg
# 271 Baden-Württemberg
# 272 Baden-Württemberg
# 273 Baden-Württemberg
# 274 Baden-Württemberg
# 275 Baden-Württemberg
# 276 Baden-Württemberg
# 277 Baden-Württemberg
# 278 Baden-Württemberg
# 279 Baden-Württemberg
# 280 Baden-Württemberg
# 281 Baden-Württemberg
# 282 Baden-Württemberg
# 283 Baden-Württemberg
# 284 Baden-Württemberg
# 285 Baden-Württemberg
# 286 Baden-Württemberg
# 287 Baden-Württemberg
# 288 Baden-Württemberg
# 289 Baden-Württemberg
# 290 Baden-Württemberg
# 291 Baden-Württemberg
# 292 Baden-Württemberg
# 293 Baden-Württemberg
# 294 Baden-Württemberg
# 295 Baden-Württemberg
# 296 Saarland
# 297 Saarland
# 298 Saarland
# 299 Saarland

# %% [markdown]
# ### Salvare un *data frame* in formato `csv`
#
# Il metodo `to_csv`
#
#         df.to_csv(file_name, index=False|True)
#
# scrive il *data frame* in formato `csv` in un  file.
#
# Se la keyword `index` è `True`, gli indici delle righe vengono prodotti in output e il relativo nome di campo è la stringa vuota.
#
# ---

# %%
df.to_csv('./output.csv', index = True)

# %% [markdown]
# ### Richiamare `matplotlib` da Pandas

# %%
df.voters.plot(label="Voters", legend=True)
# Out:
# <AxesSubplot:xlabel='area_id'>

# %% [markdown]
# ### Cambiare indice al *data frame*
#
# Il metodo:
#
#     df.set_index(column_name, inplace = True|False)
#
# assegna la colonna `column_name` (che non deve contenere duplicati) come colonna degli indici (chiavi primarie).

# %%
df = pd.read_csv("./2017-german-election-overall.csv")
df
# Out:
#      area_id                         area_names               state  \
# 0          1              Flensburg – Schleswig  Schleswig-Holstein
# 1          2  Nordfriesland – Dithmarschen Nord  Schleswig-Holstein
# 2          3       Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 3          4              Rendsburg-Eckernförde  Schleswig-Holstein
# 4          5                               Kiel  Schleswig-Holstein
# ..       ...                                ...                 ...
# 294      295           Zollernalb – Sigmaringen   Baden-Württemberg
# 295      296                        Saarbrücken            Saarland
# 296      297                          Saarlouis            Saarland
# 297      298                         St. Wendel            Saarland
# 298      299                            Homburg            Saarland
#
#      registered.voters  total_votes  invalid_first_votes  \
# 0               225659       171905                 1647
# 1               186384       139200                 1299
# 2               175950       132016                 1133
# 3               199632       157387                 1285
# 4               204650       151463                 1657
# ..                 ...          ...                  ...
# 294             183202       139544                 2354
# 295             199887       147602                 2304
# 296             207500       160371                 2422
# 297             177468       141378                 2620
# 298             192408       145990                 2668
#
#      invalid_second_votes  valid_first_votes  valid_second_votes
# 0                    1509             170258              170396
# 1                    1125             137901              138075
# 2                    1141             130883              130875
# 3                    1119             156102              156268
# 4                    1290             149806              150173
# ..                    ...                ...                 ...
# 294                  1818             137190              137726
# 295                  2171             145298              145431
# 296                  2831             157949              157540
# 297                  2668             138758              138710
# 298                  2467             143322              143523
#
# [299 rows x 9 columns]

# %%
df.set_index('area_id', inplace = True)

# %%
df
# Out:
#                                 area_names               state  \
# area_id
# 1                    Flensburg – Schleswig  Schleswig-Holstein
# 2        Nordfriesland – Dithmarschen Nord  Schleswig-Holstein
# 3             Steinburg – Dithmarschen Süd  Schleswig-Holstein
# 4                    Rendsburg-Eckernförde  Schleswig-Holstein
# 5                                     Kiel  Schleswig-Holstein
# ...                                    ...                 ...
# 295               Zollernalb – Sigmaringen   Baden-Württemberg
# 296                            Saarbrücken            Saarland
# 297                              Saarlouis            Saarland
# 298                             St. Wendel            Saarland
# 299                                Homburg            Saarland
#
#          registered.voters  total_votes  invalid_first_votes  \
# area_id
# 1                   225659       171905                 1647
# 2                   186384       139200                 1299
# 3                   175950       132016                 1133
# 4                   199632       157387                 1285
# 5                   204650       151463                 1657
# ...                    ...          ...                  ...
# 295                 183202       139544                 2354
# 296                 199887       147602                 2304
# 297                 207500       160371                 2422
# 298                 177468       141378                 2620
# 299                 192408       145990                 2668
#
#          invalid_second_votes  valid_first_votes  valid_second_votes
# area_id
# 1                        1509             170258              170396
# 2                        1125             137901              138075
# 3                        1141             130883              130875
# 4                        1119             156102              156268
# 5                        1290             149806              150173
# ...                       ...                ...                 ...
# 295                      1818             137190              137726
# 296                      2171             145298              145431
# 297                      2831             157949              157540
# 298                      2668             138758              138710
# 299                      2467             143322              143523
#
# [299 rows x 8 columns]
